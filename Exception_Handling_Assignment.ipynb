# %% [markdown]
# Q1. Parse a deposit amount for banking case 1; use sample reference ACC-1001 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
raw = input("Enter deposit amount: ")

try:
    amount = float(raw)
    print("Account ACC-1001 deposit:", amount)
except ValueError:
    print("Deposit amount must be a valid number.")
# Out:
# Enter deposit amount: abc
# Deposit amount must be a valid number.

# %% [markdown]
# Q2. Handle a missing account key for banking case 1; use sample reference ACC-1002 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path

# %%
accounts = {
    "ACC-1001": 5000.0
}

account = "ACC-1002"

try:
    balance = accounts[account]
    print("Account", account, "balance:", balance)
except KeyError:
    print("Account", account, "was not found.")
# Out:
# Account ACC-1002 was not found.

# %% [markdown]
# Q3. Prevent division by zero in average balance for banking case 1; use sample reference ACC-1003 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1003"

balance = input("Enter balance: ")
months = input("Enter number of months: ")

try:
    balance = float(balance)
    months = int(months)

    average_balance = balance / months
    print("Average balance for", account, ":", average_balance)

except ValueError:
    print("Balance and months must be valid numbers.")
except ZeroDivisionError:
    print("Cannot calculate average balance because months is zero.")
# Out:
# Enter balance: 2500
# Enter number of months: 0
# Cannot calculate average balance because months is zero.

# %% [markdown]
# Q4. Open a transaction file safely for banking case 1; use sample reference ACC-1004 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1004"
file_name = input("Enter transaction file name: ")

try:
    file = open(file_name, "r")
    print("Transaction file opened successfully for", account)
    file.close()

except FileNotFoundError:
    print("Transaction file was not found for", account)

except TypeError:
    print("File name must be a valid string.")
# Out:
# Enter transaction file name: ee
# Transaction file was not found for ACC-1004

# %% [markdown]
# Q5. Reject a negative withdrawal for banking case 1; use sample reference ACC-1005 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1005"

balance = input("Enter balance: ")
withdrawal = input("Enter withdrawal amount: ")

try:
    balance = float(balance)
    withdrawal = float(withdrawal)

    if withdrawal < 0:
        print("Withdrawal amount cannot be negative.")
    elif withdrawal > balance:
        print("Insufficient balance.")
    else:
        balance -= withdrawal
        print("Account", account, "balance:", balance)

except ValueError:
    print("Balance and withdrawal amount must be valid numbers.")
# Out:
# Enter balance: 2300
# Enter withdrawal amount: 1000
# Account ACC-1005 balance: 1300.0

# %% [markdown]
# Q6. Catch invalid tenure input for banking case 1; use sample reference ACC-1006 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1006"

tenure = input("Enter loan tenure in years: ")

try:
    tenure = int(tenure)

    if tenure <= 0:
        print("Tenure must be greater than zero.")
    else:
        print("Valid tenure for", account, ":", tenure, "years")

except ValueError:
    print("Tenure must be a valid whole number.")
# Out:
# Enter loan tenure in years: 2
# Valid tenure for ACC-1006 : 2 years

# %% [markdown]
# Q7. Use else after pin-format validation for banking case 1; use sample reference ACC-1007 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1007"

pin = input("Enter 4-digit PIN: ")

try:
    if len(pin) != 4 or not pin.isdigit():
        raise ValueError("Invalid PIN format")
except ValueError:
    print("PIN must contain exactly 4 digits.")
else:
    print("Valid PIN format for", account)
# Out:
# Enter 4-digit PIN: 32344
# PIN must contain exactly 4 digits.

# %% [markdown]
# Q8. Use finally to close a session for banking case 1; use sample reference ACC-1008 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1008"
session = None
session_id = input("Enter session ID: ")

try:
    if not session_id:
        raise ValueError("Session ID cannot be empty.")

    session = "Session-" + session_id
    print("Session opened for", account)

except ValueError:
    print("Invalid session ID.")

finally:
    if session is not None:
        print("Session closed for", account)
    else:
        print("No session to close for", account)
# Out:
# Enter session ID: 32
# Session opened for ACC-1008
# Session closed for ACC-1008

# %% [markdown]
# Q9. Catch multiple numeric conversion errors for banking case 1; use sample reference ACC-1009 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1009"

balance = input("Enter balance: ")
amount = input("Enter transaction amount: ")

try:
    balance = float(balance)
    amount = float(amount)

    print("Account", account, "transaction amount:", amount)

except (ValueError, TypeError):
    print("Balance and transaction amount must be valid numbers.")
# Out:
# Enter balance: 25000
# Enter transaction amount: 15000
# Account ACC-1009 transaction amount: 15000.0

# %% [markdown]
# Q10. Raise a clear valueerror for banking case 1; use sample reference ACC-1010 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1010"

amount = input("Enter deposit amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Deposit amount must be greater than zero.")

    print("Valid deposit for", account, ":", amount)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter deposit amount: 5000
# Valid deposit for ACC-1010 : 5000.0

# %% [markdown]
# Q11. Parse a deposit amount for banking case 2; use sample reference ACC-1011 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure
# failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1011"
raw = input("Enter deposit amount: ")
try:
    amount = float(raw)
    print("Deposit amount for", account, ":", amount)

except (ValueError, TypeError):
    print("Deposit amount must be a valid number.")
# Out:
# Enter deposit amount: 2000
# Deposit amount for ACC-1011 : 2000.0

# %% [markdown]
# Q12. Handle a missing account key for banking case 2; use sample reference ACC-1012 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1012"
accounts = {
    "ACC-1001": 5000.0,
    "ACC-1011": 2500.0
}
try:
    account_input = input("Enter account reference: ")
    if account_input == "":
        raise ValueError("Account reference cannot be empty.")
    balance = accounts[account_input]
    print("Account", account_input, "balance:", balance)
except ValueError as e:
    print("Error:", e)
except KeyError:
    print("Account", account_input, "was not found.")
# Out:
# Enter account reference: ACC-1001
# Account ACC-1001 balance: 5000.0

# %% [markdown]
# Q13. Prevent division by zero in average balance for banking case 2; use sample reference ACC-1013 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1013"
balance = input("Enter balance: ")
months = input("Enter number of months: ")
try:
    balance = float(balance)
    months = int(months)
    if months == 0:
        raise ZeroDivisionError("Number of months cannot be zero.")
    average_balance = balance / months
    print("Average balance for", account, ":", average_balance)
except ValueError:
    print("Balance and months must be valid numbers.")

except ZeroDivisionError as e:
    print("Error:", e)
# Out:
# Enter balance: 30000
# Enter number of months: 5
# Average balance for ACC-1013 : 6000.0

# %% [markdown]
# Q14. Open a transaction file safely for banking case 2; use sample reference ACC-1014 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1014"

file_name = input("Enter file name: ")

try:
    file = open(file_name, "r")
    print("Transaction file opened successfully for", account)
    file.close()

except FileNotFoundError:
    print("Transaction file was not found for", account)
# Out:
# Enter file name: transactions.txt
# Transaction file was not found for ACC-1014

# %% [markdown]
# Q15. Reject a negative withdrawal for banking case 2; use sample reference ACC-1015 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1015"
balance = input("Enter balance: ")
withdrawal = input("Enter withdrawal amount: ")
try:
    balance = float(balance)
    withdrawal = float(withdrawal)
    if withdrawal < 0:
        print("Withdrawal amount cannot be negative.")
    elif withdrawal > balance:
        print("Insufficient balance.")
    else:
        balance = balance - withdrawal
        print("Withdrawal successful for", account)
        print("Remaining balance:", balance)
except ValueError:
    print("Balance and withdrawal amount must be valid numbers.")
# Out:
# Enter balance: 2000
# Enter withdrawal amount: 1500
# Withdrawal successful for ACC-1015
# Remaining balance: 500.0

# %% [markdown]
# Q16. Catch invalid tenure input for banking case 2; use sample reference ACC-1016 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1016"
tenure = input("Enter loan tenure in years: ")
try:
    tenure = int(tenure)
    if tenure <= 0:
        print("Tenure must be greater than zero.")
    else:
        print("Valid tenure for", account, ":", tenure, "years")
except ValueError:
    print("Tenure must be a valid whole number.")
# Out:
# Enter loan tenure in years: 0
# Tenure must be greater than zero.

# %% [markdown]
# Q17. Use else after pin-format validation for banking case 2; use sample reference ACC-1017 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1017"

pin = input("Enter 4-digit PIN: ")

try:
    if len(pin) != 4 or not pin.isdigit():
        raise ValueError("Invalid PIN format")

except ValueError:
    print("PIN must contain exactly 4 digits.")

else:
    print("Valid PIN format for", account)
# Out:
# Enter 4-digit PIN: 374
# PIN must contain exactly 4 digits.

# %% [markdown]
# Q18. Use finally to close a session for banking case 2; use sample reference ACC-1018 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1018"
session_id = input("Enter session ID: ")
session = None
try:
    if session_id == "":
        raise ValueError("Session ID cannot be empty.")
    session = "Session-" + session_id
    print("Session opened for", account)
except ValueError as e:
    print("Error:", e)
finally:
    if session is not None:
        print("Session closed for", account)
    else:
        print("No session to close for", account)
# Out:
# Enter session ID: ab
# Session opened for ACC-1018
# Session closed for ACC-1018

# %% [markdown]
# Q19. Catch multiple numeric conversion errors for banking case 2; use sample reference ACC-1019 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1019"
balance = input("Enter balance: ")
amount = input("Enter transaction amount: ")
try:
    balance = float(balance)
    amount = float(amount)
    print("Account", account, "transaction amount:", amount)
except (ValueError, TypeError):
    print("Balance and transaction amount must be valid numbers.")
# Out:
# Enter balance: 20000
# Enter transaction amount: 10000
# Account ACC-1019 transaction amount: 10000.0

# %% [markdown]
# Q20. Raise a clear valueerror for banking case 2; use sample reference ACC-1020 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1020"

amount = input("Enter deposit amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Deposit amount must be greater than zero.")

    print("Valid deposit for", account, ":", amount)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter deposit amount: 0
# Error: Deposit amount must be greater than zero.

# %% [markdown]
# Q21. Parse a deposit amount for banking case 3; use sample reference ACC-1021 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1021"
raw = input("Enter deposit amount: ")
try:
    if raw == "":
        raise ValueError("Deposit amount cannot be empty.")
    amount = float(raw)
    print("Deposit amount for", account, ":", amount)
except ValueError as e:
    print("Error:", e)
except TypeError:
    print("Deposit amount must be a valid number.")
# Out:
# Enter deposit amount: 20000
# Deposit amount for ACC-1021 : 20000.0

# %% [markdown]
# Q22. Handle a missing account key for banking case 3; use sample reference ACC-1022 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1022"
accounts = {
    "ACC-1001": 5000.0,
    "ACC-1011": 2500.0
}
account_input = input("Enter account reference: ")
try:
    if account_input == "":
        raise ValueError("Account reference cannot be empty.")
    balance = accounts[account_input]
    print("Account", account_input, "balance:", balance)
except ValueError as e:
    print("Error:", e)
except KeyError:
    print("Account", account_input, "was not found.")
except TypeError:
    print("Account reference must be a valid string.")
# Out:
# Enter account reference: ACC-1011
# Account ACC-1011 balance: 2500.0

# %% [markdown]
# Q23. Prevent division by zero in average balance for banking case 3; use sample reference ACC-1023 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1023"

balance = input("Enter balance: ")
months = input("Enter number of months: ")

try:
    balance = float(balance)
    months = int(months)

    if months == 0:
        raise ZeroDivisionError("Number of months cannot be zero.")

    average_balance = balance / months

    print("Average balance for", account, ":", average_balance)

except ValueError:
    print("Balance and months must be valid numbers.")

except ZeroDivisionError as e:
    print("Error:", e)
# Out:
# Enter balance: 10000
# Enter number of months: 8
# Average balance for ACC-1023 : 1250.0

# %% [markdown]
# Q24. Open a transaction file safely for banking case 3; use sample reference ACC-1024 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1024"
file_name = input("Enter transaction file name: ")
try:
    if file_name == "":
        raise ValueError("File name cannot be empty.")
    file = open(file_name, "r")
    print("Transaction file opened successfully for", account)
    file.close()
except ValueError as e:
    print("Error:", e)
except FileNotFoundError:
    print("Transaction file was not found for", account)
except TypeError:
    print("File name must be a valid string.")
# Out:
# Enter transaction file name: abc.txt
# Transaction file was not found for ACC-1024

# %% [markdown]
# Q25. Reject a negative withdrawal for banking case 3; use sample reference ACC-1025 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1025"
balance = input("Enter balance: ")
withdrawal = input("Enter withdrawal amount: ")
try:
    balance = float(balance)
    withdrawal = float(withdrawal)
    if withdrawal < 0:
        print("Withdrawal cannot be negative.")
    elif withdrawal > balance:
        print("Insufficient balance.")
    else:
        balance = balance - withdrawal
        print("Withdrawal successful for", account)
        print("Remaining balance:", balance)
except ValueError:
    print("Enter valid numbers.")
# Out:
# Enter balance: 20000
# Enter withdrawal amount: 5000
# Withdrawal successful for ACC-1025
# Remaining balance: 15000.0

# %% [markdown]
# Q26. Catch invalid tenure input for banking case 3; use sample reference ACC-1026 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1026"
tenure = input("Enter loan tenure in years: ")
try:
    tenure = int(tenure)
    if tenure <= 0:
        print("Tenure must be greater than zero.")
    else:
        print("Valid tenure for", account, ":", tenure, "years")
except ValueError:
    print("Enter a valid whole number.")
# Out:
# Enter loan tenure in years: 6
# Valid tenure for ACC-1026 : 6 years

# %% [markdown]
# Q27. Use else after pin-format validation for banking case 3; use sample reference ACC-1027 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1027"
pin = input("Enter 4-digit PIN: ")
try:
    if len(pin) != 4 or not pin.isdigit():
        raise ValueError("Invalid PIN")
except ValueError:
    print("PIN must contain exactly 4 digits.")
else:
    print("Valid PIN for", account)
# Out:
# Enter 4-digit PIN: 23
# PIN must contain exactly 4 digits.

# %% [markdown]
# Q28. Use finally to close a session for banking case 3; use sample reference ACC-1028 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1028"
session = None
session_id = input("Enter session ID: ")
try:
    if session_id == "":
        raise ValueError("Session ID cannot be empty.")
    session = "Session-" + session_id
    print("Session opened for", account)
except ValueError as e:
    print("Error:", e)
finally:
    if session is not None:
        print("Session closed for", account)
    else:
        print("No session to close for", account)
# Out:
# Enter session ID:
# Error: Session ID cannot be empty.
# No session to close for ACC-1028

# %% [markdown]
# Q29. Catch multiple numeric conversion errors for banking case 3; use sample reference ACC-1029 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1029"

balance = input("Enter balance: ")
amount = input("Enter transaction amount: ")

try:
    balance = float(balance)
    amount = float(amount)

    print("Transaction amount for", account, ":", amount)

except (ValueError, TypeError):
    print("Enter valid numbers.")
# Out:
# Enter balance: 5000
# Enter transaction amount: 1500
# Transaction amount for ACC-1029 : 1500.0

# %% [markdown]
# Q30. Raise a clear valueerror for banking case 3; use sample reference ACC-1030 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1030"

amount = input("Enter deposit amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Deposit amount must be greater than zero.")

    print("Valid deposit for", account, ":", amount)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter deposit amount: 5000
# Valid deposit for ACC-1030 : 5000.0

# %% [markdown]
# Medium
#
# Reusable components and multi-step workflows.
#
# Q31. Create insufficientfundserror for banking case 1; use sample reference
#
# ACC-1031 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InsufficientFundsError(Exception):
    pass
account = "ACC-1031"
balance = input("Enter balance: ")
withdrawal = input("Enter withdrawal amount: ")
try:
    balance = float(balance)
    withdrawal = float(withdrawal)
    if withdrawal < 0:
        raise ValueError("Withdrawal cannot be negative.")
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds.")
    balance = balance - withdrawal
    print("Withdrawal successful for", account)
    print("Remaining balance:", balance)
except ValueError as e:
    print("Error:", e)
except InsufficientFundsError as e:
    print("Error:", e)
# Out:
# Enter balance: 20000
# Enter withdrawal amount: 40000
# Error: Insufficient funds.

# %% [markdown]
# Q32. Chain invalidtransactionerror from valueerror for banking case 1; use sample reference ACC-1032 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InvalidTransactionError(Exception):
    pass


account = "ACC-1032"

amount = input("Enter transaction amount: ")

try:
    if amount == "":
        raise ValueError("Amount cannot be empty.")


    amount = float(amount)

    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")

except ValueError as e:
    raise InvalidTransactionError("Invalid transaction for " + account) from e
# Out:
# Enter transaction amount: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1204/2480399365.py in <cell line: 0>()
#      16     if amount <= 0:
# ---> 17         raise ValueError("Amount must be greater than zero.")
#      18
#
# ValueError: Amount must be greater than zero.
#
# The above exception was the direct cause of the following exception:
#
# InvalidTransactionError                   Traceback (most recent call last)
# /tmp/ipykernel_1204/2480399365.py in <cell line: 0>()
#      18
#      19 except ValueError as e:
# ---> 20     raise InvalidTransactionError("Invalid transaction for " + account) from e
#
# InvalidTransactionError: Invalid transaction for ACC-1032

# %% [markdown]
# Q33. Process transfers while isolating bad rows for banking case 1; use sample reference ACC-1033 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
id="73924"
class InvalidTransferError(Exception):
    pass
account = "ACC-1033"

transfers = [
    ("ACC-2001", "1000"),
    ("ACC-2002", "abc"),
    ("ACC-2003", "500")
]
for receiver, amount in transfers:
    try:
        if amount == "":
            raise ValueError("Amount is empty.")
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be greater than zero.")
        print("Transfer to", receiver, "successful:", amount)
    except (ValueError, TypeError) as e:
        print("Bad transfer for", receiver, ":", e)
print("Transfer processing completed for", account)
# Out:
# Transfer to ACC-2001 successful: 1000.0
# Bad transfer for ACC-2002 : could not convert string to float: 'abc'
# Transfer to ACC-2003 successful: 500.0
# Transfer processing completed for ACC-1033

# %% [markdown]
# Q34. Retry a transient payment gateway for banking case 1; use sample reference ACC-1034 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentGatewayError(Exception):
    pass
account = "ACC-1034"
amount = input("Enter payment amount: ")
try:
    if amount == "":
        raise ValueError("Amount cannot be empty.")
    amount = float(amount)
    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")
    for attempt in range(3):
        try:
            if attempt < 2:
                raise PaymentGatewayError("Gateway temporarily unavailable.")
            print("Payment successful for", account)
            break
        except PaymentGatewayError as e:
            print("Attempt", attempt + 1, "failed:", e)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter payment amount: 3000
# Attempt 1 failed: Gateway temporarily unavailable.
# Attempt 2 failed: Gateway temporarily unavailable.
# Payment successful for ACC-1034

# %% [markdown]
# Q35. Log failed standing instructions for banking case 1; use sample reference
# ACC-1035 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass


account = "ACC-1035"

amount = input("Enter standing instruction amount: ")

try:
    if amount == "":
        raise ValueError("Amount cannot be empty.")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")

    try:
        # Simulate a failed standing instruction
        raise PaymentError("Payment failed.")

    except PaymentError as e:
        print("Standing instruction failed for", account)
        print("Log:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter standing instruction amount: 0
# Error: Amount must be greater than zero.

# %% [markdown]
# Q36. Return a structured failure result for banking case 1; use sample reference ACC-1036 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1036"

amount = input("Enter withdrawal amount: ")

try:
    if amount == "":
        raise ValueError("Amount cannot be empty.")

    amount = float(amount)

    if amount < 0:
        return_result = {
            "account": account,
            "success": False,
            "error": "Withdrawal cannot be negative."
        }

    else:
        balance = 5000

        if amount > balance:
            return_result = {
                "account": account,
                "success": False,
                "error": "Insufficient funds."
            }
        else:
            balance = balance - amount
            return_result = {
                "account": account,
                "success": True,
                "balance": balance
            }

except ValueError as e:
    return_result = {
        "account": account,
        "success": False,
        "error": str(e)
    }

except TypeError:
    return_result = {
        "account": account,
        "success": False,
        "error": "Invalid amount type."
    }

print(return_result)

# %% [markdown]
# Q37. Validate a nested beneficiary record for banking case 1; use sample reference ACC-1037 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1037"

beneficiary = {
    "name": input("Enter beneficiary name: "),
    "bank": {
        "account": input("Enter beneficiary account: ")
    }
}

try:
    name = beneficiary["name"]
    acc_no = beneficiary["bank"]["account"]

    if name == "" or acc_no == "":
        raise ValueError("Beneficiary details cannot be empty.")

    print("Valid beneficiary for", account)

except KeyError:
    print("Beneficiary record is missing a required field.")

except ValueError as e:
    print("Error:", e)
# Out:
# Enter beneficiary name: abc
# Enter beneficiary account: 12345
# Valid beneficiary for ACC-1037

# %% [markdown]
# Q38. Use a context manager for an audit file for banking case 1; use sample reference ACC-1038 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1038"

file_name = input("Enter audit file name: ")

try:
    if file_name == "":
        raise ValueError("File name cannot be empty.")

    with open(file_name, "w") as file:
        file.write("Audit record for " + account)

    print("Audit file written successfully.")

except ValueError as e:
    print("Error:", e)

except (FileNotFoundError, PermissionError):
    print("Unable to access the audit file.")

except TypeError:
    print("File name must be a string.")
# Out:
# Enter audit file name: audit.txt
# Audit file written successfully.

# %% [markdown]
# Q39. Separate validation and recovery for banking case 1; use sample reference ACC-1039 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1039"
balance = 5000

# Validation
amount = input("Enter withdrawal amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")

    if amount > balance:
        raise ValueError("Insufficient balance.")

except ValueError as e:
    print("Validation failed:", e)

else:
    # Recovery-safe update
    old_balance = balance

    try:
        balance = balance - amount
        print("Withdrawal successful for", account)
        print("Remaining balance:", balance)

    except Exception:
        balance = old_balance
        print("Withdrawal failed. Balance restored.")
# Out:
# Enter withdrawal amount: 3000
# Withdrawal successful for ACC-1039
# Remaining balance: 2000.0

# %% [markdown]
# Q40. Collect all kyc validation errors for banking case 1; use sample reference ACC-1040 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1040"
name = input("Enter name: ")
age = input("Enter age: ")
pan = input("Enter PAN: ")
errors = []
if name == "":
    errors.append("Name cannot be empty.")
try:
    age = int(age)
    if age < 18:
        errors.append("Age must be 18 or above.")
except ValueError:
    errors.append("Age must be a valid number.")
if pan == "":
    errors.append("PAN cannot be empty.")
if errors:
    print("KYC validation failed for", account)
    for error in errors:
        print("-", error)
else:
    print("KYC validation successful for", account)
# Out:
# Enter name: surekha
# Enter age: 22
# Enter PAN:
# KYC validation failed for ACC-1040
# - PAN cannot be empty.

# %% [markdown]
# Q41. Create insufficientfundserror for banking case 2; use sample reference ACC-1041 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InsufficientFundsError(Exception):
    pass
account = "ACC-1041"
balance = 5000
amount = input("Enter withdrawal amount: ")
try:
    amount = float(amount)
    if amount < 0:
        raise ValueError("Withdrawal cannot be negative.")
    if amount > balance:
        raise InsufficientFundsError("Insufficient funds.")
    balance = balance - amount
    print("Withdrawal successful for", account)
    print("Remaining balance:", balance)
except ValueError as e:
    print("Error:", e)
except InsufficientFundsError as e:
    print("Error:", e)
# Out:
# Enter withdrawal amount: 5000
# Withdrawal successful for ACC-1041
# Remaining balance: 0.0

# %% [markdown]
# Q42. Chain invalidtransactionerror from valueerror for banking case 2; use sample reference ACC-1042 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InvalidTransactionError(Exception):
    pass


account = "ACC-1042"

amount = input("Enter transaction amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")

except ValueError as e:
    raise InvalidTransactionError("Invalid transaction for " + account) from e

else:
    print("Transaction successful for", account)
# Out:
# Enter transaction amount: 2000
# Transaction successful for ACC-1042

# %% [markdown]
# Q43. Process transfers while isolating bad rows for banking case 2; use sample reference ACC-1043 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1043"

transfers = [
    ("ACC-2001", "1000"),
    ("ACC-2002", "abc"),
    ("ACC-2003", "500")
]

for receiver, amount in transfers:
    try:
        if amount == "":
            raise ValueError("Amount cannot be empty.")

        amount = float(amount)

        if amount <= 0:
            raise ValueError("Amount must be greater than zero.")

        print("Transfer successful to", receiver)

    except (ValueError, TypeError) as e:
        print("Bad transfer:", receiver, "-", e)

print("Transfer processing completed for", account)
# Out:
# Transfer successful to ACC-2001
# Bad transfer: ACC-2002 - could not convert string to float: 'abc'
# Transfer successful to ACC-2003
# Transfer processing completed for ACC-1043

# %% [markdown]
# Q44. Retry a transient payment gateway for banking case 2; use sample reference ACC-1044 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentGatewayError(Exception):
    pass

account = "ACC-1044"
amount = input("Enter payment amount: ")
try:
    amount = float(amount)
    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")
    for attempt in range(3):
        try:
            if attempt < 2:
                raise PaymentGatewayError("Gateway temporarily unavailable.")
            print("Payment successful for", account)
            break
        except PaymentGatewayError:
            print("Retrying payment...")
except ValueError as e:
    print("Error:", e)
# Out:
# Enter payment amount: 50000
# Retrying payment...
# Retrying payment...
# Payment successful for ACC-1044

# %% [markdown]
# Q45. Log failed standing instructions for banking case 2; use sample reference ACC-1045 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass

account = "ACC-1045"
amount = input("Enter standing instruction amount: ")
try:
    amount = float(amount)
    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")
    try:
        # Simulate payment failure
        raise PaymentError("Payment failed.")
    except PaymentError as e:
        print("Failed standing instruction for", account)
        print("Log:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter standing instruction amount: 10000
# Failed standing instruction for ACC-1045
# Log: Payment failed.

# %% [markdown]
# Q46. Return a structured failure result for banking case 2; use sample reference ACC-1046 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1046"
balance = 5000

amount = input("Enter withdrawal amount: ")

try:
    amount = float(amount)

    if amount > balance:
        result = {"success": False, "error": "Insufficient funds"}
    elif amount < 0:
        result = {"success": False, "error": "Negative amount"}
    else:
        balance = balance - amount
        result = {"success": True, "balance": balance}

except ValueError:
    result = {"success": False, "error": "Invalid amount"}

print(result)
# Out:
# Enter withdrawal amount: 5000
# {'success': True, 'balance': 0.0}

# %% [markdown]
# Q47. Validate a nested beneficiary record for banking case 2; use sample reference ACC-1047 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1047"
beneficiary = {
    "name": input("Enter beneficiary name: "),
    "bank": {
        "account": input("Enter beneficiary account: ")
    }
}
try:
    name = beneficiary["name"]
    acc_no = beneficiary["bank"]["account"]
    if name == "" or acc_no == "":
        raise ValueError("Beneficiary details cannot be empty.")
    print("Valid beneficiary for", account)
except ValueError as e:
    print("Error:", e)
except KeyError:
    print("Beneficiary record is incomplete.")
except TypeError:
    print("Invalid beneficiary type.")
# Out:
# Enter beneficiary name: rahul
# Enter beneficiary account: 2452
# Valid beneficiary for ACC-1047

# %% [markdown]
# Q48. Use a context manager for an audit file for banking case 2; use sample reference ACC-1048 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1048"
file_name = input("Enter audit file name: ")
try:
    # Business/input validation
    if file_name == "":
        raise ValueError("File name cannot be empty.")
    # Risky statement: opening/writing the file
    with open(file_name, "w") as file:
        file.write("Audit record for " + account)
    print("Audit file written successfully for", account)
except ValueError as e:
    print("Validation error:", e)
except (FileNotFoundError, PermissionError, OSError) as e:
    print("Audit file operation failed:", e)
except TypeError:
    print("File name must be a valid string.")
# Out:
# Enter audit file name: trans.txt
# Audit file written successfully for ACC-1048

# %% [markdown]
# Q49. Separate validation and recovery for banking case 2; use sample reference ACC-1049 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1049"
balance = 5000
amount = input("Enter withdrawal amount: ")
try:
    if amount == "":
        raise ValueError("Amount cannot be empty.")
    amount = float(amount)
    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")
    if amount > balance:
        raise ValueError("Insufficient balance.")
    old_balance = balance
    balance = balance - amount
    print("Withdrawal successful for", account)
    print("Remaining balance:", balance)
except ValueError as e:
    print("Error:", e)
except TypeError:
    balance = old_balance
    print("Invalid amount. Balance restored.")
# Out:
# Enter withdrawal amount: 10000
# Error: Insufficient balance.

# %% [markdown]
# Q50. Collect all kyc validation errors for banking case 2; use sample reference ACC-1050 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1050"
name = input("Enter name: ")
age = input("Enter age: ")
pan = input("Enter PAN: ")
errors = []
if name == "":
    errors.append("Name is empty")
try:
    age = int(age)
    if age < 18:
        errors.append("Age must be 18 or above")
except ValueError:
    errors.append("Invalid age")
if pan == "":
    errors.append("PAN is empty")
if errors:
    print("KYC failed for", account)
    for error in errors:
        print(error)
else:
    print("KYC successful for", account)
# Out:
# Enter name: priya
# Enter age: 27
# Enter PAN: ehq7wdh
# KYC successful for ACC-1050

# %% [markdown]
# Q51. Create insufficientfundserror for banking case 3; use sample reference ACC-1051 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InsufficientFundsError(Exception):
    pass
account = "ACC-1051"
balance = 5000
amount = input("Enter withdrawal amount: ")
try:
    amount = float(amount)
    if amount > balance:
        raise InsufficientFundsError("Insufficient funds")
    balance = balance - amount
    print("Withdrawal successful")
    print("Balance:", balance)
except ValueError:
    print("Enter a valid amount")
except InsufficientFundsError as e:
    print("Error:", e)
# Out:
# Enter withdrawal amount: 3000
# Withdrawal successful
# Balance: 2000.0

# %% [markdown]
# Q52. Chain invalidtransactionerror from valueerror for banking case 3; use sample reference ACC-1052 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InvalidTransactionError(Exception):
    pass

account = "ACC-1052"
amount = input("Enter transaction amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Amount must be greater than zero")

except ValueError as e:
    raise InvalidTransactionError(
        "Invalid transaction for " + account
    ) from e
# Out:
# Enter transaction amount: 5000

# %% [markdown]
# Q53. Process transfers while isolating bad rows for banking case 3; use sample reference ACC-1053 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1053"
transfers = [
    ("ACC-2001", "1000"),
    ("ACC-2002", "abc"),
    ("ACC-2003", "500")
]
for receiver, amount in transfers:
    try:
        if amount == "":
            raise ValueError("Amount is empty")
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be greater than zero")
        print("Transfer successful to", receiver)
    except ValueError as e:
        print("Bad transfer:", receiver, "-", e)
print("Transfer processing completed for", account)
# Out:
# Transfer successful to ACC-2001
# Bad transfer: ACC-2002 - could not convert string to float: 'abc'
# Transfer successful to ACC-2003
# Transfer processing completed for ACC-1053

# %% [markdown]
# Q54. Retry a transient payment gateway for banking case 3; use sample reference ACC-1054 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentGatewayError(Exception):
    pass

account = "ACC-1054"
amount = input("Enter payment amount: ")
try:
    amount = float(amount)
    if amount <= 0:
        raise ValueError("Amount must be greater than zero")
    for attempt in range(3):
        try:
            if attempt < 2:
                raise PaymentGatewayError("Gateway temporarily unavailable")
            print("Payment successful for", account)
            break
        except PaymentGatewayError as e:
            print("Attempt", attempt + 1, "failed:", e)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter payment amount: 3000
# Attempt 1 failed: Gateway temporarily unavailable
# Attempt 2 failed: Gateway temporarily unavailable
# Payment successful for ACC-1054

# %% [markdown]
# Q55. Log failed standing instructions for banking case 3; use sample reference ACC-1055 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass

account = "ACC-1055"
amount = input("Enter standing instruction amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Amount must be greater than zero")

    # Simulate payment failure
    raise PaymentError("Payment failed")

except ValueError as e:
    print("Error:", e)

except PaymentError as e:
    print("Standing instruction failed for", account)
    print("Log:", e)
# Out:
# Enter standing instruction amount: 2000
# Standing instruction failed for ACC-1055
# Log: Payment failed

# %% [markdown]
# Q56. Return a structured failure result for banking case 3; use sample reference ACC-1056 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1056"
balance = 5000

amount = input("Enter amount: ")

try:
    amount = float(amount)

    if amount > balance:
        result = {"success": False, "error": "Insufficient funds"}
    else:
        balance = balance - amount
        result = {"success": True, "balance": balance}

except ValueError:
    result = {"success": False, "error": "Invalid amount"}

print(result)
# Out:
# Enter amount: 20000
# {'success': False, 'error': 'Insufficient funds'}

# %% [markdown]
# Q57. Validate a nested beneficiary record for banking case 3; use sample reference ACC-1057 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1057"

beneficiary = {
    "name": input("Enter beneficiary name: "),
    "bank": {
        "account": input("Enter beneficiary account: ")
    }
}

try:
    name = beneficiary["name"]
    acc = beneficiary["bank"]["account"]

    if name == "" or acc == "":
        raise ValueError("Details cannot be empty")

    print("Valid beneficiary for", account)

except ValueError as e:
    print("Error:", e)

except KeyError:
    print("Missing beneficiary details")

except TypeError:
    print("Invalid beneficiary type")
# Out:
# Enter beneficiary name: ravi
# Enter beneficiary account: 4389
# Valid beneficiary for ACC-1057

# %% [markdown]
# Q58. Use a context manager for an audit file for banking case 3; use sample reference ACC-1058 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1058"

file_name = input("Enter audit file name: ")

try:
    if file_name == "":
        raise ValueError("File name cannot be empty")

    with open(file_name, "w") as file:
        file.write("Audit record for " + account)

    print("Audit file created successfully")

except ValueError as e:
    print("Error:", e)

except (FileNotFoundError, PermissionError):
    print("File operation failed")

except TypeError:
    print("Invalid file name")
# Out:
# Enter audit file name: audit.txt
# Audit file created successfully

# %% [markdown]
# Q59. Separate validation and recovery for banking case 3; use sample reference ACC-1059 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1059"
balance = 5000

amount = input("Enter withdrawal amount: ")

# Validation
try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

except ValueError as e:
    print("Validation failed:", e)

else:
    # Recovery
    old_balance = balance

    try:
        balance = balance - amount
        print("Withdrawal successful for", account)
        print("Balance:", balance)

    except TypeError:
        balance = old_balance
        print("Withdrawal failed. Balance restored.")
# Out:
# Enter withdrawal amount: 5000
# Withdrawal successful for ACC-1059
# Balance: 0.0

# %% [markdown]
# Q60. Collect all kyc validation errors for banking case 3; use sample reference ACC-1060 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1060"

name = input("Enter name: ")
age = input("Enter age: ")
pan = input("Enter PAN: ")

errors = []

if name == "":
    errors.append("Name is empty")

try:
    age = int(age)

    if age < 18:
        errors.append("Age must be 18 or above")

except ValueError:
    errors.append("Invalid age")

if pan == "":
    errors.append("PAN is empty")

if errors:
    print("KYC failed for", account)

    for error in errors:
        print("-", error)
else:
    print("KYC successful for", account)
# Out:
# Enter name: surekha
# Enter age: 22
# Enter PAN: wjr48fjce
# KYC successful for ACC-1060

# %% [markdown]
# Q61. Create insufficientfundserror for banking case 4; use sample reference ACC-1061 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InsufficientFundsError(Exception):
    pass

account = "ACC-1061"
balance = 5000

amount = input("Enter withdrawal amount: ")

try:
    amount = float(amount)

    if amount > balance:
        raise InsufficientFundsError("Insufficient funds")

    balance = balance - amount

    print("Withdrawal successful")
    print("Balance:", balance)

except ValueError:
    print("Enter a valid amount")

except InsufficientFundsError as e:
    print("Error:", e)
# Out:
# Enter withdrawal amount: 10000
# Error: Insufficient funds

# %% [markdown]
# Q62. Chain invalidtransactionerror from valueerror for banking case 4; use sample reference ACC-1062 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InvalidTransactionError(Exception):
    pass

account = "ACC-1062"
amount = input("Enter transaction amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Amount must be greater than zero")

except ValueError as e:
    raise InvalidTransactionError(
        "Invalid transaction for " + account
    ) from e
# Out:
# Enter transaction amount: 10000

# %% [markdown]
# Q63. Process transfers while isolating bad rows for banking case 4; use sample reference ACC-1063 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1063"

transfers = [
    ("ACC-2001", "1000"),
    ("ACC-2002", "abc"),
    ("ACC-2003", "500")
]

for receiver, amount in transfers:
    try:
        amount = float(amount)

        if amount <= 0:
            raise ValueError("Invalid amount")

        print("Transfer successful to", receiver)

    except ValueError as e:
        print("Bad transfer:", receiver, "-", e)

print("Transfer processing completed for", account)
# Out:
# Transfer successful to ACC-2001
# Bad transfer: ACC-2002 - could not convert string to float: 'abc'
# Transfer successful to ACC-2003
# Transfer processing completed for ACC-1063

# %% [markdown]
# Q64. Retry a transient payment gateway for banking case 4; use sample reference ACC-1064 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentGatewayError(Exception):
    pass

account = "ACC-1064"
amount = input("Enter payment amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    for attempt in range(3):
        try:
            if attempt < 2:
                raise PaymentGatewayError("Gateway failed")

            print("Payment successful for", account)
            break

        except PaymentGatewayError as e:
            print("Attempt", attempt + 1, "failed:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter payment amount: 12000
# Attempt 1 failed: Gateway failed
# Attempt 2 failed: Gateway failed
# Payment successful for ACC-1064

# %% [markdown]
# Q65. Log failed standing instructions for banking case 4; use sample reference ACC-1065 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass

account = "ACC-1065"
amount = input("Enter standing instruction amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    # Payment failure
    raise PaymentError("Payment failed")

except ValueError as e:
    print("Error:", e)

except PaymentError as e:
    print("Standing instruction failed for", account)
    print("Log:", e)
# Out:
# Enter standing instruction amount: 2000
# Standing instruction failed for ACC-1065
# Log: Payment failed

# %% [markdown]
# Q66. Return a structured failure result for banking case 4; use sample reference ACC-1066 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1066"
balance = 5000

amount = input("Enter withdrawal amount: ")

try:
    amount = float(amount)

    if amount > balance:
        result = {
            "account": account,
            "success": False,
            "error": "Insufficient funds"
        }
    else:
        balance = balance - amount
        result = {
            "account": account,
            "success": True,
            "balance": balance
        }

except ValueError:
    result = {
        "account": account,
        "success": False,
        "error": "Invalid amount"
    }

print(result)
# Out:
# Enter withdrawal amount: 5000
# {'account': 'ACC-1066', 'success': True, 'balance': 0.0}

# %% [markdown]
# Q67. Validate a nested beneficiary record for banking case 4; use sample reference ACC-1067 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1067"

beneficiary = {
    "name": input("Enter beneficiary name: "),
    "bank": {
        "account": input("Enter beneficiary account: ")
    }
}

try:
    name = beneficiary["name"]
    acc = beneficiary["bank"]["account"]

    if name == "" or acc == "":
        raise ValueError("Details cannot be empty")

    print("Valid beneficiary for", account)

except ValueError as e:
    print("Error:", e)

except KeyError:
    print("Missing beneficiary details")

except TypeError:
    print("Invalid beneficiary type")
# Out:
# Enter beneficiary name: asritha
# Enter beneficiary account: 20000
# Valid beneficiary for ACC-1067

# %% [markdown]
# Q68. Use a context manager for an audit file for banking case 4; use sample reference ACC-1068 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1068"

file_name = input("Enter audit file name: ")

try:
    if file_name == "":
        raise ValueError("File name cannot be empty")

    with open(file_name, "w") as file:
        file.write("Audit record for " + account)

    print("Audit file created successfully")

except ValueError as e:
    print("Error:", e)

except (FileNotFoundError, PermissionError):
    print("File operation failed")

except TypeError:
    print("Invalid file name")
# Out:
# Enter audit file name: file.txt
# Audit file created successfully

# %% [markdown]
# Q69. Separate validation and recovery for banking case 4; use sample reference ACC-1069 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1069"
balance = 5000

amount = input("Enter withdrawal amount: ")

# Validation
try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

except ValueError as e:
    print("Validation failed:", e)

else:
    # Recovery
    old_balance = balance

    try:
        balance = balance - amount
        print("Withdrawal successful for", account)
        print("Balance:", balance)

    except TypeError:
        balance = old_balance
        print("Withdrawal failed. Balance restored.")
# Out:
# Enter withdrawal amount: 4000
# Withdrawal successful for ACC-1069
# Balance: 1000.0

# %% [markdown]
# Q70. Collect all kyc validation errors for banking case 4; use sample reference ACC-1070 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1070"

name = input("Enter name: ")
age = input("Enter age: ")
pan = input("Enter PAN: ")

errors = []

if name == "":
    errors.append("Name is empty")

try:
    age = int(age)
    if age < 18:
        errors.append("Age must be 18 or above")
except ValueError:
    errors.append("Invalid age")

if pan == "":
    errors.append("PAN is empty")

if errors:
    print("KYC failed for", account)
    for error in errors:
        print("-", error)
else:
    print("KYC successful for", account)
# Out:
# Enter name: suri
# Enter age: 29
# Enter PAN: hhhhhhhh
# KYC successful for ACC-1070

# %% [markdown]
# Difficult
#
# Architecture, edge cases, and end-to-end banking systems.
#
# Q71. Design a banking exception hierarchy for banking case 1; use sample
# reference ACC-1071 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankingError(Exception):
    pass

class InsufficientFundsError(BankingError):
    pass

class InvalidAmountError(BankingError):
    pass


account = "ACC-1071"
balance = 5000

amount = input("Enter withdrawal amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise InvalidAmountError("Invalid amount")

    if amount > balance:
        raise InsufficientFundsError("Insufficient funds")

    balance = balance - amount

    print("Withdrawal successful")
    print("Balance:", balance)

except InvalidAmountError as e:
    print("Error:", e)

except InsufficientFundsError as e:
    print("Error:", e)
# Out:
# Enter withdrawal amount: 4000
# Withdrawal successful
# Balance: 1000.0

# %% [markdown]
# Q72. Make a transfer rollback-safe for banking case 1; use sample reference ACC-1072 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1072"

sender = 5000
receiver = 2000

amount = input("Enter amount: ")

try:
    amount = float(amount)

    if amount > sender:
        raise ValueError("Insufficient balance")

    old_sender = sender
    old_receiver = receiver

    sender = sender - amount
    receiver = receiver + amount

    print("Transfer successful")
    print("Sender:", sender)
    print("Receiver:", receiver)

except ValueError as e:
    sender = old_sender if "old_sender" in locals() else sender
    receiver = old_receiver if "old_receiver" in locals() else receiver
    print("Transfer failed:", e)
# Out:
# Enter amount: 5000
# Transfer successful
# Sender: 0.0
# Receiver: 7000.0

# %% [markdown]
# Q73. Preserve causes across service layers for banking case 1; use sample reference ACC-1073 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass


account = "ACC-1073"
balance = 5000

amount = input("Enter amount: ")

try:
    try:
        amount = float(amount)

        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > balance:
            raise ValueError("Insufficient balance")

    except ValueError as e:
        raise PaymentError("Payment validation failed") from e

    old_balance = balance

    try:
        balance = balance - amount

        # Service failure
        raise OSError("Payment gateway failed")

    except OSError as e:
        balance = old_balance
        raise PaymentError("Payment failed") from e

except PaymentError as e:
    print("Error:", e)
    print("Cause:", e.__cause__)
# Out:
# Enter amount: 5000
# Error: Payment failed
# Cause: Payment gateway failed

# %% [markdown]
# Q74. Implement bounded exponential retry for banking case 1; use sample reference ACC-1074 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass

account = "ACC-1074"
balance = 5000

amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Amount is empty")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

    old_balance = balance

    for attempt in range(3):
        try:
            balance = balance - amount

            if attempt < 2:
                raise OSError("Gateway failed")

            print("Payment successful for", account)
            print("Balance:", balance)
            break

        except OSError as e:
            balance = old_balance

            if attempt == 2:
                raise PaymentError("Payment failed") from e

            print("Retrying...")

except ValueError as e:
    print("Invalid input:", e)

except PaymentError as e:
    print("Payment error:", e)
    print("Cause:", e.__cause__)
# Out:
# Enter amount: 50000
# Invalid input: Insufficient balance

# %% [markdown]
# Q75. Create a transaction context manager for banking case 1; use sample reference ACC-1075 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transaction:
    def __init__(self, balance):
        self.balance = balance

    def __enter__(self):
        self.old = self.balance
        return self

    def __exit__(self, *args):
        if args[0]:
            self.balance = self.old
            print("Transaction rolled back")


account = "ACC-1075"
balance = 5000
amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0 or amount > balance:
        raise ValueError("Invalid amount")

    with Transaction(balance) as t:
        t.balance -= amount

        # Simulate bank failure
        raise OSError("Bank service failed")

except ValueError as e:
    print("Error:", e)

except OSError as e:
    print("Service error:", e)
# Out:
# Enter amount: 6000
# Error: Invalid amount

# %% [markdown]
# Q76. Build a dead-letter queue for payment events for banking case 1; use sample reference ACC-1076 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
dead_letter_queue = []

account = "ACC-1076"
amount = input("Enter payment amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    # Payment processing fails
    raise OSError("Payment service failed")

except ValueError as e:
    print("Invalid payment:", e)

except OSError as e:
    dead_letter_queue.append({
        "account": account,
        "amount": amount,
        "error": str(e)
    })

    print("Payment moved to dead-letter queue")
    print(dead_letter_queue)
# Out:
# Enter payment amount: 5000
# Payment moved to dead-letter queue
# [{'account': 'ACC-1076', 'amount': 5000.0, 'error': 'Payment service failed'}]

# %% [markdown]
# Q77. Make batch settlement failure-isolated for banking case 1; use sample reference ACC-1077 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1077"

payments = ["1000", "abc", "0", "2000"]

for amount in payments:
    try:
        if amount == "":
            raise ValueError("Empty amount")

        amount = float(amount)

        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount == 2000:
            raise OSError("Settlement service failed")

        print("Settlement successful:", amount)

    except ValueError as e:
        print("Business error:", e)

    except OSError as e:
        print("Service error:", e)

print("Batch settlement completed for", account)
# Out:
# Settlement successful: 1000.0
# Business error: could not convert string to float: 'abc'
# Business error: Invalid amount
# Service error: Settlement service failed
# Batch settlement completed for ACC-1077

# %% [markdown]
# Q78. Report exact paths in nested statements for banking case 1; use sample reference ACC-1078 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1078"

data = {
    "payment": {
        "amount": input("Enter amount: ")
    }
}

try:
    amount = data["payment"]["amount"]

    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    print("Payment successful for", account)

except ValueError as e:
    print("Error at path: data['payment']['amount']")
    print("Reason:", e)

except KeyError:
    print("Error at path: data['payment']")
# Out:
# Enter amount: 2000
# Payment successful for ACC-1078

# %% [markdown]
# Q79. Design idempotent recovery after timeout for banking case 1; use sample reference ACC-1079 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1079"
balance = 5000
done = False

amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

    if not done:
        balance -= amount
        done = True
        raise TimeoutError("Payment timed out")

except ValueError as e:
    print("Error:", e)

except TimeoutError as e:
    print("Timeout:", e)
    print("Recovery: do not process the payment again")
# Out:
# Enter amount: 2000
# Timeout: Payment timed out
# Recovery: do not process the payment again

# %% [markdown]
# Q80. Build an exception-safe reconciliation pipeline for banking case 1; use sample reference ACC-1080 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1080"
balance = 5000

amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

    old_balance = balance
    balance -= amount

    # Reconciliation failure
    raise OSError("Reconciliation failed")

except ValueError as e:
    print("Business error:", e)

except OSError as e:
    balance = old_balance
    print("Reconciliation failed for", account)
    print("Balance restored:", balance)
# Out:
# Enter amount: 5000
# Reconciliation failed for ACC-1080
# Balance restored: 5000

# %% [markdown]
# Q81. Design a banking exception hierarchy for banking case 2; use sample reference ACC-1081 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a
# realistic failure path.

# %%
class BankingError(Exception):
    pass

class InvalidAmountError(BankingError):
    pass

class InsufficientFundsError(BankingError):
    pass


account = "ACC-1081"
balance = 5000
amount = input("Enter amount: ")

try:
    if amount == "":
        raise InvalidAmountError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise InvalidAmountError("Invalid amount")

    if amount > balance:
        raise InsufficientFundsError("Insufficient balance")

    balance -= amount
    print("Payment successful:", balance)

except InvalidAmountError as e:
    print("Invalid amount:", e)

except InsufficientFundsError as e:
    print("Error:", e)

except ValueError:
    print("Invalid type")
# Out:
# Enter amount: 4000
# Payment successful: 1000.0

# %% [markdown]
# Q82. Make a transfer rollback-safe for banking case 2; use sample reference ACC-1082 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1082"
sender = 5000
receiver = 2000

amount = input("Enter amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > sender:
        raise ValueError("Insufficient balance")

    old_sender = sender
    old_receiver = receiver

    sender -= amount
    receiver += amount

    # Failure
    raise OSError("Transfer failed")

except ValueError as e:
    print("Error:", e)

except OSError:
    sender = old_sender
    receiver = old_receiver
    print("Transfer failed. Balances restored.")
# Out:
# Enter amount: 2000
# Transfer failed. Balances restored.

# %% [markdown]
# Q83. Preserve causes across service layers for banking case 2; use sample reference ACC-1083 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass

account = "ACC-1083"
balance = 5000

amount = input("Enter amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

    old_balance = balance
    balance -= amount

    try:
        raise OSError("Bank service failed")
    except OSError as e:
        balance = old_balance
        raise PaymentError("Payment failed") from e

except ValueError as e:
    print("Business error:", e)

except PaymentError as e:
    print("Service error:", e)
    print("Cause:", e.__cause__)
# Out:
# Enter amount: 10000
# Business error: Insufficient balance

# %% [markdown]
# Q84. Implement bounded exponential retry for banking case 2; use sample reference ACC-1084 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass

account = "ACC-1084"
balance = 5000
amount = input("Enter amount: ")

try:
    amount = float(amount)

    if amount <= 0 or amount > balance:
        raise ValueError("Invalid amount")

    for i in range(3):
        try:
            if i < 2:
                raise OSError("Bank service failed")

            balance -= amount
            print("Payment successful:", balance)
            break

        except OSError as e:
            print("Retry", i + 1)

            if i == 2:
                raise PaymentError("Payment failed") from e

except ValueError as e:
    print("Error:", e)

except PaymentError as e:
    print("Error:", e)
# Out:
# Enter amount: 2000
# Retry 1
# Retry 2
# Payment successful: 3000.0

# %% [markdown]
# Q85. Create a transaction context manager for banking case 2; use sample reference ACC-1085 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transaction:
    def __init__(self, balance):
        self.balance = balance
        self.old = balance

    def __enter__(self):
        return self

    def __exit__(self, *args):
        if args[0]:
            self.balance = self.old
            print("Transaction rolled back")


account = "ACC-1085"
balance = 5000
amount = input("Enter amount: ")

try:
    amount = float(amount)

    if amount <= 0 or amount > balance:
        raise ValueError("Invalid amount")

    with Transaction(balance) as t:
        t.balance -= amount

        # Simulate failure
        raise OSError("Bank service failed")

except ValueError as e:
    print("Business error:", e)

except OSError as e:
    print("Service error for", account, ":", e)
# Out:
# Enter amount: 2000
# Transaction rolled back
# Service error for ACC-1085 : Bank service failed

# %% [markdown]
# Q86. Build a dead-letter queue for payment events for banking case 2; use sample reference ACC-1086 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
dead_letter_queue = []

account = "ACC-1086"
amount = input("Enter amount: ")

try:
    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    # Payment service failure
    raise OSError("Payment failed")

except ValueError as e:
    print("Business error:", e)

except OSError as e:
    dead_letter_queue.append((account, amount, str(e)))
    print("Payment moved to dead-letter queue")
    print(dead_letter_queue)
# Out:
# Enter amount: 2000
# Payment moved to dead-letter queue
# [('ACC-1086', 2000.0, 'Payment failed')]

# %% [markdown]
# Q87. Make batch settlement failure-isolated for banking case 2; use sample reference ACC-1087 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1087"

payments = ["1000", "abc", "0", "2000"]

for amount in payments:
    try:
        if amount == "":
            raise ValueError("Empty amount")

        amount = float(amount)

        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount == 2000:
            raise OSError("Settlement failed")

        print("Success:", amount)

    except ValueError as e:
        print("Business error:", e)

    except OSError as e:
        print("Service error:", e)

print("Batch completed for", account)
# Out:
# Success: 1000.0
# Business error: could not convert string to float: 'abc'
# Business error: Invalid amount
# Service error: Settlement failed
# Batch completed for ACC-1087

# %% [markdown]
# Q88. Report exact paths in nested statements for banking case 2; use sample reference ACC-1088 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1088"

data = {
    "payment": {
        "amount": input("Enter amount: ")
    }
}

try:
    amount = data["payment"]["amount"]

    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    print("Payment successful for", account)

except ValueError as e:
    print("Path: data['payment']['amount']")
    print("Error:", e)

except KeyError as e:
    print("Missing path:", e)
# Out:
# Enter amount: 4000
# Payment successful for ACC-1088

# %% [markdown]
# Q89. Design idempotent recovery after timeout for banking case 2; use sample reference ACC-1089 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1089"
balance = 5000
done = False

amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

    if done:
        print("Already processed")
    else:
        balance -= amount
        done = True
        raise TimeoutError("Payment timeout")

except ValueError as e:
    print("Error:", e)

except TimeoutError:
    print("Timeout for", account)
    print("Recovery: do not process again")
# Out:
# Enter amount: 6000
# Error: Insufficient balance

# %% [markdown]
# Q90. Build an exception-safe reconciliation pipeline for banking case 2; use sample reference ACC-1090 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1090"
balance = 5000

amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

    old_balance = balance
    balance -= amount

    # Reconciliation failure
    raise OSError("Reconciliation failed")

except ValueError as e:
    print("Business error:", e)

except OSError as e:
    balance = old_balance
    print("Reconciliation failed for", account)
    print("Balance restored:", balance)
# Out:
# Enter amount: 10000
# Business error: Insufficient balance

# %% [markdown]
# Q91. Design a banking exception hierarchy for banking case 3; use sample reference ACC-1091 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankingError(Exception):
    pass

class InvalidAmountError(BankingError):
    pass

class InsufficientFundsError(BankingError):
    pass

class BankError(BankingError):
    pass


account = "ACC-1091"
balance = 5000
amount = input("Enter amount: ")

try:
    if amount == "":
        raise InvalidAmountError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise InvalidAmountError("Invalid amount")

    if amount > balance:
        raise InsufficientFundsError("Insufficient balance")

    balance -= amount
    print("Payment successful:", balance)

except InvalidAmountError as e:
    print("Invalid amount:", e)

except InsufficientFundsError as e:
    print("Error:", e)

except OSError as e:
    print("Bank service error:", e)
# Out:
# Enter amount: 4000
# Payment successful: 1000.0

# %% [markdown]
# Q92. Make a transfer rollback-safe for banking case 3; use sample reference ACC-1092 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1092"

sender = 5000
receiver = 2000
amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0 or amount > sender:
        raise ValueError("Invalid amount")

    old_sender = sender
    old_receiver = receiver

    sender -= amount
    receiver += amount

    # Bank failure
    raise OSError("Transfer failed")

except ValueError as e:
    print("Business error:", e)

except OSError as e:
    sender = old_sender
    receiver = old_receiver
    print("Transfer failed for", account)
    print("Balances restored")
# Out:
# Enter amount: 3000
# Transfer failed for ACC-1092
# Balances restored

# %% [markdown]
# Q93. Preserve causes across service layers for banking case 3; use sample reference ACC-1093 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass

account = "ACC-1093"
balance = 5000
amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

    old_balance = balance
    balance -= amount

    try:
        raise OSError("Bank service failed")
    except OSError as e:
        balance = old_balance
        raise PaymentError("Payment failed") from e

except ValueError as e:
    print("Business error:", e)

except PaymentError as e:
    print("Service error:", e)
    print("Cause:", e.__cause__)
# Out:
# Enter amount: 10000
# Business error: Insufficient balance

# %% [markdown]
# Q94. Implement bounded exponential retry for banking case 3; use sample reference ACC-1094 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass

account = "ACC-1094"
balance = 5000
amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0 or amount > balance:
        raise ValueError("Invalid amount")

    old_balance = balance

    for i in range(3):
        try:
            if i < 2:
                raise OSError("Bank service failed")

            balance -= amount
            print("Payment successful:", balance)
            break

        except OSError as e:
            balance = old_balance
            print("Retry", i + 1)

            if i == 2:
                raise PaymentError("Payment failed") from e

except ValueError as e:
    print("Business error:", e)

except PaymentError as e:
    print("Service error for", account)
    print("Cause:", e.__cause__)
# Out:
# Enter amount: 9000
# Business error: Invalid amount

# %% [markdown]
# Q95. Create a transaction context manager for banking case 3; use sample reference ACC-1095 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transaction:
    def __init__(self, balance):
        self.balance = balance
        self.old = balance

    def __enter__(self):
        return self

    def __exit__(self, *args):
        if args[0]:
            self.balance = self.old
            print("Transaction rolled back")


account = "ACC-1095"
balance = 5000
amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0 or amount > balance:
        raise ValueError("Invalid amount")

    with Transaction(balance) as t:
        t.balance -= amount

        # Simulate bank failure
        raise OSError("Bank service failed")

except ValueError as e:
    print("Business error:", e)

except OSError as e:
    print("Service error:", e)
# Out:
# Enter amount: 3500
# Transaction rolled back
# Service error: Bank service failed

# %% [markdown]
# Q96. Build a dead-letter queue for payment events for banking case 3; use sample reference ACC-1096 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
dead_letter_queue = []

account = "ACC-1096"
amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty amount")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    # Payment service failure
    raise OSError("Payment failed")

except ValueError as e:
    print("Business error:", e)

except OSError as e:
    dead_letter_queue.append((account, amount, str(e)))
    print("Moved to dead-letter queue")
    print(dead_letter_queue)
# Out:
# Enter amount: 4000
# Moved to dead-letter queue
# [('ACC-1096', 4000.0, 'Payment failed')]

# %% [markdown]
# Q97. Make batch settlement failure-isolated for banking case 3; use sample reference ACC-1097 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentError(Exception):
    pass


account = "ACC-1097"
balance = 5000

payments = [
    input("Enter payment 1: "),
    input("Enter payment 2: "),
    input("Enter payment 3: ")
]

for amount in payments:
    try:
        if amount == "":
            raise ValueError("Empty input")

        amount = float(amount)

        if amount <= 0:
            raise ValueError("Invalid amount")

        if amount > balance:
            raise ValueError("Insufficient balance")

        old_balance = balance

        try:
            balance -= amount

            # Realistic service failure
            if amount == 2000:
                raise OSError("Settlement service failed")

            print("Payment successful:", amount)

        except OSError as e:
            balance = old_balance
            raise PaymentError("Payment failed") from e

    except ValueError as e:
        print("Business error:", e)

    except PaymentError as e:
        print("Service error:", e)
        print("Cause:", e.__cause__)

print("Batch completed for", account)
print("Final balance:", balance)
# Out:
# Enter payment 1: 2000
# Enter payment 2: 3000
# Enter payment 3: 40000
# Service error: Payment failed
# Cause: Settlement service failed
# Payment successful: 3000.0
# Business error: Insufficient balance
# Batch completed for ACC-1097
# Final balance: 2000.0

# %% [markdown]
# Q98. Report exact paths in nested statements for banking case 3; use sample reference ACC-1098 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1098"
balance = 5000

data = {
    "payment": {
        "amount": input("Enter amount: ")
    }
}

try:
    # Smallest risky statement
    amount = data["payment"]["amount"]

    if amount == "":
        raise ValueError("Empty input")

    amount = float(amount)

    if amount <= 0:
        raise ValueError("Invalid amount")

    if amount > balance:
        raise ValueError("Insufficient balance")

    old_balance = balance

    try:
        balance -= amount

        # Realistic failure
        if amount == 2000:
            raise OSError("Settlement service failed")

        print("Payment successful for", account)
        print("Balance:", balance)

    except OSError as e:
        balance = old_balance
        print("Path: data['payment']['amount']")
        print("Service error:", e)
        print("Balance restored:", balance)

except KeyError as e:
    print("Missing path: data['payment']['amount']")

except ValueError as e:
    print("Path: data['payment']['amount']")
    print("Business error:", e)
# Out:
# Enter amount: 2000
# Path: data['payment']['amount']
# Service error: Settlement service failed
# Balance restored: 5000

# %% [markdown]
# Q99. Design idempotent recovery after timeout for banking case 3; use sample reference ACC-1099 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1099"
balance = 5000
processed = False

amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty input")

    amount = float(amount)

    if amount <= 0 or amount > balance:
        raise ValueError("Invalid amount")

    old_balance = balance

    try:
        balance -= amount
        processed = True

        # Simulate timeout
        raise TimeoutError("Payment timeout")

    except TimeoutError:
        if processed:
            print("Timeout occurred")
            print("Payment already processed. No duplicate payment.")
            print("Balance:", balance)
        else:
            balance = old_balance
            print("Payment failed")

except ValueError as e:
    print("Business error:", e)
# Out:
# Enter amount: 2000
# Timeout occurred
# Payment already processed. No duplicate payment.
# Balance: 3000.0

# %% [markdown]
# Q100. Build an exception-safe reconciliation pipeline for banking case 3; use sample reference ACC-1100 and explain the result.
#
# Hints
#
# Identify the smallest risky statement and the narrow exception it can raise.
#
# Keep business-rule failures distinct from programming or infrastructure failures.
#
# For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1100"
balance = 5000

amount = input("Enter amount: ")

try:
    if amount == "":
        raise ValueError("Empty input")

    amount = float(amount)

    if amount <= 0 or amount > balance:
        raise ValueError("Invalid amount")

    old_balance = balance
    balance -= amount

    try:
        # Reconciliation failure
        raise OSError("Reconciliation failed")

    except OSError as e:
        balance = old_balance
        print("Reconciliation failed for", account)
        print("Balance restored:", balance)
        print("Cause:", e)

except ValueError as e:
    print("Business error:", e)
# Out:
# Enter amount: 2000
# Reconciliation failed for ACC-1100
# Balance restored: 5000
# Cause: Reconciliation failed
