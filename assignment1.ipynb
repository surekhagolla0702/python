# %%
text="Edukron Data Science and Data Engineering Batch 2026"

# %%
## Indexing expression to print"Edukron"
text="Edukron Data Science and Data Engineering Batch 2026"
print(text[0:7])
print(text[-52:-45])
# Out:
# Edukron
# Edukron

# %%
##Indexing expression to print "Data"
text="Edukron Data Science and Data Engineering Batch 2026"
print(text[8:12])
print(text[-44:-40])
# Out:
# Data
# Data

# %%
text="Edukron Data Science and Data Engineering Batch 2026"
##indexing to print"Science"
print(text[13:20])
print(text[-39:-32])
# Out:
# Science
# Science

# %%
text="Edukron Data Science and Data Engineering Batch 2026"
##indexing to print "and"
print(text[21:24])
print(text[-31:-27])
# Out:
# and
# and

# %%
text="Edukron Data Science and Data Engineering Batch 2026"
## indexing to print"Data Engineering"
print(text[25:41])
print(text[-27:-11])
# Out:
# Data Engineering
# Data Engineering

# %%
text="Edukron Data Science and Data Engineering Batch 2026"
## indexing to print "Engineering"
print(text[30:41])
print(text[-22:-11])
# Out:
# Engineering
# Engineering

# %%
text="Edukron Data Science and Data Engineering Batch 2026"
##indexing to print "Batch"
print(text[42:47])
print(text[-10:-5])
# Out:
# Batch
# Batch

# %%
text="Edukron Data Science and Data Engineering Batch 2026"
##indexing to print "2026"
print(text[48:52])
print(text[-4:0])
# Out:
# 2026

# %%
text="Edukron Data Science and Data Engineering Batch 2026"
## indexing to print"Science and Data"
print(text[13:29])
print(text[-39:-23])
# Out:
# Science and Data
# Science and Data

# %%
text="Edukron Data Science and Data Engineering Batch 2026"
## indexing to print"Data Science and Data Engineering Batch"
print(text[8:47])
print(text[-44:-5])
# Out:
# Data Science and Data Engineering Batch
# Data Science and Data Engineering Batch
