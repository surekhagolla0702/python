# %% [markdown]
# Easy
# Fundamentals and direct applications.
#
# Q1. Find a account code for banking case 1; use sample reference ACC-1001 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"^(ACC-\d{4})$"
try:
    ref = input("Enter account reference: ")
    if ref == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, ref)
    if not match:
        raise ValueError("Invalid account reference")
    print("Account reference:", match.group(1))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-367878
# Error: Invalid account reference

# %% [markdown]
# Q2. Validate a six-digit pin for banking case 1; use sample reference ACC-1002 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<pin>\d{6})"
try:
    pin = input("Enter PIN: ")
    if pin == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, pin)
    if not match:
        raise ValueError("PIN must contain exactly 6 digits")
    print("Account:", "ACC-1002")
    print("Valid PIN:", match.group("pin"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter PIN: 78897
# Error: PIN must contain exactly 6 digits

# %% [markdown]
# Q3. Extract all amounts for banking case 1; use sample reference ACC-1003 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<amount>\d+(?:\.\d{2})?)"
try:
    text = input("Enter amounts separated by spaces: ")
    if text == "":
        raise ValueError("Empty input")
    amounts = re.findall(pattern, text)
    if not amounts:
        raise ValueError("No valid amounts found")
    print("Account:", "ACC-1003")
    print("Amounts:", amounts)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amounts separated by spaces: 2000 43000 0400
# Account: ACC-1003
# Amounts: ['2000', '43000', '0400']

# %% [markdown]
# Q4. Match a receipt date for banking case 1; use sample reference ACC-1004 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<date>\d{2}-\d{2}-\d{4})"
try:
    date = input("Enter receipt date (DD-MM-YYYY): ")
    if date == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, date)
    if not match:
        raise ValueError("Invalid date format")
    print("Account:", "ACC-1004")
    print("Receipt date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter receipt date (DD-MM-YYYY): 23-09-2019
# Account: ACC-1004
# Receipt date: 23-09-2019

# %% [markdown]
# Q5. Find uppercase account references for banking case 1; use sample reference ACC-1005 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})"
try:
    account = input("Enter account reference: ")
    if account == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, account)
    if not match:
        raise ValueError("Invalid uppercase account reference")
    print("Account:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-43892
# Error: Invalid uppercase account reference

# %% [markdown]
# Q6. Remove extra spaces for banking case 1; use sample reference ACC-1006 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})"
try:
    text = input("Enter account reference: ")
    if text == "":
        raise ValueError("Empty input")
    text = text.strip()                # Remove extra spaces from beginning and end
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Invalid account reference")
    print("Account:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-8374
# Account: ACC-8374

# %% [markdown]
# Q7. Split a comma-separated tag list for banking case 1; use sample reference ACC-1007 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<tag>[A-Za-z]+)"
try:
    text = input("Enter tags separated by commas: ")
    if text == "":
        raise ValueError("Empty input")
    tags = [tag.strip() for tag in text.split(",")]
    for tag in tags:
        if not re.fullmatch(pattern, tag):
            raise ValueError("Invalid tag list")
    print("Account:", "ACC-1007")
    print("Tags:", tags)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter tags separated by commas: savings, deposit, active
# Account: ACC-1007
# Tags: ['savings', 'deposit', 'active']

# %% [markdown]
# Q8. Check a phone number for banking case 1; use sample reference ACC-1008 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<phone>[6-9]\d{9})"
try:
    phone = input("Enter phone number: ")
    if phone == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, phone)
    if not match:
        raise ValueError("Invalid phone number")
    print("Account:", "ACC-1008")
    print("Phone number:", match.group("phone"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter phone number: 9701283847
# Account: ACC-1008
# Phone number: 9701283847

# %% [markdown]
# Q9. Find fee waiver codes for banking case 1; use sample reference ACC-1009 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<code>WAIVE-\d{4})"
try:
    code = input("Enter fee waiver code: ")
    if code == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, code)
    if not match:
        raise ValueError("Invalid fee waiver code")
    print("Account:", "ACC-1009")
    print("Fee waiver code:", match.group("code"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter fee waiver code: WAIVE-1009
# Account: ACC-1009
# Fee waiver code: WAIVE-1009

# %% [markdown]
# Q10. Replace masked card digits for banking case 1; use sample reference ACC-1010 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<masked>\*+)"
try:
    card = input("Enter masked card number: ")
    if card == "":
        raise ValueError("Empty input")
    match = re.search(pattern, card)
    if not match:
        raise ValueError("No masked digits found")
    result = re.sub(pattern, "XXXX", card)
    print("Account:", "ACC-1010")
    print("Updated card:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter masked card number: 8327493472q
# Error: No masked digits found

# %% [markdown]
# Q11. Extract quantities for banking case 1; use sample reference ACC-1011 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<quantity>\d+)"
try:
    text = input("Enter quantities: ")
    if text == "":
        raise ValueError("Empty input")
    quantities = re.findall(pattern, text)
    if not quantities:
        raise ValueError("No valid quantities found")
    print("Account:", "ACC-1011")
    print("Quantities:", quantities)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter quantities: 328
# Account: ACC-1011
# Quantities: ['328']

# %% [markdown]
# Q12. Match branch ids for banking case 1; use sample reference ACC-1012 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<branch>BR\d{4})"
try:
    branch = input("Enter branch ID: ")
    if branch == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, branch)
    if not match:
        raise ValueError("Invalid branch ID")
    print("Account:", "ACC-1012")
    print("Branch ID:", match.group("branch"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter branch ID: 79880o
# Error: Invalid branch ID

# %% [markdown]
# Q13. Find email addresses for banking case 1; use sample reference ACC-1013 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<email>[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,})"
try:
    text = input("Enter email address: ")
    if text == "":
        raise ValueError("Empty input")
    emails = re.findall(pattern, text)
    if not emails:
        raise ValueError("No valid email address found")
    print("Account:", "ACC-1013")
    print("Email addresses:", emails)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter email address: asuyd@gmail.com
# Account: ACC-1013
# Email addresses: ['asuyd@gmail.com']

# %% [markdown]
# Q14. Validate a postcode for banking case 1; use sample reference ACC-1014 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<postcode>\d{6})"
try:
    postcode = input("Enter postcode: ")
    if postcode == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, postcode)
    if not match:
        raise ValueError("Invalid postcode")
    print("Account:", "ACC-1014")
    print("Postcode:", match.group("postcode"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter postcode: 793824
# Account: ACC-1014
# Postcode: 793824

# %% [markdown]
# Q15. Detect the word sale for banking case 1; use sample reference ACC-1015 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<sale>\bsale\b)"
try:
    text = input("Enter text: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.search(pattern, text, re.IGNORECASE)
    if not match:
        raise ValueError("Word 'sale' not found")
    print("Account:", "ACC-1015")
    print("Sale detected:", match.group("sale"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter text: sale
# Account: ACC-1015
# Sale detected: sale

# %% [markdown]
# Q16. Find a account code for banking case 2; use sample reference ACC-1016 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})"
try:
    account = input("Enter account code: ")
    if account == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, account)
    if not match:
        raise ValueError("Invalid account code")
    print("Account:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account code: ACC-1016
# Account: ACC-1016

# %% [markdown]
# Q17. Validate a six-digit pin for banking case 2; use sample reference ACC-1017 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<pin>\d{6})"
try:
    pin = input("Enter PIN: ")
    if pin == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, pin)
    if not match:
        raise ValueError("PIN must contain exactly 6 digits")
    print("Account:", "ACC-1017")
    print("Valid PIN:", match.group("pin"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter PIN: 243567
# Account: ACC-1017
# Valid PIN: 243567

# %% [markdown]
# Q18. Extract all amounts for banking case 2; use sample reference ACC-1018 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<amount>\d+(?:\.\d{2})?)"
try:
    text = input("Enter amounts: ")
    if text == "":
        raise ValueError("Empty input")
    amounts = re.findall(pattern, text)
    if not amounts:
        raise ValueError("No valid amounts found")
    print("Account:", "ACC-1018")
    print("Amounts:", amounts)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amounts: 22389
# Account: ACC-1018
# Amounts: ['22389']

# %% [markdown]
# Q19. Match a receipt date for banking case 2; use sample reference ACC-1019 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<date>\d{2}-\d{2}-\d{4})"
try:
    date = input("Enter receipt date (DD-MM-YYYY): ")
    if date == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, date)
    if not match:
        raise ValueError("Invalid date format")
    print("Account:", "ACC-1019")
    print("Receipt date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter receipt date (DD-MM-YYYY): 32-12-2011
# Account: ACC-1019
# Receipt date: 32-12-2011

# %% [markdown]
# Q20. Find uppercase account references for banking case 2; use sample reference ACC-1020 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify
# dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})"
try:
    account = input("Enter account reference: ")
    if account == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, account)
    if not match:
        raise ValueError("Invalid uppercase account reference")
    print("Account:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-7890
# Account: ACC-7890

# %% [markdown]
# Q21. Remove extra spaces for banking case 2; use sample reference ACC-1021 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})"
try:
    text = input("Enter account reference: ")
    if text == "":
        raise ValueError("Empty input")
    text = text.strip()
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Invalid account reference")
    print("Account:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-7892
# Account: ACC-7892

# %% [markdown]
# Q22. Split a comma-separated tag list for banking case 2; use sample reference ACC-1022 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<tag>[A-Za-z]+)"
try:
    text = input("Enter tags separated by commas: ")
    if text == "":
        raise ValueError("Empty input")
    tags = [tag.strip() for tag in text.split(",")]
    for tag in tags:
        if not re.fullmatch(pattern, tag):
            raise ValueError("Invalid tag list")
    print("Account:", "ACC-1022")
    print("Tags:", tags)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter tags separated by commas: savings,active,veriffies
# Account: ACC-1022
# Tags: ['savings', 'active', 'veriffies']

# %% [markdown]
# Q23. Check a phone number for banking case 2; use sample reference ACC-1023 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<phone>[6-9]\d{9})"
try:
    phone = input("Enter phone number: ")
    if phone == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, phone)
    if not match:
        raise ValueError("Invalid phone number")
    print("Account:", "ACC-1023")
    print("Phone number:", match.group("phone"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter phone number: 9550619212
# Account: ACC-1023
# Phone number: 9550619212

# %% [markdown]
# Q24. Find fee waiver codes for banking case 2; use sample reference ACC-1024 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<code>WAIVE-\d{4})"
try:
    code = input("Enter fee waiver code: ")
    if code == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, code)
    if not match:
        raise ValueError("Invalid fee waiver code")
    print("Account:", "ACC-1024")
    print("Fee waiver code:", match.group("code"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter fee waiver code: WAIVE-1024
# Account: ACC-1024
# Fee waiver code: WAIVE-1024

# %% [markdown]
# Q25. Replace masked card digits for banking case 2; use sample reference ACC-1025 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<masked>\*+)"
try:
    card = input("Enter masked card number: ")
    if card == "":
        raise ValueError("Empty input")
    match = re.search(pattern, card)
    if not match:
        raise ValueError("No masked digits found")
    result = re.sub(pattern, "XXXX", card)
    print("Account:", "ACC-1025")
    print("Updated card:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter masked card number: 123-**390-98
# Account: ACC-1025
# Updated card: 123-XXXX390-98

# %% [markdown]
# Q26. Extract quantities for banking case 2; use sample reference ACC-1026 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<quantity>\d+)"
try:
    text = input("Enter quantities: ")
    if text == "":
        raise ValueError("Empty input")
    quantities = re.findall(pattern, text)
    if not quantities:
        raise ValueError("No valid quantities found")
    print("Account:", "ACC-1026")
    print("Quantities:", quantities)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter quantities: 2,4
# Account: ACC-1026
# Quantities: ['2', '4']

# %% [markdown]
# Q27. Match branch ids for banking case 2; use sample reference ACC-1027 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<branch>BR\d{4})"
try:
    branch = input("Enter branch ID: ")
    if branch == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, branch)
    if not match:
        raise ValueError("Invalid branch ID")
    print("Account:", "ACC-1027")
    print("Branch ID:", match.group("branch"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter branch ID: 32
# Error: Invalid branch ID

# %% [markdown]
# Q28. Find email addresses for banking case 2; use sample reference ACC-1028 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<email>[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,})"
try:
    text = input("Enter email addresses: ")
    if text == "":
        raise ValueError("Empty input")
    emails = re.findall(pattern, text)
    if not emails:
        raise ValueError("No valid email address found")
    print("Account:", "ACC-1028")
    print("Email addresses:", emails)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter email addresses: rohit@gmail.com
# Account: ACC-1028
# Email addresses: ['rohit@gmail.com']

# %% [markdown]
# Q29. Validate a postcode for banking case 2; use sample reference ACC-1029 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<postcode>\d{6})"
try:
    postcode = input("Enter postcode: ")
    if postcode == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, postcode)
    if not match:
        raise ValueError("Invalid postcode")
    print("Account:", "ACC-1029")
    print("Postcode:", match.group("postcode"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter postcode: 797902
# Account: ACC-1029
# Postcode: 797902

# %% [markdown]
# Q30. Detect the word sale for banking case 2; use sample reference ACC-1030 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<sale>\bsale\b)"
try:
    text = input("Enter text: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.search(pattern, text, re.IGNORECASE)
    if not match:
        raise ValueError("Word 'sale' not found")
    print("Account:", "ACC-1030")
    print("Sale detected:", match.group("sale"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter text: sale
# Account: ACC-1030
# Sale detected: sale

# %% [markdown]
# Medium
# Reusable components and multi-step workflows.
#
# Q31. Parse a receipt line into named groups for banking case 1; use sample reference ACC-1031 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4}),(?P<amount>\d+(?:\.\d{2})?),(?P<date>\d{2}-\d{2}-\d{4})"
try:
    receipt = input("Enter receipt line: ")
    if receipt == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, receipt)
    if not match:
        raise ValueError("Invalid receipt format")
    print("Account:", match.group("account"))
    print("Amount:", match.group("amount"))
    print("Date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter receipt line: ACC-1031,1000.50,10-09-2026
# Account: ACC-1031
# Amount: 1000.50
# Date: 10-09-2026

# %% [markdown]
# Q32. Validate an account reference with optional category prefix for banking case 1; use sample reference ACC-1032 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<category>SAV|CUR-)?(?P<account>ACC-\d{4})"
try:
    reference = input("Enter account reference: ")
    if reference == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, reference)
    if not match:
        raise ValueError("Invalid account reference")
    category = match.group("category")
    if category:
        print("Category:", category.rstrip("-"))
    else:
        print("Category: None")
    print("Account:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-1023
# Category: None
# Account: ACC-1023

# %% [markdown]
# Q33. Extract currency and amount for banking case 1; use sample reference ACC-1033 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<currency>USD|INR|EUR)\s+(?P<amount>\d+(?:\.\d{2})?)"
try:
    value = input("Enter currency and amount: ")
    if value == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, value)
    if not match:
        raise ValueError("Invalid currency or amount")
    print("Account:", "ACC-1033")
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter currency and amount: INR 1500.50
# Account: ACC-1033
# Currency: INR
# Amount: 1500.50

# %% [markdown]
# Q34. Normalize account holder phone numbers for banking case 1; use sample reference ACC-1034 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?:\+91[- ]?)?(?P<phone>[6-9]\d{9})"
try:
    phone = input("Enter phone number: ")
    if phone == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, phone)
    if not match:
        raise ValueError("Invalid phone number")
    normalized = match.group("phone")
    print("Account:", "ACC-1034")
    print("Normalized phone:", normalized)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter phone number: 9381890330
# Account: ACC-1034
# Normalized phone: 9381890330

# %% [markdown]
# Q35. Find repeated account words for banking case 1; use sample reference ACC-1035 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"\b(?P<word>account)\b"
try:
    text = input("Enter banking text: ")
    if text == "":
        raise ValueError("Empty input")
    matches = re.findall(pattern, text, re.IGNORECASE)
    if len(matches) < 2:
        raise ValueError("Repeated account word not found")
    print("Account:", "ACC-1035")
    print("Repeated words:", matches)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter banking text: The account holder updated the account details
# Account: ACC-1035
# Repeated words: ['account', 'account']

# %% [markdown]
# Q36. Validate fee waiver start and end anchors for banking case 1; use sample reference ACC-1036 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"^(?P<code>WAIVE-\d{4})$"
try:
    code = input("Enter fee waiver code: ")
    if code == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, code)
    if not match:
        raise ValueError("Invalid fee waiver code")
    print("Account:", "ACC-1036")
    print("Fee waiver code:", match.group("code"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter fee waiver code: WAIVE-1036
# Account: ACC-1036
# Fee waiver code: WAIVE-1036

# %% [markdown]
# Q37. Redact emails from support text for banking case 1; use sample reference ACC-1037 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<email>[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,})"
try:
    text = input("Enter support text: ")
    if text == "":
        raise ValueError("Empty input")
    emails = re.findall(pattern, text)
    if not emails:
        raise ValueError("No email address found")
    redacted_text = re.sub(pattern, "[REDACTED]", text)
    print("Account:", "ACC-1037")
    print("Emails found:", emails)
    print("Redacted text:", redacted_text)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter support text: Customer email is user@gmail.com and contact surekha@example.com
# Account: ACC-1037
# Emails found: ['user@gmail.com', 'surekha@example.com']
# Redacted text: Customer email is [REDACTED] and contact [REDACTED]

# %% [markdown]
# Q38. Extract transfer ids without partial matches for banking case 1; use sample reference ACC-1038 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?<![A-Z0-9])(?P<transfer_id>TRF-\d{4})(?![A-Z0-9])"
try:
    text = input("Enter transfer ID text: ")
    if text == "":
        raise ValueError("Empty input")
    transfer_ids = re.findall(pattern, text)
    if not transfer_ids:
        raise ValueError("No valid transfer ID found")
    print("Account:", "ACC-1038")
    print("Transfer IDs:", transfer_ids)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter transfer ID text: Transfer TRF-1001 completed and TRF-2050 is pending
# Account: ACC-1038
# Transfer IDs: ['TRF-1001', 'TRF-2050']

# %% [markdown]
# Q39. Parse inventory key-value pairs for banking case 1; use sample reference ACC-1039 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<key>[A-Za-z]+)=(?P<value>[A-Za-z0-9]+)"
try:
    text = input("Enter inventory key-value pairs: ")
    if text == "":
        raise ValueError("Empty input")
    pairs = text.split(",")
    inventory = {}
    for pair in pairs:
        match = re.fullmatch(pattern, pair.strip())
        if not match:
            raise ValueError("Invalid key-value pair")
        key = match.group("key")
        value = match.group("value")
        inventory[key] = value
    print("Account:", "ACC-1039")
    print("Inventory:", inventory)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter inventory key-value pairs: item=pen,quantity=10,status=available
# Account: ACC-1039
# Inventory: {'item': 'pen', 'quantity': '10', 'status': 'available'}

# %% [markdown]
# Q40. Use lookahead for strong fee waiver tokens for banking case 1; use sample reference ACC-1040 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<token>WAIVE-(?=.*[A-Z])(?=.*[a-z])(?=.*\d)[A-Za-z\d]{4,})"
try:
    token = input("Enter fee waiver token: ")
    if token == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, token)
    if not match:
        raise ValueError("Weak or invalid fee waiver token")
    print("Account:", "ACC-1040")
    print("Strong token:", match.group("token"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter fee waiver token: WAIVE-Abc1
# Account: ACC-1040
# Strong token: WAIVE-Abc1

# %% [markdown]
# Q41. Use negative lookahead to reject test account references for banking case 1; use sample reference ACC-1041 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"^(?!TEST-)(?P<account>ACC-\d{4})$"
try:
    account = input("Enter account reference: ")
    if account == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, account)
    if not match:
        raise ValueError("Invalid or test account reference")
    print("Account:", "ACC-1041")
    print("Valid reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-18797
# Error: Invalid or test account reference

# %% [markdown]
# Q42. Extract account names between delimiters for banking case 1; use sample reference ACC-1042 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"\[(?P<name>[A-Za-z ]+)\]"
try:
    text = input("Enter account name in brackets: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Invalid account name format")
    print("Account:", "ACC-1042")
    print("Account name:", match.group("name").strip())
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account name in brackets: [john]
# Account: ACC-1042
# Account name: john

# %% [markdown]
# Q43. Replace dates with iso format for banking case 1; use sample reference ACC-1043 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<day>\d{2})-(?P<month>\d{2})-(?P<year>\d{4})"
try:
    date = input("Enter date (DD-MM-YYYY): ")
    if date == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, date)
    if not match:
        raise ValueError("Invalid date format")
    iso_date = (
        match.group("year") + "-" +
        match.group("month") + "-" +
        match.group("day")
    )
    print("Account:", "ACC-1043")
    print("ISO date:", iso_date)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter date (DD-MM-YYYY): 10-09-2026
# Account: ACC-1043
# ISO date: 2026-09-10

# %% [markdown]
# Q44. Compile a reusable account pattern for banking case 1; use sample reference ACC-1044 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
account_pattern = re.compile(r"(?P<account>ACC-\d{4})")
try:
    account = input("Enter account reference: ")
    if account == "":
        raise ValueError("Empty input")
    match = account_pattern.fullmatch(account)
    if not match:
        raise ValueError("Invalid account reference")
    print("Account:", "ACC-1044")
    print("Valid reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-1045
# Account: ACC-1044
# Valid reference: ACC-1045

# %% [markdown]
# Q45. Use case-insensitive matching for brand search for banking case 1; use sample reference ACC-1045 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<brand>hdfc)"
try:
    text = input("Enter brand name: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.search(pattern, text, re.IGNORECASE)
    if not match:
        raise ValueError("Brand not found")
    print("Account:", "ACC-1045")
    print("Brand found:", match.group("brand"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter brand name: HDFC
# Account: ACC-1045
# Brand found: HDFC

# %% [markdown]
# Q46. Parse a receipt line into named groups for banking case 2; use sample reference ACC-1046 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4}),(?P<amount>\d+(?:\.\d{2})?),(?P<date>\d{2}-\d{2}-\d{4})"
try:
    receipt = input("Enter receipt line: ")
    if receipt == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, receipt)
    if not match:
        raise ValueError("Invalid receipt format")
    print("Account:", "ACC-1046")
    print("Account Reference:", match.group("account"))
    print("Amount:", match.group("amount"))
    print("Date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter receipt line: ACC-1046,2500.75,15-08-2026
# Account: ACC-1046
# Account Reference: ACC-1046
# Amount: 2500.75
# Date: 15-08-2026

# %% [markdown]
# Q47. Validate an account reference with optional category prefix for banking case 2; use sample reference ACC-1047 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<category>(?:SAV|CUR)-)?(?P<account>ACC-\d{4})"
try:
    reference = input("Enter account reference: ")
    if reference == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, reference)
    if not match:
        raise ValueError("Invalid account reference")
    category = match.group("category")
    if category:
        category = category[:-1]
    else:
        category = "None"
    print("Account:", "ACC-1047")
    print("Category:", category)
    print("Account Reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-1078
# Account: ACC-1047
# Category: None
# Account Reference: ACC-1078

# %% [markdown]
# Q48. Extract currency and amount for banking case 2; use sample reference ACC-1048 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<currency>USD|INR|EUR)\s+(?P<amount>\d+(?:\.\d{2})?)"
try:
    value = input("Enter currency and amount: ")
    if value == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, value)
    if not match:
        raise ValueError("Invalid currency or amount")
    print("Account:", "ACC-1048")
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter currency and amount: INR 1500.50
# Account: ACC-1048
# Currency: INR
# Amount: 1500.50

# %% [markdown]
# Q49. Normalize account holder phone numbers for banking case 2; use sample reference ACC-1049 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?:\+91[- ]?)?(?P<phone>[6-9]\d{9})"
try:
    phone = input("Enter phone number: ")
    if phone == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, phone)
    if not match:
        raise ValueError("Invalid phone number")
    normalized = match.group("phone")
    print("Account:", "ACC-1049")
    print("Normalized phone:", normalized)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter phone number: 9381890330
# Account: ACC-1049
# Normalized phone: 9381890330

# %% [markdown]
# Q50. Find repeated account words for banking case 2; use sample reference ACC-1050 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"\b(?P<word>account)\b"
try:
    text = input("Enter banking text: ")
    if text == "":
        raise ValueError("Empty input")
    matches = re.findall(pattern, text, re.IGNORECASE)
    if len(matches) < 2:
        raise ValueError("Repeated account word not found")
    print("Account:", "ACC-1050")
    print("Repeated words:", matches)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter banking text: The account holder updated the account details
# Account: ACC-1050
# Repeated words: ['account', 'account']

# %% [markdown]
# Q51. Validate fee waiver start and end anchors for banking case 2; use sample reference ACC-1051 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"^(?P<code>WAIVE-\d{4})$"
try:
    code = input("Enter fee waiver code: ")
    if code == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, code)
    if not match:
        raise ValueError("Invalid fee waiver code")
    print("Account:", "ACC-1051")
    print("Fee waiver code:", match.group("code"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter fee waiver code: WAIVE-1051
# Account: ACC-1051
# Fee waiver code: WAIVE-1051

# %% [markdown]
# Q52. Redact emails from support text for banking case 2; use sample reference ACC-1052 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<email>[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,})"
try:
    text = input("Enter support text: ")
    if text == "":
        raise ValueError("Empty input")
    emails = re.findall(pattern, text)
    if not emails:
        raise ValueError("No email address found")
    redacted_text = re.sub(pattern, "[REDACTED]", text)
    print("Account:", "ACC-1052")
    print("Emails found:", emails)
    print("Redacted text:", redacted_text)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter support text: Customer email is user@gmail.com and contact surekha@example.com
# Account: ACC-1052
# Emails found: ['user@gmail.com', 'surekha@example.com']
# Redacted text: Customer email is [REDACTED] and contact [REDACTED]

# %% [markdown]
# Q53. Extract transfer ids without partial matches for banking case 2; use sample reference ACC-1053 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?<![A-Z0-9])(?P<transfer_id>TRF-\d{4})(?![A-Z0-9])"
try:
    text = input("Enter transfer ID text: ")
    if text == "":
        raise ValueError("Empty input")
    transfer_ids = re.findall(pattern, text)
    if not transfer_ids:
        raise ValueError("No valid transfer ID found")
    print("Account:", "ACC-1053")
    print("Transfer IDs:", transfer_ids)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter transfer ID text: Transfer TRF-1053 completed and TRF-2050 is pending
# Account: ACC-1053
# Transfer IDs: ['TRF-1053', 'TRF-2050']

# %% [markdown]
# Q54. Parse inventory key-value pairs for banking case 2; use sample reference ACC-1054 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<key>[A-Za-z]+)=(?P<value>[A-Za-z0-9]+)"
try:
    text = input("Enter inventory key-value pairs: "
    if text == "":
        raise ValueError("Empty input")
    pairs = text.split(",")
    inventory = {}
    for pair in pairs:
        match = re.fullmatch(pattern, pair.strip())
        if not match:
            raise ValueError("Invalid key-value pair")
        key = match.group("key")
        value = match.group("value")
        inventory[key] = value
    print("Account:", "ACC-1054")
    print("Inventory:", inventory)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter inventory key-value pairs: item=pen,quantity=10,status=available
# Account: ACC-1054
# Inventory: {'item': 'pen', 'quantity': '10', 'status': 'available'}

# %% [markdown]
# Q55. Use lookahead for strong fee waiver tokens for banking case 2; use sample reference ACC-1055 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<token>WAIVE-(?=.*[A-Z])(?=.*[a-z])(?=.*\d)[A-Za-z\d]{4,})"
try:
    token = input("Enter fee waiver token: ")
    if token == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, token)
    if not match:
        raise ValueError("Weak or invalid fee waiver token")
    print("Account:", "ACC-1055")
    print("Strong token:", match.group("token"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter fee waiver token: WAIVE-Abc1
# Account: ACC-1055
# Strong token: WAIVE-Abc1

# %% [markdown]
# Q56. Use negative lookahead to reject test account references for banking case 2; use sample reference ACC-1056 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"^(?!TEST-)(?P<account>ACC-\d{4})$"
try:
    account = input("Enter account reference: ")
    if account == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, account)
    if not match:
        raise ValueError("Invalid or test account reference")
    print("Account:", "ACC-1056")
    print("Valid reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-9087
# Account: ACC-1056
# Valid reference: ACC-9087

# %% [markdown]
# Q57. Extract account names between delimiters for banking case 2; use sample reference ACC-1057 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"\[(?P<name>[A-Za-z ]+)\]"
try:
    text = input("Enter account name in brackets: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Invalid account name format")
    print("Account:", "ACC-1057")
    print("Account name:", match.group("name").strip())
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account name in brackets: [ravi]
# Account: ACC-1057
# Account name: ravi

# %% [markdown]
# Q58. Replace dates with iso format for banking case 2; use sample reference ACC-1058 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<day>\d{2})-(?P<month>\d{2})-(?P<year>\d{4})"
try:
    date = input("Enter date (DD-MM-YYYY): ")
    if date == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, date)
    if not match:
        raise ValueError("Invalid date format")
    iso_date = (
        match.group("year") + "-" +
        match.group("month") + "-" +
        match.group("day")
    )
    print("Account:", "ACC-1058")
    print("ISO date:", iso_date)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter date (DD-MM-YYYY): 10-09-2026
# Account: ACC-1058
# ISO date: 2026-09-10

# %% [markdown]
# Q59. Compile a reusable account pattern for banking case 2; use sample reference ACC-1059 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
account_pattern = re.compile(r"(?P<account>ACC-\d{4})")
try:
    account = input("Enter account reference: ")
    if account == "":
        raise ValueError("Empty input")
    match = account_pattern.fullmatch(account)
    if not match:
        raise ValueError("Invalid account reference")
    print("Account:", "ACC-1059")
    print("Valid reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: ACC-7872
# Account: ACC-1059
# Valid reference: ACC-7872

# %% [markdown]
# Q60. Use case-insensitive matching for brand search for banking case 2; use sample reference ACC-1060 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<brand>hdfc)"
try:
    text = input("Enter brand name: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.search(pattern, text, re.IGNORECASE)
    if not match:
        raise ValueError("Brand not found")
    print("Account:", "ACC-1060")
    print("Brand found:", match.group("brand"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter brand name: Customer uses HDFC bank
# Account: ACC-1060
# Brand found: HDFC

# %% [markdown]
# Q61. Parse a receipt line into named groups for banking case 3; use sample reference ACC-1061 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4}),(?P<amount>\d+(?:\.\d{2})?),(?P<date>\d{2}-\d{2}-\d{4})"
try:
    receipt = input("Enter receipt line: ")
    if receipt == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, receipt)
    if not match:
        raise ValueError("Invalid receipt format")
    print("Account:", "ACC-1061")
    print("Account Reference:", match.group("account"))
    print("Amount:", match.group("amount"))
    print("Date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter receipt line: ACC-1061,2500.75,15-08-2026
# Account: ACC-1061
# Account Reference: ACC-1061
# Amount: 2500.75
# Date: 15-08-2026

# %% [markdown]
# Q62. Validate an account reference with optional category prefix for banking case 3; use sample reference ACC-1062 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<category>(?:SAV|CUR)-)?(?P<account>ACC-\d{4})"
try:
    reference = input("Enter account reference: ")
    if reference == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, reference)
    if not match:
        raise ValueError("Invalid account reference")
    category = match.group("category")
    if category:
        category = category[:-1]
    else:
        category = "None"
    print("Account:", "ACC-1062")
    print("Category:", category)
    print("Account Reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account reference: SAV-ACC-1062
# Account: ACC-1062
# Category: SAV
# Account Reference: ACC-1062

# %% [markdown]
# Q63. Extract currency and amount for banking case 3; use sample reference ACC-1063 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<currency>USD|INR|EUR)\s+(?P<amount>\d+(?:\.\d{2})?)"
try:
    value = input("Enter currency and amount: ")
    if value == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, value)
    if not match:
        raise ValueError("Invalid currency or amount")
    print("Account:", "ACC-1063")
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter currency and amount: INR 500
# Account: ACC-1063
# Currency: INR
# Amount: 500

# %% [markdown]
# Q64. Normalize account holder phone numbers for banking case 3; use sample reference ACC-1064 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?:\+91[- ]?)?(?P<phone>[6-9]\d{9})"
try:
    phone = input("Enter phone number: ")
    if phone == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, phone)
    if not match:
        raise ValueError("Invalid phone number")
    normalized = match.group("phone")
    print("Account:", "ACC-1064")
    print("Normalized phone:", normalized)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter phone number: 9701283847
# Account: ACC-1064
# Normalized phone: 9701283847

# %% [markdown]
# Q65. Find repeated account words for banking case 3; use sample reference ACC-1065 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"\b(?P<word>account)\b"
try:
    text = input("Enter banking text: ")
    if text == "":
        raise ValueError("Empty input")
    matches = re.findall(pattern, text, re.IGNORECASE)
    if len(matches) < 2:
        raise ValueError("Repeated account word not found")
    print("Account:", "ACC-1065")
    print("Repeated words:", matches)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter banking text: The account holder updated the account details
# Account: ACC-1065
# Repeated words: ['account', 'account']

# %% [markdown]
# Q66. Validate fee waiver start and end anchors for banking case 3; use sample reference ACC-1066 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"^(?P<code>WAIVE-\d{4})$"
try:
    code = input("Enter fee waiver code: ")
    if code == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, code)
    if not match:
        raise ValueError("Invalid fee waiver code")
    print("Account:", "ACC-1066")
    print("Fee waiver code:", match.group("code"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter fee waiver code: WAIVE-1066
# Account: ACC-1066
# Fee waiver code: WAIVE-1066

# %% [markdown]
# Q67. Redact emails from support text for banking case 3; use sample reference ACC-1067 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<email>[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,})"
try:
    text = input("Enter support text: ")
    if text == "":
        raise ValueError("Empty input")
    emails = re.findall(pattern, text)
    if not emails:
        raise ValueError("No email address found")
    redacted_text = re.sub(pattern, "[REDACTED]", text)
    print("Account:", "ACC-1067")
    print("Emails found:", emails)
    print("Redacted text:", redacted_text)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter support text: Customer email is user@gmail.com and contact surekha@example.com
# Account: ACC-1067
# Emails found: ['user@gmail.com', 'surekha@example.com']
# Redacted text: Customer email is [REDACTED] and contact [REDACTED]

# %% [markdown]
# Q68. Extract transfer ids without partial matches for banking case 3; use sample reference ACC-1068 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?<![A-Z0-9])(?P<transfer_id>TRF-\d{4})(?![A-Z0-9])"
try:
    text = input("Enter transfer ID text: ")
    if text == "":
        raise ValueError("Empty input")
    transfer_ids = re.findall(pattern, text)
    if not transfer_ids:
        raise ValueError("No valid transfer ID found")
    print("Account:", "ACC-1068")
    print("Transfer IDs:", transfer_ids)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter transfer ID text: Transfer TRF-1068 completed and TRF-2050 is pending
# Account: ACC-1068
# Transfer IDs: ['TRF-1068', 'TRF-2050']

# %% [markdown]
# Q69. Parse inventory key-value pairs for banking case 3; use sample reference ACC-1069 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<key>[A-Za-z]+)=(?P<value>[A-Za-z0-9]+)"
try:
    text = input("Enter inventory key-value pairs: ")
    if text == "":
        raise ValueError("Empty input")
    pairs = text.split(",")
    inventory = {}
    for pair in pairs:
        match = re.fullmatch(pattern, pair.strip())
        if not match:
            raise ValueError("Invalid key-value pair")
        key = match.group("key")
        value = match.group("value")
        inventory[key] = value
    print("Account:", "ACC-1069")
    print("Inventory:", inventory)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter inventory key-value pairs: item=pen,quantity=10,status=available
# Account: ACC-1069
# Inventory: {'item': 'pen', 'quantity': '10', 'status': 'available'}

# %% [markdown]
# Q70. Use lookahead for strong fee waiver tokens for banking case 3; use sample reference ACC-1070 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<token>WAIVE-(?=.*[A-Z])(?=.*[a-z])(?=.*\d)[A-Za-z\d]{4,})"
try:
    token = input("Enter fee waiver token: ")
    if token == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, token)
    if not match:
        raise ValueError("Weak or invalid fee waiver token")
    print("Account:", "ACC-1070")
    print("Strong token:", match.group("token"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter fee waiver token: WAIVE-Abc1
# Account: ACC-1070
# Strong token: WAIVE-Abc1

# %% [markdown]
# Difficult
# Architecture, edge cases, and end-to-end banking systems.
#
# Q71. Tokenize a messy receipt safely for banking case 1; use sample reference ACC-1071 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s*,\s*(?P<amount>\d+(?:\.\d{2})?)\s*,\s*(?P<date>\d{2}-\d{2}-\d{4})"
try:
    receipt = input("Enter messy receipt: ")
    if receipt == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, receipt.strip())
    if not match:
        raise ValueError("Invalid receipt format")
    account = match.group("account")
    amount = match.group("amount")
    date = match.group("date")
    print("Account:", "ACC-1071")
    print("Account Reference:", account)
    print("Amount:", amount)
    print("Date:", date)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter messy receipt: ACC-1071 , 2500.50 , 15-08-2026
# Account: ACC-1071
# Account Reference: ACC-1071
# Amount: 2500.50
# Date: 15-08-2026

# %% [markdown]
# Q72. Validate a multi-part warehouse location for banking case 1; use sample reference ACC-1072 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<warehouse>WH\d{2})-(?P<zone>Z\d{2})-(?P<rack>R\d{2})"
try:
    location = input("Enter warehouse location: ")
    if location == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, location)
    if not match:
        raise ValueError("Invalid warehouse location")
    print("Account:", "ACC-1072")
    print("Warehouse:", match.group("warehouse"))
    print("Zone:", match.group("zone"))
    print("Rack:", match.group("rack"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter warehouse location: WH01-Z05-R10
# Account: ACC-1072
# Warehouse: WH01
# Zone: Z05
# Rack: R10

# %% [markdown]
# Q73. Extract nested-looking account annotations within a defined limit for banking case 1; use sample reference ACC-1073 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s+\[(?P<annotation>[A-Za-z ]+(?:\([A-Za-z ]+\))?)\]"
try:
    text = input("Enter account annotation: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Invalid account annotation")
    annotation = match.group("annotation")
    if len(annotation) > 30:
        raise ValueError("Annotation is too long")
    print("Account:", "ACC-1073")
    print("Account Reference:", match.group("account"))
    print("Annotation:", annotation)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account annotation: ACC-1073 [VIP (Verified)]
# Account: ACC-1073
# Account Reference: ACC-1073
# Annotation: VIP (Verified)

# %% [markdown]
# Q74. Find duplicate adjacent account reference tokens with backreferences for banking case 1; use sample reference ACC-1074 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s+\1"
try:
    text = input("Enter two account references: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Duplicate adjacent account references not found")
    print("Account:", "ACC-1074")
    print("Duplicate reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter two account references: ACC-1074 ACC-1074
# Account: ACC-1074
# Duplicate reference: ACC-1074

# %% [markdown]
# Q75. Redact card-like numbers while preserving last four digits for banking case 1; use sample reference ACC-1075 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<card>\d{4}[- ]?\d{4}[- ]?\d{4}[- ]?\d{4})"
try:
    card = input("Enter synthetic card-like number: ")
    if card == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, card)
    if not match:
        raise ValueError("Invalid card-like number")
    card_number = match.group("card")
    last_four = re.sub(r"\D", "", card_number)[-4:]
    redacted = "**** **** **** " + last_four
    print("Account:", "ACC-1075")
    print("Redacted number:", redacted)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter synthetic card-like number: 1234-5678-9012-3456
# Account: ACC-1075
# Redacted number: **** **** **** 3456

# %% [markdown]
# Q76. Parse audit log entries with named groups for banking case 1; use sample reference ACC-1076 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s*\|\s*(?P<action>[A-Z]+)\s*\|\s*(?P<date>\d{2}-\d{2}-\d{4})"
try:
    log = input("Enter audit log entry: ")
    if log == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, log)
    if not match:
        raise ValueError("Invalid audit log format")
    print("Account:", "ACC-1076")
    print("Account Reference:", match.group("account"))
    print("Action:", match.group("action"))
    print("Date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter audit log entry: ACC-1076 | TRANSFER | 10-09-2026
# Account: ACC-1076
# Account Reference: ACC-1076
# Action: TRANSFER
# Date: 10-09-2026

# %% [markdown]
# Q77. Build a verbose-mode pattern for account holder ids for banking case 1; use sample reference ACC-1077 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = re.compile(r"""
    (?P<account>        # Account holder ID
        ACC-             # Required prefix
        \d{4}             # Exactly 4 digits
    )
""", re.VERBOSE)
try:
    account_id = input("Enter account holder ID: ")
    if account_id == "":
        raise ValueError("Empty input")
    match = pattern.fullmatch(account_id)
    if not match:
        raise ValueError("Invalid account holder ID")
    print("Account:", "ACC-1077")
    print("Account Holder ID:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account holder ID: ACC-1077
# Account: ACC-1077
# Account Holder ID: ACC-1077

# %% [markdown]
# Q78. Avoid catastrophic backtracking in a interest offer pattern for banking case 1; use sample reference ACC-1078 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<offer>INT-(?:\d{1,2}(?:\.\d{2})?)%)"
try:
    offer = input("Enter interest offer: ")
    if offer == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, offer)
    if not match:
        raise ValueError("Invalid interest offer")
    print("Account:", "ACC-1078")
    print("Interest Offer:", match.group("offer"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter interest offer: INT-10.50%
# Account: ACC-1078
# Interest Offer: INT-10.50%

# %% [markdown]
# Q79. Validate amount formats across supported currencies for banking case 1; use sample reference ACC-1079 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<currency>INR|USD|EUR)\s+(?P<amount>\d+(?:\.\d{2})?)"
try:
    value = input("Enter currency and amount: ")
    if value == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, value)
    if not match:
        raise ValueError("Invalid currency or amount")
    print("Account:", "ACC-1079")
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter currency and amount: USD 1000.50
# Account: ACC-1079
# Currency: USD
# Amount: 1000.50

# %% [markdown]
# Q80. Create a regex-based data quality report for banking case 1; use sample reference ACC-1080 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4}),(?P<amount>\d+(?:\.\d{2})?),(?P<date>\d{2}-\d{2}-\d{4})"
try:
    receipt = input("Enter receipt: ")
    if receipt == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, receipt)
    if match:
        print("Account:", "ACC-1080")
        print("Data Quality Report:")
        print("Account Reference: VALID")
        print("Amount: VALID")
        print("Date Format: VALID")
        print("\nExtracted Data:")
        print("Account:", match.group("account"))
        print("Amount:", match.group("amount"))
        print("Date:", match.group("date"))
    else:
        print("Account:", "ACC-1080")
        print("Data Quality Report: INVALID")
        print("Reason: Receipt format is incorrect")
except ValueError as e:
    print("Error:", e)
# Out:
# Enter receipt: ACC-1080,2500.50,10-09-2026
# Account: ACC-1080
# Data Quality Report:
# Account Reference: VALID
# Amount: VALID
# Date Format: VALID
#
# Extracted Data:
# Account: ACC-1080
# Amount: 2500.50
# Date: 10-09-2026

# %% [markdown]
# Q81. Tokenize a messy receipt safely for banking case 2; use sample reference ACC-1081 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s*,\s*(?P<amount>\d+(?:\.\d{2})?)\s*,\s*(?P<date>\d{2}-\d{2}-\d{4})"
try:
    receipt = input("Enter messy receipt: ")
    if receipt == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, receipt.strip())
    if not match:
        raise ValueError("Invalid receipt format")
    print("Account:", "ACC-1081")
    print("Account Reference:", match.group("account"))
    print("Amount:", match.group("amount"))
    print("Date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter messy receipt: ACC-1081 , 2500.50 , 15-08-2026
# Account: ACC-1081
# Account Reference: ACC-1081
# Amount: 2500.50
# Date: 15-08-2026

# %% [markdown]
# Q82. Validate a multi-part warehouse location for banking case 2; use sample reference ACC-1082 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify
# dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<warehouse>WH\d{2})-(?P<zone>Z\d{2})-(?P<rack>R\d{2})"
try:
    location = input("Enter warehouse location: ")
    if location == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, location)
    if not match:
        raise ValueError("Invalid warehouse location")
    print("Account:", "ACC-1082")
    print("Warehouse:", match.group("warehouse"))
    print("Zone:", match.group("zone"))
    print("Rack:", match.group("rack"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter warehouse location: WH01-Z05-R10
# Account: ACC-1082
# Warehouse: WH01
# Zone: Z05
# Rack: R10

# %% [markdown]
# Q83. Extract nested-looking account annotations within a defined limit for banking case 2; use sample reference ACC-1083 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s+\[(?P<annotation>[A-Za-z ]+(?:\([A-Za-z ]+\))?)\]"
try:
    text = input("Enter account annotation: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Invalid account annotation")
    annotation = match.group("annotation")
    if len(annotation) > 30:
        raise ValueError("Annotation is too long")
    print("Account:", "ACC-1083")
    print("Account Reference:", match.group("account"))
    print("Annotation:", annotation)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account annotation: ACC-1083 [VIP (Verified)]
# Account: ACC-1083
# Account Reference: ACC-1083
# Annotation: VIP (Verified)

# %% [markdown]
# Q84. Find duplicate adjacent account reference tokens with backreferences for banking case 2; use sample reference ACC-1084 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s+\1"
try:
    text = input("Enter two account references: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Duplicate adjacent account references not found")
    print("Account:", "ACC-1084")
    print("Duplicate reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter two account references: ACC-1084 ACC-1084
# Account: ACC-1084
# Duplicate reference: ACC-1084

# %% [markdown]
# Q85. Redact card-like numbers while preserving last four digits for banking case 2; use sample reference ACC-1085 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<card>\d{4}[- ]?\d{4}[- ]?\d{4}[- ]?\d{4})"
try:
    card = input("Enter synthetic card-like number: ")
    if card == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, card)
    if not match:
        raise ValueError("Invalid card-like number")
    card_number = match.group("card")
    digits = re.sub(r"\D", "", card_number)
    last_four = digits[-4:]
    redacted = "**** **** **** " + last_four
    print("Account:", "ACC-1085")
    print("Redacted number:", redacted)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter synthetic card-like number: 1234-5678-9012-3456
# Account: ACC-1085
# Redacted number: **** **** **** 3456

# %% [markdown]
# Q86. Parse audit log entries with named groups for banking case 2; use sample reference ACC-1086 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s*\|\s*(?P<action>[A-Z]+)\s*\|\s*(?P<date>\d{2}-\d{2}-\d{4})"
try:
    log = input("Enter audit log entry: ")
    if log == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, log)
    if not match:
        raise ValueError("Invalid audit log format")
    print("Account:", "ACC-1086")
    print("Account Reference:", match.group("account"))
    print("Action:", match.group("action"))
    print("Date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter audit log entry: ACC-1086 | TRANSFER | 10-09-2026
# Account: ACC-1086
# Account Reference: ACC-1086
# Action: TRANSFER
# Date: 10-09-2026

# %% [markdown]
# Q87. Build a verbose-mode pattern for account holder ids for banking case 2; use sample reference ACC-1087 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = re.compile(r"""
    (?P<account>        # Account holder ID
        ACC-             # Required prefix
        \d{4}            # Exactly 4 digits
    )
""", re.VERBOSE)
try:
    account_id = input("Enter account holder ID: ")
    if account_id == "":
        raise ValueError("Empty input")
    match = pattern.fullmatch(account_id)
    if not match:
        raise ValueError("Invalid account holder ID")
    print("Account:", "ACC-1087")
    print("Account Holder ID:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account holder ID: ACC-1087
# Account: ACC-1087
# Account Holder ID: ACC-1087

# %% [markdown]
# Q88. Avoid catastrophic backtracking in a interest offer pattern for banking case 2; use sample reference ACC-1088 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<offer>INT-(?:\d{1,2}(?:\.\d{2})?)%)"
try:
    offer = input("Enter interest offer: ")
    if offer == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, offer)
    if not match:
        raise ValueError("Invalid interest offer")
    print("Account:", "ACC-1088")
    print("Interest Offer:", match.group("offer"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter interest offer: INT-10.50%
# Account: ACC-1088
# Interest Offer: INT-10.50%

# %% [markdown]
# Q89. Validate amount formats across supported currencies for banking case 2; use sample reference ACC-1089 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<currency>INR|USD|EUR)\s+(?P<amount>\d+(?:\.\d{2})?)"
try:
    value = input("Enter currency and amount: ")
    if value == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, value)
    if not match:
        raise ValueError("Invalid currency or amount")
    print("Account:", "ACC-1089")
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter currency and amount: USD 1000.50
# Account: ACC-1089
# Currency: USD
# Amount: 1000.50

# %% [markdown]
# Q90. Create a regex-based data quality report for banking case 2; use sample reference ACC-1090 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4}),(?P<amount>\d+(?:\.\d{2})?),(?P<date>\d{2}-\d{2}-\d{4})"
try:
    receipt = input("Enter receipt: ")
    if receipt == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, receipt)
    if match:
        print("Account:", "ACC-1090")
        print("Data Quality Report:")
        print("Account Reference: VALID")
        print("Amount: VALID")
        print("Date Format: VALID")
        print("\nExtracted Data:")
        print("Account:", match.group("account"))
        print("Amount:", match.group("amount"))
        print("Date:", match.group("date"))
    else:
        print("Account:", "ACC-1090")
        print("Data Quality Report: INVALID")
        print("Reason: Receipt format is incorrect")
except ValueError as e:
    print("Error:", e)
# Out:
# Enter receipt: ACC-1090,2500.50,10-09-2026
# Account: ACC-1090
# Data Quality Report:
# Account Reference: VALID
# Amount: VALID
# Date Format: VALID
#
# Extracted Data:
# Account: ACC-1090
# Amount: 2500.50
# Date: 10-09-2026

# %% [markdown]
# Q91. Tokenize a messy receipt safely for banking case 3; use sample reference ACC-1091 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s*,\s*(?P<amount>\d+(?:\.\d{2})?)\s*,\s*(?P<date>\d{2}-\d{2}-\d{4})"
try:
    receipt = input("Enter messy receipt: ")
    if receipt == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, receipt.strip())
    if not match:
        raise ValueError("Invalid receipt format")
    print("Account:", "ACC-1091")
    print("Account Reference:", match.group("account"))
    print("Amount:", match.group("amount"))
    print("Date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter messy receipt: ACC-1091 , 2500.50 , 15-08-2026
# Account: ACC-1091
# Account Reference: ACC-1091
# Amount: 2500.50
# Date: 15-08-2026

# %% [markdown]
# Q92. Validate a multi-part warehouse location for banking case 3; use sample reference ACC-1092 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<warehouse>WH\d{2})-(?P<zone>Z\d{2})-(?P<rack>R\d{2})"
try:
    location = input("Enter warehouse location: ")
    if location == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, location)
    if not match:
        raise ValueError("Invalid warehouse location")
    print("Account:", "ACC-1092")
    print("Warehouse:", match.group("warehouse"))
    print("Zone:", match.group("zone"))
    print("Rack:", match.group("rack"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter warehouse location: WH01-Z01-R01
# Account: ACC-1092
# Warehouse: WH01
# Zone: Z01
# Rack: R01

# %% [markdown]
# Q93. Extract nested-looking account annotations within a defined limit for banking case 3; use sample reference ACC-1093 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s+\[(?P<annotation>[A-Za-z ]+(?:\([A-Za-z ]+\))?)\]"
try:
    text = input("Enter account annotation: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Invalid account annotation")
    annotation = match.group("annotation")
    if len(annotation) > 30:
        raise ValueError("Annotation is too long")
    print("Account:", "ACC-1093")
    print("Account Reference:", match.group("account"))
    print("Annotation:", annotation)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account annotation: ACC-1093 [VIP (Verified)]
# Account: ACC-1093
# Account Reference: ACC-1093
# Annotation: VIP (Verified)

# %% [markdown]
# Q94. Find duplicate adjacent account reference tokens with backreferences for banking case 3; use sample reference ACC-1094 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s+\1"
try:
    text = input("Enter two account references: ")
    if text == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, text)
    if not match:
        raise ValueError("Duplicate adjacent account references not found")
    print("Account:", "ACC-1094")
    print("Duplicate reference:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter two account references: ACC-1094 ACC-1094
# Account: ACC-1094
# Duplicate reference: ACC-1094

# %% [markdown]
# Q95. Redact card-like numbers while preserving last four digits for banking case 3; use sample reference ACC-1095 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<card>\d{4}[- ]?\d{4}[- ]?\d{4}[- ]?\d{4})"
try:
    card = input("Enter synthetic card-like number: ")
    if card == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, card)
    if not match:
        raise ValueError("Invalid card-like number")
    card_number = match.group("card")
    digits = re.sub(r"\D", "", card_number)
    last_four = digits[-4:]
    redacted = "**** **** **** " + last_four
    print("Account:", "ACC-1095")
    print("Redacted number:", redacted)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter synthetic card-like number: 1234-5678-9012-3456
# Account: ACC-1095
# Redacted number: **** **** **** 3456

# %% [markdown]
# Q96. Parse audit log entries with named groups for banking case 3; use sample reference ACC-1096 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4})\s*\|\s*(?P<action>[A-Z]+)\s*\|\s*(?P<date>\d{2}-\d{2}-\d{4})"
try:
    log = input("Enter audit log entry: ")
    if log == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, log)
    if not match:
        raise ValueError("Invalid audit log format")
    print("Account:", "ACC-1096")
    print("Account Reference:", match.group("account"))
    print("Action:", match.group("action"))
    print("Date:", match.group("date"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter audit log entry: ACC-1096 | LOGIN | 10-09-2026
# Account: ACC-1096
# Account Reference: ACC-1096
# Action: LOGIN
# Date: 10-09-2026

# %% [markdown]
# Q97. Build a verbose-mode pattern for account holder ids for banking case 3; use sample reference ACC-1097 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = re.compile(r"""
    (?P<account>        # Account holder ID
        ACC-             # Required prefix
        \d{4}             # Exactly 4 digits
    )
""", re.VERBOSE)
try:
    account_id = input("Enter account holder ID: ")
    if account_id == "":
        raise ValueError("Empty input")
    match = pattern.fullmatch(account_id)
    if not match:
        raise ValueError("Invalid account holder ID")
    print("Account:", "ACC-1097")
    print("Account Holder ID:", match.group("account"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account holder ID: ACC-1097
# Account: ACC-1097
# Account Holder ID: ACC-1097

# %% [markdown]
# Q98. Avoid catastrophic backtracking in a interest offer pattern for banking case 3; use sample reference ACC-1098 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<offer>INT-(?:\d{1,2}(?:\.\d{2})?)%)"
try:
    offer = input("Enter interest offer: ")
    if offer == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, offer)
    if not match:
        raise ValueError("Invalid interest offer")
    print("Account:", "ACC-1098")
    print("Interest Offer:", match.group("offer"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter interest offer: INT-10.50%
# Account: ACC-1098
# Interest Offer: INT-10.50%

# %% [markdown]
# Q99. Validate amount formats across supported currencies for banking case 3; use sample reference ACC-1099 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<currency>INR|USD|EUR)\s+(?P<amount>\d+(?:\.\d{2})?)"
try:
    value = input("Enter currency and amount: ")
    if value == "":
        raise ValueError("Empty input")
    match = re.fullmatch(pattern, value)
    if not match:
        raise ValueError("Invalid currency or amount")
    print("Account:", "ACC-1099")
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter currency and amount: USD 1000.50
# Account: ACC-1099
# Currency: USD
# Amount: 1000.50

# %% [markdown]
# Q100. Create a regex-based data quality report for banking case 3; use sample reference ACC-1100 and explain the result.
#
# Hints
#
# Write representative valid and invalid samples before writing the pattern.
#
# Use raw strings, named groups for extraction, and fullmatch for whole-field validation.
#
# Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re
pattern = r"(?P<account>ACC-\d{4}),(?P<amount>\d+(?:\.\d{2})?),(?P<date>\d{2}-\d{2}-\d{4})"
receipt = input("Enter receipt: ")
if receipt == "":
    print("Error: Empty input")
else:
    match = re.fullmatch(pattern, receipt)
    if match:
        print("Account: ACC-1100")
        print("Data Quality Report: VALID")
        print("Account:", match.group("account"))
        print("Amount:", match.group("amount"))
        print("Date:", match.group("date"))
    else:
        print("Account: ACC-1100")
        print("Data Quality Report: INVALID")
# Out:
# Enter receipt: ACC-1100,2500.50,10-09-2026
# Account: ACC-1100
# Data Quality Report: VALID
# Account: ACC-1100
# Amount: 2500.50
# Date: 10-09-2026
