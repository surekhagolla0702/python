# %% [markdown]
# Question 1

# %%
# program to find the square root of a number using math module
import math
math.sqrt(16)
# Out:
# 4.0

# %% [markdown]
# Question 2

# %%
# program to find cube root of a number using mathematical operations
n = 27
cbrt = n ** (1/3)
print(cbrt)
# Out:
# 3.0

# %% [markdown]
# Question 3

# %%
math.factorial(6)  ## factorial of a number using math.factorial()
# Out:
# 720

# %% [markdown]
# Question 4

# %%
#GCD: Greatest Common Divisor
math.gcd(6,21)
# Out:
# 3

# %% [markdown]
# Question 5

# %%
math.lcm(14,18) #lcm of two numbers
# Out:
# 126

# %% [markdown]
# Question 6

# %%
# program to find the value of 5 raised to the power of 8 using math.pow
math.pow(5, 8)
5 is the base value
8 is the exponent
# Out:
# 390625.0

# %% [markdown]
# Question 7

# %%
#Program to find the absolute value of a negative decimal number using math.fabs()
math.fabs(-10)
# Out:
# 10.0

# %% [markdown]
# Question 8

# %%
# program to round a floating-point number up using math.ceil()
math.ceil(5.6774)
# ceil() round to the highest value
# Out:
# 6

# %% [markdown]
# Question 9

# %%
# program to round a floating-point number down using math.floor().
math.floor(6.785)
# floor() round to the lowest value
# Out:
# 6

# %% [markdown]
# Question 10

# %%
# program to round a floating-point number to the nearest integer using round().
round(4.683, 2)
# Out:
# 4.68

# %% [markdown]
# Question 11

# %%
# program to find the remainder of two numbers using math.fmod()
x, y =20,3
math.fmod(x, y)
# Out:
# 2.0

# %% [markdown]
# Question 12

# %%
#program to find the quotient and remainder using divmod()
n1 = 28
n2 = 11
quotient, remainder = divmod(n1, n2)
print(quotient)
print(remainder)
# Out:
# 2
# 6

# %% [markdown]
# Question 13

# %%
# program to calculate the sine, cosine, and tangent of 45 degrees
print(math.sin(45))
print(math.cos(45))
print(math.tan(45))
# Out:
# 0.8509035245341184
# 0.5253219888177297
# 1.6197751905438615

# %% [markdown]
# Question 14

# %%
# program to convert an angle from degrees to radians
math.radians(90)
# math.radians() is used to an angle from degrees to radians
# Out:
# 1.5707963267948966

# %% [markdown]
# Question 15

# %%
#Convert an angle from radians to degrees
radians = math.pi
degrees = math.degrees(radians)
print(degrees)
# Out:
# 180.0

# %% [markdown]
# Question 16

# %%
# program to find the logarithm (base 10) of a number using math.log10()
math.log10(100)
# Out:
# 2.0

# %% [markdown]
# Question 17

# %%
# program to find the natural logarithm of a number using math.log().
math.log(32)
# Out:
# 3.4657359027997265

# %% [markdown]
# Question 18

# %%
# Calculate e raised to the power of x using math.exp()
math.exp(2)
# Out:
# 7.38905609893065

# %% [markdown]
# Question 19

# %%
 # Find the value of π (pi) and Euler's number (e) from the math module
 math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %% [markdown]
# Question 20

# %%
#Find the distance between two points using math.dist()
math.dist((1,2),(3,6))
# Out:
# 4.47213595499958

# %% [markdown]
# Question 21

# %%
# Calculate the hypotenuse of a right triangle using math.hypot().
base = 6
height = 8
hypotenuse = math.hypot(base, height)
print(hypotenuse)
# Out:
# 10.0

# %% [markdown]
# Question 22

# %%
# Find the combination (nCr) using math.comb().
math.comb(5,3)
# Out:
# 10

# %% [markdown]
# Question 23

# %%
# Find the permutation (nPr) using math.perm().
import math
math.perm(5, 3)
# Out:
# 60

# %% [markdown]
# Question 24

# %%
# Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan().
num = 10
math.isfinite(num)
# Out:
# True

# %%
math.isinf(num)
# Out:
# False

# %%
math.isnan(num)
# Out:
# False

# %% [markdown]
# Question 25

# %%
# Find the product of all numbers in a list using math.prod()
n= [2,4,6,2]
math.prod(n)
# Out:
# 96

# %% [markdown]
# Question 26

# %%
# Find the sum of square roots of all numbers in a list.
numbers = [4, 9, 16, 25]
res = sum(math.sqrt(num)for num in numbers)
print(res)
# Out:
# 14.0

# %% [markdown]
# Question 27

# %%
# Find the largest integer less than or equal to the square root of a given number.
n = 20
res = math.floor(math.sqrt(n))
print(res)
# Out:
# 4

# %% [markdown]
# Question 28

# %%
# Calculate compound interest using math.pow()
principal = 1000
rate = 5
time = 2
amount = principal * math.pow((1 + rate / 100), time)
compound_interest = amount - principal
print("Amount:", amount)
print("Compound Interest:", compound_interest)
# Out:
# Amount: 1102.5
# Compound Interest: 102.5

# %% [markdown]
# Question 29

# %%
# Find the area and circumference of a circle using math.pi.
radius = 7
area = math.pi * radius ** 2
circumference = 2 * math.pi * radius
print("Area:", area)
print("Circumference:", circumference)
# Out:
# Area: 153.93804002589985
# Circumference: 43.982297150257104

# %% [markdown]
# Question 30

# %%
# create a scientific calculator that supprots square root,factorial,logarithm,power,trigonometric functions, GCD and LCM
print("Scientific Calculator")
print("1. Square Root")
print("2. Factorial")
print("3. Logarithm (base 10)")
print("4. Power")
print("5. Sine")
print("6. Cosine")
print("7. Tangent")
print("8. GCD")
print("9. LCM")
choice = int(input("Enter your choice (1-9): "))
if choice == 1:
    num = float(input("Enter a number: "))
    print("Square Root =", math.sqrt(num))
elif choice == 2:
    num = int(input("Enter a number: "))
    print("Factorial =", math.factorial(num))
elif choice == 3:
    num = float(input("Enter a number: "))
    print("Logarithm =", math.log10(num))
elif choice == 4:
    base = float(input("Enter base: "))
    exponent = float(input("Enter exponent: "))
    print("Power =", math.pow(base, exponent))
elif choice == 5:
    angle = float(input("Enter angle in degrees: "))
    print("Sine =", math.sin(math.radians(angle)))
elif choice == 6:
    angle = float(input("Enter angle in degrees: "))
    print("Cosine =", math.cos(math.radians(angle)))
elif choice == 7:
    angle = float(input("Enter angle in degrees: "))
    print("Tangent =", math.tan(math.radians(angle)))
elif choice == 8:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("GCD =", math.gcd(a, b))
elif choice == 9:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("LCM =", math.lcm(a, b))
else:
    print("Invalid Choice")
# Out:
# Scientific Calculator
# 1. Square Root
# 2. Factorial
# 3. Logarithm (base 10)
# 4. Power
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. GCD
# 9. LCM
# Enter your choice (1-9): 6
# Enter angle in degrees: 90
# Cosine = 6.123233995736766e-17

# %% [markdown]
# Operators

# %% [markdown]
# Arithmetic Operators

# %% [markdown]
# Question 1

# %%
# write a program to perform addition,subtraction,multiplication,division,floor division,modulus and exponentiation on two numbers
a = 20
b = 10
print("Addition:",a + b)
print("Subtraction:", a - b)
print("Multiplication:",a * b)
print("Division:",a / b)
print("Floor division:", a // b)
print("Modulus:",a % b)
print("Exponentiation:",a ** b)
# Out:
# Addition: 30
# Subtraction: 10
# Multiplication: 200
# Division: 2.0
# Floor division: 2
# Modulus: 0
# Exponentiation: 10240000000000

# %% [markdown]
# Question 2

# %%
# Swap two numbers without using a third variable
a = 10
b = 20
a, b = b, a
print("a =", a)
print("b =", b)
# Out:
# a = 20
# b = 10

# %% [markdown]
# Question 3

# %%
# Find whether a number is even or odd using the modulus operator.
number = 11
if number % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %% [markdown]
# Question 4

# %%
# Reverse a three-digit number using arithmetic operators.
num = 122
rev = (num % 10) * 100 + ((num // 10) * 10) + (num // 100)
print("reversed number:", rev)
# Out:
# reversed number: 321

# %% [markdown]
# Question 5

# %%
# Find the last digit and first digit of a given number
num = 102938
last_digit = num % 10
while num >= 10:
  num = num // 10
  first_digit = num
print("first digit:", first_digit)
print("last digit:", last_digit)
# Out:
# first digit: 1
# last digit: 8

# %% [markdown]
# Assignment Operators

# %% [markdown]
# Question 6

# %%
# Demonstrate all assignment operators (=, +=, -=, =, /=, //=, %= and *=) on a variable.
a = 10
print("= :", a)
a += 5
print("+=:", a)
a -= 3
print("-=:", a)
a *= 5
print("*=:", a)
a /= 3
print("/=:", a)
a //= 2
print("//=:", a)
a %= 4
print("%=:", a)
# Out:
# = : 10
# +=: 15
# -=: 12
# *=: 60
# /=: 20.0
# //=: 10.0
# %=: 2.0

# %% [markdown]
# Question 7

# %%
#Update a bank account balance using compound assignment operators.
balance = 2500
balance += 500
print("After Deposit:", balance)
balance -= 200
print("After Withdrawal:", balance)
balance *= 2
print("After Bonus:", balance)
balance /= 2
print("After Division:", balance)
balance //= 3
print("After Floor Division:", balance)
balance %= 100
print("After Modulus:", balance)
# Out:
# After Deposit: 3000
# After Withdrawal: 2800
# After Bonus: 5600
# After Division: 2800.0
# After Floor Division: 933.0
# After Modulus: 33.0

# %% [markdown]
# Question 8

# %%
# program to calculate the total marks using += inside a loop.
total = 0
for i in range(3):
    marks = int(input("Enter marks: "))
    total += marks
print("Total Marks =", total)
# Out:
# Enter marks: 97
# Enter marks: 83
# Enter marks: 78
# Total Marks = 258

# %% [markdown]
# Comparison Operators

# %% [markdown]
# Question 9

# %%
# Compare two numbers and print the larger number.
a = 67
b = 23
if a > b:
  print("larger number is:", a)
else:
  print("larger number is:", b)
# Out:
# larger number is: 67

# %% [markdown]
# Question 10

# %%
# Check whether three numbers are equal.
a = 111
b = 111
c = 111
if a == b == c:
  print("all numbers are equal")
else:
  print("numbers are not equal")
# Out:
# all numbers are equal

# %% [markdown]
# Question 11

# %%
# Find the largest among three numbers using comparison operators.
a = 23
b = 34
c = 11
if a >= b and a >= c:
  print("a is largest")
elif b >= a and b >= c:
  print("b is largest")
else:
  print("c is largest")
# Out:
# b is largest

# %% [markdown]
# Question 12

# %%
# Check whether a student is eligible to vote based on age
age = 25
if age >= 18:
  print("eligible to vote")
else:
  print("Not eligible to vote")
# Out:
# eligible to vote

# %% [markdown]
# Logical Operators

# %% [markdown]
# Question 13

# %%
# Check if a person is eligible for a loan (age > 21 AND salary > 30000).
age = 25
salary = 50000
if age > 21 and salary > 30000:
  print("eligible for loan")
else:
  print("not eligible for loan")
# Out:
# eligible for loan

# %% [markdown]
# Question 14

# %%
# Check if a number lies between 10 and 100 using logical operators.
number = 55
if number >= 10 and  number <= 100:
  print(" Number lies between 10 and 100")
else:
  print("Number does not lies in between 10 and 100")
# Out:
#  Number lies between 10 and 100

# %% [markdown]
# Question 15

# %%
# Validate username and password using logical operators.
username = "admin"
password = "1234"
if username == "admin" and password == "1234":
  print("Login success")
else:
  print("Invalid login")
# Out:
# Login success

# %% [markdown]
# Question 16

# %%
# Determine whether a year is a leap year using logical conditions.
year = 2026
if (year % 4 == 0 and year % 100 != 0) or (year % 400 ==  0):
  print("Leap year")
else:
  print("not leap year")
# Out:
# not leap year

# %% [markdown]
# Bitwise Operators

# %% [markdown]
# Question 17

# %%
# Find the bitwise AND, OR, XOR of two numbers.
a = 26
b = 13
print("Bitwise AND:",a & b)
print("Bitwise OR:", a | b)
print("Bitwise XOR:", a ^ b)
# Out:
# Bitwise AND: 8
# Bitwise OR: 31
# Bitwise XOR: 23

# %% [markdown]
# Question 18

# %%
#Perform left shift and right shift operations.
num = 8
print("Left Shift =", num << 2)
print("Right Shift =", num >> 2)
# Out:
# Left Shift = 32
# Right Shift = 2

# %% [markdown]
# Question 19

# %%
#Check whether a number is even using a bitwise operator.
num = 8
if (num & 1) == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# Question 20

# %%
# Swap two numbers using the XOR operator
a = 10
b = 20
a = a ^ b
b = a ^ b
a = a ^ b
print("a =", a)
print("b =", b)
# Out:
# a = 20
# b = 10

# %% [markdown]
# Question 21

# %%
# Count how many bits are set to 1 using bitwise operations
num = 13
count = 0
while num > 0:
    count += num & 1
    num = num >> 1
print("Number of set bits =", count)
# Out:
# Number of set bits = 3

# %% [markdown]
# Identity Operators

# %% [markdown]
# Question 22

# %%
#Demonstrate the difference between is and ==.
a = [1, 2, 3]
b = [1, 2, 3]
print(a == b)  # checks whether values are equal
print(a is b)  #check whether both variables refer same object in memory
# Out:
# True
# False

# %% [markdown]
# Question 23

# %%
#Check whether two variables refer to the same list object.
list1  =  [1, 2, 3]
list2 = list1
if list1 is list2:
  print("Two variables refer to same  list object")
else:
  print("Two variables does not refer to same object")
# Out:
# Two variables refer to same  list object

# %% [markdown]
# Question 24

# %%
# Show the behavior of is not with integers and lists.
a = 10
b = 20
print(a is not b)
list1 = [1, 2, 3]
list2 = [1, 2, 3]
print(list1 is not list2)
# Out:
# True
# True

# %% [markdown]
# Membership Operators

# %% [markdown]
# Question 25

# %%
#Check whether a character exists in a string.
String = "Python"
ch = "h"
if ch in String:
  print("Character exists")
else:
  print("Character does not exist")
# Out:
# Character exists

# %% [markdown]
# Question 26

# %%
#Check whether a number exists in a list.
numbers = [23, 45, 67, 12, 99]
num = 30
if num in numbers:
  print(f"{num} is exist")
else:
  print(f"{num} does not exist")
# Out:
# 30 does not exist

# %% [markdown]
# Question 27

# %%
#Count how many vowels in a string belong to a predefined vowel list using in.
text = "Data Science"
vowels = "aeiouAEIOU"
count = 0
for ch in text:
    if ch in vowels:
        count += 1
print("Number of vowels =", count)
# Out:
# Number of vowels = 5

# %% [markdown]
# Mixed Operator Programs

# %% [markdown]
# Question 28

# %%
#Build a simple calculator using arithmetic and comparison operators.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
op = input("Enter operator (+, -, *, /): ")
if op == "+":
    print("Result =", a + b)
elif op == "-":
    print("Result =", a - b)
elif op == "*":
    print("Result =", a * b)
elif op == "/":
    if b != 0:
        print("Result =", a / b)
    else:
        print("Division by zero is not possible")
else:
    print("Invalid operator")
# Out:
# Enter first number: 12
# Enter second number: 23
# Enter operator (+, -, *, /): +
# Result = 35

# %% [markdown]
# Question 29

# %%
#Create a grading system using comparison and logical operators.
marks = int(input("Enter marks: "))
if marks >= 90 and marks <= 100:
    print("Grade A")
elif marks >= 80 and marks < 90:
    print("Grade B")
elif marks >= 70 and marks < 80:
    print("Grade C")
elif marks >= 60 and marks < 70:
    print("Grade D")
elif marks >= 0 and marks < 60:
    print("Grade F")
else:
    print("Invalid marks")
# Out:
# Enter marks: 89
# Grade B

# %% [markdown]
# Question 30

# %%
#Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
print("5.Bitwise AND")
print("6.Check Equal")
print("7.Check Identity")
print("8.Check Membership")
choice = int(input("Enter your choice: "))
if choice == 1:
    result = a
    result += b                      # Assignment operator
    print("Addition =", result)
elif choice == 2:
    print("Subtraction =", a - b)
elif choice == 3:
    print("Multiplication =", a * b)
elif choice == 4:
    if b != 0:                           # Comparison operator
        print("Division =", a / b)
    else:
        print("Division not possible")
elif choice == 5:
    print("Bitwise AND =", a & b)         # Bitwise operator
elif choice == 6:
    if a == b:                            # Comparison operator
        print("Numbers are Equal")
    else:
        print("Numbers are Not Equal")
elif choice == 7:
    print(a is b)                          # Identity operator
elif choice == 8:
    numbers = [10, 20, 30, 40, 50]
    if a in numbers:                        # Membership operator
        print("First number is in the list")
    else:
        print("First number is not in the list")
else:
    print("Invalid Choice")
# Out:
# Enter first number: 32
# Enter second number: 54
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Bitwise AND
# 6.Check Equal
# 7.Check Identity
# 8.Check Membership
# Enter your choice: 1
# Addition = 86

# %% [markdown]
# Question 30
