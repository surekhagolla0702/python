# %%
bank = [
     [
           [
               ["C101", "Rahul", "Savings", 85000],
               ["C102", "Anita", "Current", 150000],
               ["C103", "Kiran", "Loan", 500000]
           ],

           [
               ["C104", "Sneha", "Savings", 95000],
               ["C105", "Vikram", "Current", 275000],
               ["C106", "Meena", "Loan", 750000]
           ]
      ],



[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
     ]

# %%
bank[0][0][0]
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
bank[0][0][1][2]
# Out:
# 'Current'

# %%
bank[0][0][2][3]
# Out:
# 500000

# %%
bank[0][1][0][0]
# Out:
# 'C104'

# %%
bank[0][1][1][3]
# Out:
# 275000

# %%
bank[0][1][2]
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %%
bank[1][0][0][0]
# Out:
# 'C201'

# %%
bank[1][0][1][1]
# Out:
# 'Pooja'

# %%
bank[1][0][2][2]
# Out:
# 'Loan'

# %%
bank[1][1][0][3]
# Out:
# 45000

# %%
bank[1][1][1][2]
# Out:
# 'Current'

# %%
bank[1][1][2][0]
# Out:
# 'C206'

# %%
bank[2][0][0][2]
# Out:
# 'Savings'

# %%
bank[2][0][1][3]
# Out:
# 240000

# %%
bank[2][0][2][3]
# Out:
# 1000000

# %%
bank[2][1][0][1]
# Out:
# 'Neha'

# %%
bank[2][1][1]
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %%
bank[2][1][2][2]
# Out:
# 'Loan'

# %%
bank[0][0]
# Out:
# [['C101', 'Rahul', 'Savings', 85000],
#  ['C102', 'Anita', 'Current', 150000],
#  ['C103', 'Kiran', 'Loan', 500000]]

# %%
bank[0][1]
# Out:
# [['C104', 'Sneha', 'Savings', 95000],
#  ['C105', 'Vikram', 'Current', 275000],
#  ['C106', 'Meena', 'Loan', 750000]]

# %%
bank[1][0]
# Out:
# [['C201', 'Arjun', 'Savings', 120000],
#  ['C202', 'Pooja', 'Current', 325000],
#  ['C203', 'Ramesh', 'Loan', 900000]]

# %%
bank[1][1]
# Out:
# [['C204', 'Priya', 'Savings', 45000],
#  ['C205', 'Amit', 'Current', 185000],
#  ['C206', 'Divya', 'Loan', 650000]]

# %%
bank[2][0]
# Out:
# [['C301', 'Nikhil', 'Savings', 78000],
#  ['C302', 'Kavya', 'Current', 240000],
#  ['C303', 'Suresh', 'Loan', 1000000]]

# %%
bank[2][1]
# Out:
# [['C304', 'Neha', 'Savings', 135000],
#  ['C305', 'Rohan', 'Current', 410000],
#  ['C306', 'Asha', 'Loan', 550000]]

# %%
bank[0]
# Out:
# [[['C101', 'Rahul', 'Savings', 85000],
#   ['C102', 'Anita', 'Current', 150000],
#   ['C103', 'Kiran', 'Loan', 500000]],
#  [['C104', 'Sneha', 'Savings', 95000],
#   ['C105', 'Vikram', 'Current', 275000],
#   ['C106', 'Meena', 'Loan', 750000]]]

# %%
bank[1]
# Out:
# [[['C201', 'Arjun', 'Savings', 120000],
#   ['C202', 'Pooja', 'Current', 325000],
#   ['C203', 'Ramesh', 'Loan', 900000]],
#  [['C204', 'Priya', 'Savings', 45000],
#   ['C205', 'Amit', 'Current', 185000],
#   ['C206', 'Divya', 'Loan', 650000]]]

# %%
bank[2]
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000],
#   ['C302', 'Kavya', 'Current', 240000],
#   ['C303', 'Suresh', 'Loan', 1000000]],
#  [['C304', 'Neha', 'Savings', 135000],
#   ['C305', 'Rohan', 'Current', 410000],
#   ['C306', 'Asha', 'Loan', 550000]]]

# %%
print(bank[0][0][0][1],
      bank[1][0][0][1],
      bank[2][0][0][1])
# Out:
# Rahul Arjun Nikhil

# %%
print(bank[0][1][1][1],
      bank[1][1][1][1],
      bank[2][1][1][1])
# Out:
# Vikram Amit Rohan

# %%
print(bank[2][1][2][3])
# Out:
# 550000

# %%
emp=["rahul","vikram","nikhil","varun","vishal"]
emp.append("sekhar")
emp
# Out:
# ['rahul', 'vikram', 'nikhil', 'varun', 'vishal', 'sekhar']

# %%
acc_num=[2344,345,567,123]
acc_num.extend([897])
acc_num
# Out:
# [2344, 345, 567, 123, 897]

# %%
customer=["asri","harshitha","harika","himani"]
customer.insert(3,"jahnavi")
customer
# Out:
# ['asri', 'harshitha', 'harika', 'jahnavi', 'himani']

# %%
trans_amt=[300,500,400,1200,1500]
trans_amt.insert(3,2000)
trans_amt
# Out:
# [300, 500, 400, 2000, 1200, 1500]

# %%
fruits=["banana","apple","guava","orange"]
fruits.pop(3)
# Out:
# 'orange'

# %%
customer=["prasanth","teja","rahul","sudheer"]
customer.remove("rahul")
customer
# Out:
# ['prasanth', 'teja', 'sudheer']

# %%
acc_type=[1,2,3,5,"Savings","Current",56,7]
acc_type.count("Savings")
# Out:
# 1

# %%
acc=["savings","salary","current","fixed deposit"]
acc.index("current")
# Out:
# 2

# %%
trans_id=[1233,4567,7890,837]
trans_id.reverse()
trans_id
# Out:
# [837, 7890, 4567, 1233]

# %%
bal=[2800,5000,1280,500,985]
bal.sort()
bal
# Out:
# [500, 985, 1280, 2800, 5000]

# %%
names=["himani","jahnavi","asritha","harshitha","meghana"]
names.sort(reverse=True)
names
# Out:
# ['meghana', 'jahnavi', 'himani', 'harshitha', 'asritha']

# %%
p=[1,2,3,4]
q=p.copy()
q[2]=133
print(p,q)
# Out:
# [1, 2, 3, 4] [1, 2, 133, 4]

# %%
q=[23,56,78,90,2]
q.clear()
q
# Out:
# []

# %%
customer_list=["prashanth","ashif","prathap","gopi","sudarshan"]
customer_list.append(["ali","nikhil"])
customer_list
# Out:
# ['prashanth', 'ashif', 'prathap', 'gopi', 'sudarshan', ['ali', 'nikhil']]

# %%
branch=["bangalore","hyderabad","chennai","delhi"]
new_branch=["mumbai","noida"]
branch.extend(new_branch)
print(branch)
# Out:
# ['bangalore', 'hyderabad', 'chennai', 'delhi', 'mumbai', 'noida']

# %%
balance=[12000,5000,3000,3400,2500,5000,9800]
balance.remove(5000)
balance
# Out:
# [12000, 3000, 3400, 2500, 5000, 9800]

# %%
element=[34,54,67,89,10,45]
removed_ele=element.pop(2)
print(removed_ele)
# Out:
# 67

# %%
city=["hyderabad","bangalore","mumbai","chennai","bangalore","noida"]
city.count("bangalore")
# Out:
# 2

# %%
bank_names=["union","SBI","canara","apgb","ICCI","RBI"]
bank_names.reverse()
bank_names
# Out:
# ['RBI', 'ICCI', 'apgb', 'canara', 'SBI', 'union']

# %%
amnt=[28000,12000,43000,70000,37000]
amnt.sort(reverse=True)
amnt
# Out:
# [70000, 43000, 37000, 28000, 12000]
