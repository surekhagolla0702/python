# %% [markdown]
# Easy
# Fundamentals and direct applications.
#
# Q1. Write a function for line total for banking case 1; use sample reference ACC-1001 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def line_total(quantity, price):
    return quantity * price
# Sample reference
print("Account:", "ACC-1001")
quantity = 5
price = 100
total = line_total(quantity, price)
print("Line Total:", total)
# Out:
# Account: ACC-1001
# Line Total: 500

# %% [markdown]
# Q2. Return a discounted amount for banking case 1; use sample reference ACC-1002 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discounted_amount(amount, discount):
    if amount < 0:
        raise ValueError("Amount cannot be negative")
    if discount < 0 or discount > 100:
        raise ValueError("Discount must be between 0 and 100")
    return amount - (amount * discount / 100)
try:
    amount = float(input("Enter amount: "))
    discount = float(input("Enter discount percentage: "))
    result = discounted_amount(amount, discount)
    print("Account:", "ACC-1002")
    print("Discounted Amount:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 2500
# Enter discount percentage: 10
# Account: ACC-1002
# Discounted Amount: 2250.0

# %% [markdown]
# Q3. Use a default tax rate for banking case 1; use sample reference ACC-1003 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def add_tax(amount, tax_rate=18):
    if amount < 0:
        raise ValueError("Amount cannot be negative")
    if tax_rate < 0 or tax_rate > 100:
        raise ValueError("Invalid tax rate")
    return amount + (amount * tax_rate / 100)
try:
    amount = float(input("Enter amount: "))
    result = add_tax(amount)
    print("Account:", "ACC-1003")
    print("Amount with Tax:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 3000
# Account: ACC-1003
# Amount with Tax: 3540.0

# %% [markdown]
# Q4. Accept keyword arguments for a account for banking case 1; use sample reference ACC-1004 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_details(**kwargs):
    if not kwargs:
        raise ValueError("No account details provided")
    for key, value in kwargs.items():
        if not isinstance(value, str):
            raise TypeError("Account details must be strings")
    return kwargs
try:
    account = account_details(
        account="ACC-1004",
        name="Surekha",
        account_type="Savings"
    )
    print("Account:", "ACC-1004")
    print("Account Details:", account)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1004
# Account Details: {'account': 'ACC-1004', 'name': 'Surekha', 'account_type': 'Savings'}

# %% [markdown]
# Q5. Return multiple inventory values for banking case 1; use sample reference ACC-1005 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def inventory_values(account, balance, transactions):
    if not account:
        raise ValueError("Account cannot be empty")
    if balance < 0 or transactions < 0:
        raise ValueError("Values cannot be negative")
    return account, balance, transactions
try:
    result = inventory_values("ACC-1005", 5000, 10)
    print("Account:", "ACC-1005")
    print("Inventory Values:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1005
# Inventory Values: ('ACC-1005', 5000, 10)

# %% [markdown]
# Q6. Write a account docstring for banking case 1; use sample reference ACC-1006 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_details(account):
    """Return account reference."""
    if account == "":
        raise ValueError("Empty account")
    return account
try:
    account = input("Enter account: ")
    result = account_details(account)
    print("Account:", "ACC-1006")
    print("Account Details:", result)
    print("Docstring:", account_details.__doc__)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter account: ACC-2045
# Account: ACC-1006
# Account Details: ACC-2045
# Docstring: Return account reference.

# %% [markdown]
# Q7. Add type hints to a amount function for banking case 1; use sample reference ACC-1007 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def amount(value: float) -> float:
    """Return the amount."""
    if value < 0:
        raise ValueError("Amount cannot be negative")
    return value
try:
    value = float(input("Enter amount: "))
    result = amount(value)
    print("Account:", "ACC-1007")
    print("Amount:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 50000
# Account: ACC-1007
# Amount: 50000.0

# %% [markdown]
# Q8. Use *args to total purchases for banking case 1; use sample reference ACC-1008 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def total_purchases(*args):
    if not args:
        raise ValueError("No purchases entered")
    for amount in args:
        if not isinstance(amount, (int, float)):
            raise TypeError("Purchase must be a number")
        if amount < 0:
            raise ValueError("Purchase cannot be negative")
    return sum(args)
try:
    purchases = [100, 200, 300]
    total = total_purchases(*purchases)
    print("Account:", "ACC-1008")
    print("Total Purchases:", total)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1008
# Total Purchases: 600

# %% [markdown]
# Q9. Use **kwargs for account attributes for banking case 1; use sample reference ACC-1009 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_attributes(**kwargs):
    if not kwargs:
        raise ValueError("No details")
    return kwargs
try:
    account = account_attributes(
        account="ACC-1009",
        name="Surekha",
        type="Savings"
    )
    print("Account:", "ACC-1009")
    print("Attributes:", account)
except ValueError as e:
    print("Error:", e)
# Out:
# Account: ACC-1009
# Attributes: {'account': 'ACC-1009', 'name': 'Surekha', 'type': 'Savings'}

# %% [markdown]
# Q10. Create a one-line amount lambda for banking case 1; use sample reference ACC-1010 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
amount = lambda x: x if x >= 0 else 0
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    value = float(value)
    if value < 0:
        raise ValueError("Amount cannot be negative")
    result = amount(value)
    print("Account:", "ACC-1010")
    print("Amount:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 40000
# Account: ACC-1010
# Amount: 40000.0

# %% [markdown]
# Q11. Map amounts to tax-inclusive amounts for banking case 1; use sample reference ACC-1011 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def add_tax(amount):
    if amount < 0:
        raise ValueError("Amount cannot be negative")
    return amount + (amount * 18 / 100)
try:
    values = input("Enter amounts separated by space: ")
    if values == "":
        raise ValueError("Empty input")
    amounts = list(map(float, values.split()))
    result = list(map(add_tax, amounts))
    print("Account:", "ACC-1011")
    print("Tax-inclusive amounts:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amounts separated by space: 2000 40000
# Account: ACC-1011
# Tax-inclusive amounts: [2360.0, 47200.0]

# %% [markdown]
# Q12. Filter in-balance accounts for banking case 1; use sample reference ACC-1012 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
# Use filter for selection, map for transformation, and reduce only when a
# clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def in_balance(account):
    return account["balance"] >= 0
try:
    accounts = [
        {"account": "ACC-1012", "balance": 5000},
        {"account": "ACC-1013", "balance": -1000},
        {"account": "ACC-1014", "balance": 0}
    ]
    if not accounts:
        raise ValueError("Empty input")
    result = list(filter(in_balance, accounts))
    print("Account:", "ACC-1012")
    print("In-balance accounts:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1012
# In-balance accounts: [{'account': 'ACC-1012', 'balance': 5000}, {'account': 'ACC-1014', 'balance': 0}]

# %% [markdown]
# Q13. Reduce a basket to its total for banking case 1; use sample reference ACC-1013 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def basket_total(values):
    if not values:
        raise ValueError("Empty basket")
    if any(not isinstance(x, (int, float)) for x in values):
        raise TypeError("Invalid value")
    if any(x < 0 for x in values):
        raise ValueError("Negative value")
    return reduce(lambda a, b: a + b, values)
try:
    basket = [100, 200, 300]
    print("Account:", "ACC-1013")
    print("Basket Total:", basket_total(basket))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1013
# Basket Total: 600

# %% [markdown]
# Q14. Demonstrate local scope for banking case 1; use sample reference ACC-1014 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_details(account):
    if account == "":
        raise ValueError("Empty account")
    if not isinstance(account, str):
        raise TypeError("Invalid account type")
    balance = 5000       # local variable
    return account, balance
try:
    result = account_details("ACC-1014")
    print("Account:", result[0])
    print("Balance:", result[1])
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1014
# Balance: 5000

# %% [markdown]
# Q15. Write a predicate for premium accounts for banking case 1; use sample reference ACC-1015 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def is_premium(balance):
    if balance < 0:
        raise ValueError("Balance cannot be negative")
    return balance >= 100000
try:
    balance = input("Enter balance: ")
    if balance == "":
        raise ValueError("Empty input")
    balance = float(balance)
    result = is_premium(balance)
    print("Account:", "ACC-1015")
    print("Premium Account:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter balance: 15000
# Account: ACC-1015
# Premium Account: False

# %% [markdown]
# Q16. Write a function for line total for banking case 2; use sample reference ACC-1016 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def line_total(quantity, price):
    if quantity < 0 or price < 0:
        raise ValueError("Values cannot be negative")
    return quantity * price
try:
    quantity = input("Enter quantity: ")
    price = input("Enter price: ")
    if quantity == "" or price == "":
        raise ValueError("Empty input")
    quantity = int(quantity)
    price = float(price)
    result = line_total(quantity, price)
    print("Account:", "ACC-1016")
    print("Line Total:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter quantity: 3
# Enter price: 30
# Account: ACC-1016
# Line Total: 90.0

# %% [markdown]
# Q17. Return a discounted amount for banking case 2; use sample reference ACC-1017 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discounted_amount(amount, discount):
    if amount < 0 or discount < 0 or discount > 100:
        raise ValueError("Invalid value")
    return amount - (amount * discount / 100)
try:
    amount = input("Enter amount: ")
    discount = input("Enter discount: ")
    if amount == "" or discount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    discount = float(discount)
    print("Account:", "ACC-1017")
    print("Discounted Amount:", discounted_amount(amount, discount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 30000
# Enter discount: 10
# Account: ACC-1017
# Discounted Amount: 27000.0

# %% [markdown]
# Q18. Use a default tax rate for banking case 2; use sample reference ACC-1018 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def add_tax(amount, tax=18):
    if amount < 0 or tax < 0 or tax > 100:
        raise ValueError("Invalid value")
    return amount + (amount * tax / 100)
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    print("Account:", "ACC-1018")
    print("Amount with Tax:", add_tax(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 20000
# Account: ACC-1018
# Amount with Tax: 23600.0

# %% [markdown]
# Q19. Accept keyword arguments for a account for banking case 2; use sample reference ACC-1019 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_details(**kwargs):
    if not kwargs:
        raise ValueError("Empty input")
    for value in kwargs.values():
        if not isinstance(value, str):
            raise TypeError("Invalid type")
    return kwargs
try:
    account = account_details(
        account="ACC-1019",
        name="Surekha",
        type="Savings"
    )
    print("Account:", "ACC-1019")
    print("Account Details:", account)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1019
# Account Details: {'account': 'ACC-1019', 'name': 'Surekha', 'type': 'Savings'}

# %% [markdown]
# Q20. Return multiple inventory values for banking case 2; use sample reference ACC-1020 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def inventory_values(account, quantity, price):
    if account == "":
        raise ValueError("Empty account")
    if not isinstance(quantity, int) or not isinstance(price, (int, float)):
        raise TypeError("Invalid type")
    if quantity < 0 or price < 0:
        raise ValueError("Invalid value")
    return account, quantity, price
try:
    result = inventory_values("ACC-1020", 10, 500)
    print("Account:", "ACC-1020")
    print("Inventory Values:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1020
# Inventory Values: ('ACC-1020', 10, 500)

# %% [markdown]
# Q21. Write a account docstring for banking case 2; use sample reference ACC-1021 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_details(account):
    """Return account reference."""
    if account == "":
        raise ValueError("Empty input")
    if not isinstance(account, str):
        raise TypeError("Invalid type")
    return account
try:
    account = input("Enter account: ")
    result = account_details(account)
    print("Account:", "ACC-1021")
    print("Account Details:", result)
    print("Docstring:", account_details.__doc__)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter account: ACC-8783
# Account: ACC-1021
# Account Details: ACC-8783
# Docstring: Return account reference.

# %% [markdown]
# Q22. Add type hints to a amount function for banking case 2; use sample reference ACC-1022 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def amount(value: float) -> float:
    if value < 0:
        raise ValueError("Amount cannot be negative")
    return value
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    value = float(value)
    result = amount(value)
    print("Account:", "ACC-1022")
    print("Amount:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 20000
# Account: ACC-1022
# Amount: 20000.0

# %% [markdown]
# Q23. Use *args to total purchases for banking case 2; use sample reference ACC-1023 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def total_purchases(*args):
    if not args:
        raise ValueError("Empty input")
    for amount in args:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
    return sum(args)
try:
    purchases = [100, 200, 300]
    total = total_purchases(*purchases)
    print("Account:", "ACC-1023")
    print("Total Purchases:", total)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1023
# Total Purchases: 600

# %% [markdown]
# Q24. Use **kwargs for account attributes for banking case 2; use sample reference ACC-1024 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_attributes(**kwargs):
    if not kwargs:
        raise ValueError("Empty input")
    for value in kwargs.values():
        if not isinstance(value, str):
            raise TypeError("Invalid type")
    return kwargs
try:
    account = account_attributes(
        account="ACC-1024",
        name="Surekha",
        type="Savings"
    )
    print("Account:", "ACC-1024")
    print("Account Attributes:", account)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1024
# Account Attributes: {'account': 'ACC-1024', 'name': 'Surekha', 'type': 'Savings'}

# %% [markdown]
# Q25. Create a one-line amount lambda for banking case 2; use sample reference ACC-1025 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
amount = lambda x: x
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    value = float(value)
    if value < 0:
        raise ValueError("Amount cannot be negative")
    result = amount(value)
    print("Account:", "ACC-1025")
    print("Amount:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 20000
# Account: ACC-1025
# Amount: 20000.0

# %% [markdown]
# Q26. Map amounts to tax-inclusive amounts for banking case 2; use sample reference ACC-1026 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def add_tax(amount):
    if amount < 0:
        raise ValueError("Negative amount")
    return amount + amount * 18 / 100
try:
    values = input("Enter amounts: ")
    if values == "":
        raise ValueError("Empty input")
    amounts = list(map(float, values.split()))
    result = list(map(add_tax, amounts))
    print("Account:", "ACC-1026")
    print("Tax-inclusive amounts:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts: 20000
# Account: ACC-1026
# Tax-inclusive amounts: [23600.0]

# %% [markdown]
# Q27. Filter in-balance accounts for banking case 2; use sample reference ACC-1027 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def in_balance(account):
    if not isinstance(account["balance"], (int, float)):
        raise TypeError("Invalid balance")
    return account["balance"] >= 0
try:
    accounts = [
        {"account": "ACC-1027", "balance": 5000},
        {"account": "ACC-1028", "balance": -1000},
        {"account": "ACC-1029", "balance": 0}
    ]
    if not accounts:
        raise ValueError("Empty input")
    result = list(filter(in_balance, accounts))
    print("Account:", "ACC-1027")
    print("In-balance accounts:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1027
# In-balance accounts: [{'account': 'ACC-1027', 'balance': 5000}, {'account': 'ACC-1029', 'balance': 0}]

# %% [markdown]
# Q28. Reduce a basket to its total for banking case 2; use sample reference ACC-1028 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def basket_total(values):
    if not values:
        raise ValueError("Empty input")
    for value in values:
        if not isinstance(value, (int, float)):
            raise TypeError("Invalid type")
        if value < 0:
            raise ValueError("Negative value")
    return reduce(lambda a, b: a + b, values)
try:
    basket = [100, 200, 300]
    result = basket_total(basket)
    print("Account:", "ACC-1028")
    print("Basket Total:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1028
# Basket Total: 600

# %% [markdown]
# Q29. Demonstrate local scope for banking case 2; use sample reference ACC-1029 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_details(account):
    if account == "":
        raise ValueError("Empty input")
    if not isinstance(account, str):
        raise TypeError("Invalid type")
    balance = 5000       # local variable
    return account, balance
try:
    account = input("Enter account: ")
    if account == "":
        raise ValueError("Empty input")
    result = account_details(account)
    print("Account:", "ACC-1029")
    print("Account Details:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter account: ACC-2032
# Account: ACC-1029
# Account Details: ('ACC-2032', 5000)

# %% [markdown]
# Q30. Write a predicate for premium accounts for banking case 2; use sample reference ACC-1030 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def is_premium(balance):
    if balance < 0:
        raise ValueError("Balance cannot be negative")
    return balance >= 100000
try:
    balance = input("Enter balance: ")
    if balance == "":
        raise ValueError("Empty input")
    balance = float(balance)
    print("Account:", "ACC-1030")
    print("Premium Account:", is_premium(balance))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter balance: 100000
# Account: ACC-1030
# Premium Account: True

# %% [markdown]
# Medium
# Reusable components and multi-step workflows.
#
# Q31. Compose discount and tax functions for banking case 1; use sample reference ACC-1031 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discount(amount):
    return amount - (amount * 10 / 100)
def tax(amount):
    return amount + (amount * 18 / 100)
def final_amount(amount):
    return tax(discount(amount))
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    print("Account:", "ACC-1031")
    print("Final Amount:", final_amount(amount))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 10000
# Account: ACC-1031
# Final Amount: 10620.0

# %% [markdown]
# Q32. Sort accounts with a lambda key for banking case 1; use sample reference ACC-1032 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a
# clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def sort_accounts(accounts):
    if not accounts:
        raise ValueError("Empty input")
    for account in accounts:
        if not isinstance(account["balance"], (int, float)):
            raise TypeError("Invalid balance")
    return sorted(accounts, key=lambda x: x["balance"])
try:
    accounts = [
        {"account": "ACC-1032", "balance": 5000},
        {"account": "ACC-1033", "balance": 2000},
        {"account": "ACC-1034", "balance": 8000}
    ]
    result = sort_accounts(accounts)
    print("Account:", "ACC-1032")
    print("Sorted Accounts:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1032
# Sorted Accounts: [{'account': 'ACC-1033', 'balance': 2000}, {'account': 'ACC-1032', 'balance': 5000}, {'account': 'ACC-1034', 'balance': 8000}]

# %% [markdown]
# Q33. Group accounts using a helper function for banking case 1; use sample reference ACC-1033 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def group_account(balance):
    return "Premium" if balance >= 100000 else "Regular"
def group_accounts(accounts):
    if not accounts:
        raise ValueError("Empty input")
    return [(a["account"], group_account(a["balance"])) for a in accounts]
try:
    accounts = [
        {"account": "ACC-1033", "balance": 150000},
        {"account": "ACC-1034", "balance": 50000},
        {"account": "ACC-1035", "balance": 100000}
    ]
    print("Account:", "ACC-1033")
    print("Grouped Accounts:", group_accounts(accounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1033
# Grouped Accounts: [('ACC-1033', 'Premium'), ('ACC-1034', 'Regular'), ('ACC-1035', 'Premium')]

# %% [markdown]
# Q34. Create a closure for category discounts for banking case 1; use sample reference ACC-1034 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a
# clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_discount(discount):
    def apply_discount(amount):
        return amount - (amount * discount / 100)
    return apply_discount
try:
    discount = input("Enter discount: ")
    amount = input("Enter amount: ")
    if discount == "" or amount == "":
        raise ValueError("Empty input")
    discount = float(discount)
    amount = float(amount)
    if discount < 0 or discount > 100 or amount < 0:
        raise ValueError("Invalid value")
    result = category_discount(discount)(amount)
    print("Account:", "ACC-1034")
    print("Discounted Amount:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter discount: 10
# Enter amount: 4000
# Account: ACC-1034
# Discounted Amount: 3600.0

# %% [markdown]
# Q35. Write a decorator that logs checkout calls for banking case 1; use sample reference ACC-1035 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path

# %%
def log_checkout(func):
    def wrapper(amount):
        print("Checkout called")
        return func(amount)
    return wrapper
@log_checkout
def checkout(amount):
    return amount
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    print("Account:", "ACC-1035")
    print("Checkout Amount:", checkout(amount))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 30000
# Account: ACC-1035
# Checkout called
# Checkout Amount: 30000.0

# %% [markdown]
# Q36. Build a map-filter-reduce transactions pipeline for banking case 1; use sample reference ACC-1036 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def process_transactions(transactions):
    if not transactions:
        raise ValueError("Empty input")
    for amount in transactions:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
    valid = filter(lambda x: x > 0, transactions)
    amounts = map(lambda x: x, valid)
    return reduce(lambda a, b: a + b, amounts, 0)
try:
    transactions = [1000, -200, 500, 0, 300]
    result = process_transactions(transactions)
    print("Account:", "ACC-1036")
    print("Total:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1036
# Total: 1800

# %% [markdown]
# Q37. Partially apply a tax function for banking case 1; use sample reference ACC-1037 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import partial
def add_tax(amount, tax):
    return amount + (amount * tax / 100)
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    tax_18 = partial(add_tax, tax=18)
    print("Account:", "ACC-1037")
    print("Amount with Tax:", tax_18(amount))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 20000
# Account: ACC-1037
# Amount with Tax: 23600.0

# %% [markdown]
# Q38. Use enumerate and zip in a balance report for banking case 1; use sample reference ACC-1038 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def balance_report(accounts, balances):
    if not accounts or not balances:
        raise ValueError("Empty input")
    if len(accounts) != len(balances):
        raise ValueError("Different lengths")
    return [(i + 1, account, balance)
            for i, (account, balance) in enumerate(zip(accounts, balances))]
try:
    accounts = ["ACC-1038", "ACC-1039", "ACC-1040"]
    balances = [5000, 0, 10000]
    print("Account:", "ACC-1038")
    print("Balance Report:", balance_report(accounts, balances))
except ValueError as e:
    print("Error:", e)
# Out:
# Account: ACC-1038
# Balance Report: [(1, 'ACC-1038', 5000), (2, 'ACC-1039', 0), (3, 'ACC-1040', 10000)]

# %% [markdown]
# Q39. Write a generator for low-balance accounts for banking case 1; use sample reference ACC-1039 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def low_balance(accounts):
    if not accounts:
        raise ValueError("Empty input")
    for account in accounts:
        if not isinstance(account["balance"], (int, float)):
            raise TypeError("Invalid balance")
        if account["balance"] < 10000:
            yield account
try:
    accounts = [
        {"account": "ACC-1039", "balance": 5000},
        {"account": "ACC-1040", "balance": 15000},
        {"account": "ACC-1041", "balance": 0}
    ]
    print("Account:", "ACC-1039")
    print("Low Balance Accounts:", list(low_balance(accounts)))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1039
# Low Balance Accounts: [{'account': 'ACC-1039', 'balance': 5000}, {'account': 'ACC-1041', 'balance': 0}]

# %% [markdown]
# Q40. Implement recursive category total for banking case 1; use sample reference ACC-1040 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_total(amounts):
    if not amounts:
        return 0
    if not isinstance(amounts[0], (int, float)):
        raise TypeError("Invalid type")
    if amounts[0] < 0:
        raise ValueError("Invalid amount")
    return amounts[0] + category_total(amounts[1:])
try:
    amounts = [1000, 2000, 3000]
    print("Account:", "ACC-1040")
    print("Category Total:", category_total(amounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1040
# Category Total: 6000

# %% [markdown]
# Q41. Validate arguments with a wrapper for banking case 1; use sample reference ACC-1041 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def validate(func):
    def wrapper(amount):
        if amount < 0:
            raise ValueError("Invalid amount")
        return func(amount)
    return wrapper
@validate
def amount(value):
    return value
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    value = float(value)
    print("Account:", "ACC-1041")
    print("Amount:", amount(value))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 26000
# Account: ACC-1041
# Amount: 26000.0

# %% [markdown]
# Q42. Return a function selected by interest offer type for banking case 1; use sample reference ACC-1042 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular(amount):
    return amount * 0.05
def premium(amount):
    return amount * 0.08
def get_offer(offer):
    if offer == "regular":
        return regular
    return premium
try:
    offer = input("Enter offer: ")
    amount = input("Enter amount: ")
    if offer == "" or amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    result = get_offer(offer)(amount)
    print("Account:", "ACC-1042")
    print("Interest:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter offer: premium
# Enter amount: 25000
# Account: ACC-1042
# Interest: 2000.0

# %% [markdown]
# Q43. Keep a pricing function pure for banking case 1; use sample reference ACC-1043 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def pricing(amount):
    if amount < 0:
        raise ValueError("Invalid amount")
    return amount * 1.18
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    print("Account:", "ACC-1043")
    print("Price:", pricing(amount))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 26000
# Account: ACC-1043
# Price: 30680.0

# %% [markdown]
# Q44. Calculate basket metrics in one pass for banking case 1; use sample reference ACC-1044 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def basket_metrics(values):
    if not values:
        raise ValueError("Empty input")
    total = 0
    for value in values:
        if not isinstance(value, (int, float)):
            raise TypeError("Invalid type")
        if value < 0:
            raise ValueError("Invalid value")
        total += value
    return total, total / len(values)
try:
    values = [100, 200, 300]
    total, average = basket_metrics(values)
    print("Account:", "ACC-1044")
    print("Total:", total)
    print("Average:", average)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1044
# Total: 600
# Average: 200.0

# %% [markdown]
# Q45. Unit-test a reusable banking function for banking case 1; use sample reference ACC-1045 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import unittest
def calculate_amount(amount):
    if amount < 0:
        raise ValueError("Invalid amount")
    return amount * 1.18
class TestBanking(unittest.TestCase):
    def test_amount(self):
        self.assertEqual(calculate_amount(1000), 1180)
    def test_zero(self):
        self.assertEqual(calculate_amount(0), 0)
    def test_negative(self):
        with self.assertRaises(ValueError):
            calculate_amount(-100)
unittest.main(argv=[''], exit=False)
# Out:
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.003s
#
# OK

# %% [markdown]
# Q46. Compose discount and tax functions for banking case 2; use sample reference ACC-1046 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discount(amount):
    return amount - amount * 10 / 100
def tax(amount):
    return amount + amount * 18 / 100
def final_amount(amount):
    return tax(discount(amount))
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    print("Account:", "ACC-1046")
    print("Final Amount:", final_amount(amount))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 30000
# Account: ACC-1046
# Final Amount: 31860.0

# %% [markdown]
# Q47. Sort accounts with a lambda key for banking case 2; use sample reference ACC-1047 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def sort_accounts(accounts):
    if not accounts:
        raise ValueError("Empty input")
    for account in accounts:
        if not isinstance(account["balance"], (int, float)):
            raise TypeError("Invalid balance")
    return sorted(accounts, key=lambda x: x["balance"])
try:
    accounts = [
        {"account": "ACC-1047", "balance": 5000},
        {"account": "ACC-1048", "balance": 2000},
        {"account": "ACC-1049", "balance": 8000}
    ]
    print("Account:", "ACC-1047")
    print("Sorted Accounts:", sort_accounts(accounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1047
# Sorted Accounts: [{'account': 'ACC-1048', 'balance': 2000}, {'account': 'ACC-1047', 'balance': 5000}, {'account': 'ACC-1049', 'balance': 8000}]

# %% [markdown]
# Q48. Group accounts using a helper function for banking case 2; use sample reference ACC-1048 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def group_account(balance):
    return "Premium" if balance >= 100000 else "Regular"
def group_accounts(accounts):
    if not accounts:
        raise ValueError("Empty input")
    for a in accounts:
        if not isinstance(a["balance"], (int, float)):
            raise TypeError("Invalid balance")
    return [(a["account"], group_account(a["balance"])) for a in accounts]
try:
    accounts = [
        {"account": "ACC-1048", "balance": 150000},
        {"account": "ACC-1049", "balance": 50000},
        {"account": "ACC-1050", "balance": 100000}
    ]
    print("Account:", "ACC-1048")
    print("Grouped Accounts:", group_accounts(accounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1048
# Grouped Accounts: [('ACC-1048', 'Premium'), ('ACC-1049', 'Regular'), ('ACC-1050', 'Premium')]

# %% [markdown]
# Q49. Create a closure for category discounts for banking case 2; use sample reference ACC-1049 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_discount(discount):
    def apply_discount(amount):
        return amount - (amount * discount / 100)
    return apply_discount
try:
    discount = input("Enter discount: ")
    amount = input("Enter amount: ")
    if discount == "" or amount == "":
        raise ValueError("Empty input")
    discount = float(discount)
    amount = float(amount)
    if discount < 0 or discount > 100 or amount < 0:
        raise ValueError("Invalid value")
    apply_discount = category_discount(discount)
    result = apply_discount(amount)
    print("Account:", "ACC-1049")
    print("Discounted Amount:", result)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter discount: 20
# Enter amount: 4000
# Account: ACC-1049
# Discounted Amount: 3200.0

# %% [markdown]
# Q50. Write a decorator that logs checkout calls for banking case 2; use sample reference ACC-1050 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_checkout(func):
    def wrapper(amount):
        print("Checkout called")
        return func(amount)
    return wrapper
@log_checkout
def checkout(amount):
    return amount
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    print("Account:", "ACC-1050")
    print("Checkout Amount:", checkout(amount))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 25000
# Account: ACC-1050
# Checkout called
# Checkout Amount: 25000.0

# %% [markdown]
# Q51. Build a map-filter-reduce transactions pipeline for banking case 2; use sample reference ACC-1051 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def process_transactions(transactions):
    if not transactions:
        raise ValueError("Empty input")
    for amount in transactions:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
    # filter: select positive transactions
    valid = filter(lambda x: x > 0, transactions)
    # map: transform the selected transactions
    amounts = map(lambda x: x, valid)
    # reduce: calculate the total
    return reduce(lambda a, b: a + b, amounts, 0)
try:
    transactions = [1000, -200, 500, 0, 300]
    result = process_transactions(transactions)
    print("Account:", "ACC-1051")
    print("Total Transactions:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1051
# Total Transactions: 1800

# %% [markdown]
# Q52. Partially apply a tax function for banking case 2; use sample reference ACC-1052 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import partial
def add_tax(amount, tax):
    return amount + (amount * tax / 100)
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    tax_18 = partial(add_tax, tax=18)
    print("Account:", "ACC-1052")
    print("Amount with Tax:", tax_18(amount))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 25000
# Account: ACC-1052
# Amount with Tax: 29500.0

# %% [markdown]
# Q53. Use enumerate and zip in a balance report for banking case 2; use sample reference ACC-1053 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def balance_report(accounts, balances):
    if not accounts or not balances:
        raise ValueError("Empty input")
    if len(accounts) != len(balances):
        raise ValueError("Different lengths")
    for balance in balances:
        if not isinstance(balance, (int, float)):
            raise TypeError("Invalid balance")
    return [
        (i + 1, account, balance)
        for i, (account, balance) in enumerate(zip(accounts, balances))
    ]
try:
    accounts = ["ACC-1053", "ACC-1054", "ACC-1055"]
    balances = [5000, 0, 10000]
    result = balance_report(accounts, balances)
    print("Account:", "ACC-1053")
    print("Balance Report:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1053
# Balance Report: [(1, 'ACC-1053', 5000), (2, 'ACC-1054', 0), (3, 'ACC-1055', 10000)]

# %% [markdown]
# Q54. Write a generator for low-balance accounts for banking case 2; use sample reference ACC-1054 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def low_balance(accounts):
    if not accounts:
        raise ValueError("Empty input")
    for account in accounts:
        if not isinstance(account["balance"], (int, float)):
            raise TypeError("Invalid balance")
        if account["balance"] < 0:
            raise ValueError("Negative balance")
        if account["balance"] < 10000:
            yield account
try:
    accounts = [
        {"account": "ACC-1054", "balance": 5000},
        {"account": "ACC-1055", "balance": 10000},
        {"account": "ACC-1056", "balance": 15000}
    ]
    print("Account:", "ACC-1054")
    print("Low Balance Accounts:", list(low_balance(accounts)))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1054
# Low Balance Accounts: [{'account': 'ACC-1054', 'balance': 5000}]

# %% [markdown]
# Q55. Implement recursive category total for banking case 2; use sample reference ACC-1055 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_total(amounts):
    if not amounts:
        return 0
    if not isinstance(amounts[0], (int, float)):
        raise TypeError("Invalid type")
    if amounts[0] < 0:
        raise ValueError("Invalid amount")
    return amounts[0] + category_total(amounts[1:])
try:
    amounts = [1000, 2000, 3000]
    print("Account:", "ACC-1055")
    print("Category Total:", category_total(amounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1055
# Category Total: 6000

# %% [markdown]
# Q56. Validate arguments with a wrapper for banking case 2; use sample reference ACC-1056 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def validate(func):
    def wrapper(amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Invalid amount")
        return func(amount)
    return wrapper
@validate
def calculate_amount(amount):
    return amount
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    value = float(value)
    print("Account:", "ACC-1056")
    print("Amount:", calculate_amount(value))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 20000
# Account: ACC-1056
# Amount: 20000.0

# %% [markdown]
# Q57. Return a function selected by interest offer type for banking case 2; use sample reference ACC-1057 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular(amount):
    return amount * 0.05
def premium(amount):
    return amount * 0.08
def get_offer(offer):
    if offer == "regular":
        return regular
    if offer == "premium":
        return premium
    raise ValueError("Invalid offer")
try:
    offer = input("Enter offer: ")
    amount = input("Enter amount: ")
    if offer == "" or amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    result = get_offer(offer)(amount)
    print("Account:", "ACC-1057")
    print("Interest:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter offer: premium
# Enter amount: 20000
# Account: ACC-1057
# Interest: 1600.0

# %% [markdown]
# Q58. Keep a pricing function pure for banking case 2; use sample reference ACC-1058 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def pricing(amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Invalid amount")
    return amount * 1.18
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    value = float(value)
    print("Account:", "ACC-1058")
    print("Price:", pricing(value))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 15000
# Account: ACC-1058
# Price: 17700.0

# %% [markdown]
# Q59. Calculate basket metrics in one pass for banking case 2; use sample reference ACC-1059 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def basket_metrics(values):
    if not values:
        raise ValueError("Empty input")
    total = 0
    for value in values:
        if not isinstance(value, (int, float)):
            raise TypeError("Invalid type")
        if value < 0:
            raise ValueError("Invalid value")
        total += value
    return total, total / len(values)
try:
    values = [100, 200, 300]
    total, average = basket_metrics(values)
    print("Account:", "ACC-1059")
    print("Total:", total)
    print("Average:", average)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1059
# Total: 600
# Average: 200.0

# %% [markdown]
# Q60. Unit-test a reusable banking function for banking case 2; use sample reference ACC-1060 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
import unittest
def calculate_amount(amount):
    if amount < 0:
        raise ValueError("Invalid amount")
    return amount * 1.18
class TestBanking(unittest.TestCase):
    def test_amount(self):
        self.assertEqual(calculate_amount(1000), 1180)
    def test_zero(self):
        self.assertEqual(calculate_amount(0), 0)
    def test_negative(self):
        with self.assertRaises(ValueError):
            calculate_amount(-100)
unittest.main(argv=[''], exit=False)
# Out:
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.006s
#
# OK

# %% [markdown]
# Q61. Compose discount and tax functions for banking case 3; use sample reference ACC-1061 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discount(amount):
    return amount - (amount * 10 / 100)
def tax(amount):
    return amount + (amount * 18 / 100)
def final_amount(amount):
    return tax(discount(amount))
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    value = float(value)
    if value < 0:
        raise ValueError("Invalid amount")
    print("Account:", "ACC-1061")
    print("Final Amount:", final_amount(value))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 20000
# Account: ACC-1061
# Final Amount: 21240.0

# %% [markdown]
# Q62. Sort accounts with a lambda key for banking case 3; use sample reference ACC-1062 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def sort_accounts(accounts):
    if not accounts:
        raise ValueError("Empty input")
    for account in accounts:
        if not isinstance(account["balance"], (int, float)):
            raise TypeError("Invalid balance")
        if account["balance"] < 0:
            raise ValueError("Invalid balance")
    return sorted(accounts, key=lambda x: x["balance"])
try:
    accounts = [
        {"account": "ACC-1062", "balance": 5000},
        {"account": "ACC-1063", "balance": 0},
        {"account": "ACC-1064", "balance": 8000}
    ]
    print("Account:", "ACC-1062")
    print("Sorted Accounts:", sort_accounts(accounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1062
# Sorted Accounts: [{'account': 'ACC-1063', 'balance': 0}, {'account': 'ACC-1062', 'balance': 5000}, {'account': 'ACC-1064', 'balance': 8000}]

# %% [markdown]
# Q63. Group accounts using a helper function for banking case 3; use sample reference ACC-1063 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a
# clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def group_account(balance):
    if balance >= 100000:
        return "Premium"
    return "Regular"
def group_accounts(accounts):
    if not accounts:
        raise ValueError("Empty input")
    for account in accounts:
        if not isinstance(account["balance"], (int, float)):
            raise TypeError("Invalid balance")
        if account["balance"] < 0:
            raise ValueError("Invalid balance")
    return [(account["account"], group_account(account["balance"]))
            for account in accounts]
try:
    accounts = [
        {"account": "ACC-1063", "balance": 150000},
        {"account": "ACC-1064", "balance": 50000},
        {"account": "ACC-1065", "balance": 100000}
    ]
    print("Account:", "ACC-1063")
    print("Grouped Accounts:", group_accounts(accounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1063
# Grouped Accounts: [('ACC-1063', 'Premium'), ('ACC-1064', 'Regular'), ('ACC-1065', 'Premium')]

# %% [markdown]
# Q64. Create a closure for category discounts for banking case 3; use sample reference ACC-1064 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_discount(discount):
    def apply_discount(amount):
        return amount - (amount * discount / 100)
    return apply_discount
try:
    discount = input("Enter discount: ")
    amount = input("Enter amount: ")
    if discount == "" or amount == "":
        raise ValueError("Empty input")
    discount = float(discount)
    amount = float(amount)
    if discount < 0 or discount > 100 or amount < 0:
        raise ValueError("Invalid value")
    result = category_discount(discount)(amount)
    print("Account:", "ACC-1064")
    print("Discounted Amount:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter discount: 10
# Enter amount: 3000
# Account: ACC-1064
# Discounted Amount: 2700.0

# %% [markdown]
# Q65. Write a decorator that logs checkout calls for banking case 3; use sample reference ACC-1065 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_checkout(func):
    def wrapper(amount):
        if amount < 0:
            raise ValueError("Invalid amount")
        print("Checkout called")
        return func(amount)
    return wrapper
@log_checkout
def checkout(amount):
    return amount
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    print("Account:", "ACC-1065")
    print("Checkout Amount:", checkout(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 5000
# Account: ACC-1065
# Checkout called
# Checkout Amount: 5000.0

# %% [markdown]
# Q66. Build a map-filter-reduce transactions pipeline for banking case 3; use sample reference ACC-1066 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def process_transactions(transactions):
    if not transactions:
        raise ValueError("Empty input")
    for amount in transactions:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
    valid = filter(lambda x: x > 0, transactions)
    amounts = map(lambda x: x, valid)
    return reduce(lambda a, b: a + b, amounts, 0)
try:
    transactions = [1000, -200, 500, 0, 300]
    result = process_transactions(transactions)
    print("Account:", "ACC-1066")
    print("Total:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1066
# Total: 1800

# %% [markdown]
# Q67. Partially apply a tax function for banking case 3; use sample reference ACC-1067 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import partial
def add_tax(amount, tax):
    return amount + (amount * tax / 100)
try:
    amount = input("Enter amount: ")
    if amount == "":
        raise ValueError("Empty input")
    amount = float(amount)
    if amount < 0:
        raise ValueError("Invalid amount")
    tax_18 = partial(add_tax, tax=18)
    print("Account:", "ACC-1067")
    print("Amount with Tax:", tax_18(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 4000
# Account: ACC-1067
# Amount with Tax: 4720.0

# %% [markdown]
# Q68. Use enumerate and zip in a balance report for banking case 3; use sample reference ACC-1068 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def balance_report(accounts, balances):
    if not accounts or not balances:
        raise ValueError("Empty input")
    if len(accounts) != len(balances):
        raise ValueError("Different lengths")
    for balance in balances:
        if not isinstance(balance, (int, float)):
            raise TypeError("Invalid type")
        if balance < 0:
            raise ValueError("Invalid balance")
    return [(i + 1, account, balance)
            for i, (account, balance) in enumerate(zip(accounts, balances))]
try:
    accounts = ["ACC-1068", "ACC-1069", "ACC-1070"]
    balances = [5000, 0, 10000]
    print("Account:", "ACC-1068")
    print("Balance Report:", balance_report(accounts, balances))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1068
# Balance Report: [(1, 'ACC-1068', 5000), (2, 'ACC-1069', 0), (3, 'ACC-1070', 10000)]

# %% [markdown]
# Q69. Write a generator for low-balance accounts for banking case 3; use sample reference ACC-1069 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def low_balance(accounts):
    if not accounts:
        raise ValueError("Empty input")
    for account in accounts:
        if not isinstance(account["balance"], (int, float)):
            raise TypeError("Invalid type")
        if account["balance"] < 0:
            raise ValueError("Invalid balance")
        if account["balance"] < 10000:
            yield account
try:
    accounts = [
        {"account": "ACC-1069", "balance": 5000},
        {"account": "ACC-1070", "balance": 10000},
        {"account": "ACC-1071", "balance": 15000}
    ]
    print("Account:", "ACC-1069")
    print("Low Balance Accounts:", list(low_balance(accounts)))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1069
# Low Balance Accounts: [{'account': 'ACC-1069', 'balance': 5000}]

# %% [markdown]
# Q70. Implement recursive category total for banking case 3; use sample reference ACC-1070 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_total(amounts):
    if not amounts:
        return 0
    if not isinstance(amounts[0], (int, float)):
        raise TypeError("Invalid type")
    if amounts[0] < 0:
        raise ValueError("Invalid amount")
    return amounts[0] + category_total(amounts[1:])
try:
    amounts = [1000, 2000, 0, 3000]
    print("Account:", "ACC-1070")
    print("Category Total:", category_total(amounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1070
# Category Total: 6000

# %% [markdown]
# Difficult
# Architecture, edge cases, and end-to-end banking systems.
#
# Q71. Design a configurable transformation pipeline for banking case 1; use sample reference ACC-1071 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path

# %%
def discount(amount):
    return amount * 0.90
def tax(amount):
    return amount * 1.18
def pipeline(amounts, apply_discount, apply_tax):
    if not amounts:
        raise ValueError("Empty input")
    for amount in amounts:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Invalid amount")
    result = amounts
    if apply_discount:
        result = list(map(discount, result))
    if apply_tax:
        result = list(map(tax, result))
    return result
try:
    amounts = [1000, 2000, 0]
    result = pipeline(amounts, True, True)
    print("Account:", "ACC-1071")
    print("Result:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1071
# Result: [1062.0, 2124.0, 0.0]

# %% [markdown]
# Q72. Implement memoized demand calculation for banking case 1; use sample reference ACC-1072 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import lru_cache
@lru_cache(maxsize=None)
def calculate_demand(amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Invalid amount")
    return amount * 0.10
def demand_pipeline(amounts):
    if not amounts:
        raise ValueError("Empty input")
    for amount in amounts:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Invalid amount")
    return list(map(calculate_demand, amounts))
try:
    amounts = [1000, 2000, 0, 1000]   # 0 = boundary, 1000 repeated = memoization
    result = demand_pipeline(amounts)
    print("Account:", "ACC-1072")
    print("Demand:", result)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Account: ACC-1072
# Demand: [100.0, 200.0, 0.0, 100.0]

# %% [markdown]
# Q73. Build a decorator with arguments for banking case 1; use sample reference ACC-1073 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def limit(max_amount):
    def decorator(func):
        def wrapper(amount):
            if not isinstance(amount, (int, float)):
                raise TypeError("Invalid type")
            if amount < 0:
                raise ValueError("Negative amount")
            if amount > max_amount:
                raise ValueError("Amount exceeds limit")
            return func(amount)
        return wrapper
    return decorator
@limit(10000)
def demand(amount):
    return amount * 0.10
# Normal + boundary
try:
    amounts = [1000, 10000, 0]
    print("Account:", "ACC-1073")
    print("Demand:", list(map(demand, amounts)))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Empty input
try:
    print("Empty:", list(map(demand, [])))
except (ValueError, TypeError) as e:
    print("Empty error:", e)
# Invalid type
try:
    demand("abc")
except (ValueError, TypeError) as e:
    print("Invalid type:", e)
# Realistic failure
try:
    demand(15000)
except (ValueError, TypeError) as e:
    print("Failure:", e)
# Out:
# Account: ACC-1073
# Demand: [100.0, 1000.0, 0.0]
# Empty: []
# Invalid type: Invalid type
# Failure: Amount exceeds limit

# %% [markdown]
# Q74. Create a function registry for interest offers for banking case 1; use sample reference ACC-1074 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular(amount):
    return amount * 0.05
def premium(amount):
    return amount * 0.08
offers = {
    "regular": regular,
    "premium": premium
}
def get_interest(offer, amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    if offer not in offers:
        raise ValueError("Invalid offer")
    return offers[offer](amount)
# Normal + boundary value
try:
    amounts = [10000, 0]
    print("Account:", "ACC-1074")
    print("Interest:", list(map(lambda x: get_interest("premium", x), amounts)))
except (ValueError, TypeError) as e:
    print("Error:", e)
# 1. Empty input
try:
    amounts = []
    print("Empty input:", list(map(lambda x: get_interest("premium", x), amounts)))
except (ValueError, TypeError) as e:
    print("Empty error:", e)
# 2. Invalid type
try:
    get_interest("premium", "abc")
except (ValueError, TypeError) as e:
    print("Invalid type:", e)
# 3. Boundary value
try:
    print("Boundary value:", get_interest("premium", 0))
except (ValueError, TypeError) as e:
    print("Boundary error:", e)
# 4. Realistic failure path
try:
    get_interest("gold", 10000)
except (ValueError, TypeError) as e:
    print("Failure path:", e)
# Out:
# Account: ACC-1074
# Interest: [800.0, 0.0]
# Empty input: []
# Invalid type: Invalid type
# Boundary value: 0.0
# Failure path: Invalid offer

# %% [markdown]
# Q75. Implement a currying example for amounts for banking case 1; use sample reference ACC-1075 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def add_tax(tax):
    def calculate(amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
        return amount + amount * tax / 100
    return calculate
tax_18 = add_tax(18)
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1075")
    print("Amount with tax:", tax_18(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 20000
# Account: ACC-1075
# Amount with tax: 23600.0

# %% [markdown]
# Q76. Compare lazy generators with eager map results for banking case 1; use sample reference ACC-1076 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate(amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    return amount * 1.10
def lazy_amounts(amounts):
    for amount in amounts:
        yield calculate(amount)
try:
    value = input("Enter amounts separated by space: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    print("Account:", "ACC-1076")
    print("Eager map:", list(map(calculate, amounts)))
    print("Lazy generator:", list(lazy_amounts(amounts)))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts separated by space: 2000 4000 5000
# Account: ACC-1076
# Eager map: [2200.0, 4400.0, 5500.0]
# Lazy generator: [2200.0, 4400.0, 5500.0]

# %% [markdown]
# Q77. Write a robust reduce for grouped totals for banking case 1; use sample reference ACC-1077 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def total(amounts):
    if not amounts:
        raise ValueError("Empty input")
    for amount in amounts:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
    return reduce(lambda a, b: a + b, amounts)
try:
    value = input("Enter amounts separated by space: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    print("Account:", "ACC-1077")
    print("Total:", total(amounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts separated by space: 3000 6000 90000
# Account: ACC-1077
# Total: 99000.0

# %% [markdown]
# Q78. Implement retry as a higher-transfer function for banking case 1; use sample reference ACC-1078 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def transfer(amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    if amount == 0:
        return "Transfer successful"
    raise ConnectionError("Transfer failed")
def retry(func, attempts):
    def wrapper(amount):
        for i in range(attempts):
            try:
                return func(amount)
            except ConnectionError:
                if i == attempts - 1:
                    raise
        return None
    return wrapper
safe_transfer = retry(transfer, 3)
try:
    value = input("Enter transfer amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1078")
    print(safe_transfer(amount))
except (ValueError, TypeError, ConnectionError) as e:
    print("Error:", e)
# Out:
# Enter transfer amount: 5000
# Account: ACC-1078
# Error: Transfer failed

# %% [markdown]
# Q79. Create a functional checkout with immutable updates for banking case 1; use sample reference ACC-1079 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def checkout(account, amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    if amount > account["balance"]:
        raise ValueError("Insufficient balance")
    return {
        **account,
        "balance": account["balance"] - amount
    }
try:
    value = input("Enter checkout amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    account = {
        "account": "ACC-1079",
        "balance": 5000
    }
    result = checkout(account, amount)
    print("Account:", "ACC-1079")
    print("Updated Account:", result)
    print("Original Account:", account)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter checkout amount: 30000
# Error: Insufficient balance

# %% [markdown]
# Q80. Design an end-to-end transactions analytics pipeline for banking case 1; use sample reference ACC-1080 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def analytics(transactions):
    if not transactions:
        raise ValueError("Empty input")
    for amount in transactions:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
    # filter → select positive transactions
    valid = filter(lambda x: x > 0, transactions)
    # map → add 10% to each transaction
    updated = map(lambda x: x * 1.10, valid)
    # reduce → calculate total
    return reduce(lambda a, b: a + b, updated, 0)
try:
    value = input("Enter transaction amounts separated by space: ")
    if value == "":
        raise ValueError("Empty input")
    transactions = [float(x) for x in value.split()]
    print("Account:", "ACC-1080")
    print("Analytics Total:", analytics(transactions))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter transaction amounts separated by space: 4000 8000 12000
# Account: ACC-1080
# Analytics Total: 26400.0

# %% [markdown]
# Q81. Design a configurable transformation pipeline for banking case 2; use sample reference ACC-1081 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discount(amount):
    return amount * 0.90
def tax(amount):
    return amount * 1.18
def pipeline(amounts):
    if not amounts:
        raise ValueError("Empty input")
    for amount in amounts:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
    return list(map(tax, map(discount, amounts)))
try:
    value = input("Enter amounts: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    print("Account:", "ACC-1081")
    print("Result:", pipeline(amounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts: 20000 30000
# Account: ACC-1081
# Result: [21240.0, 31860.0]

# %% [markdown]
# Q82. Implement memoized demand calculation for banking case 2; use sample reference ACC-1082 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import lru_cache
@lru_cache
def demand(amount):
    if amount < 0:
        raise ValueError("Negative amount")
    return amount * 0.10
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1082")
    print("Demand:", demand(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 2000
# Account: ACC-1082
# Demand: 200.0

# %% [markdown]
# Q83. Build a decorator with arguments for banking case 2; use sample reference ACC-1083 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def limit(max_amount):
    def decorator(func):
        def wrapper(amount):
            if not isinstance(amount, (int, float)):
                raise TypeError("Invalid type")
            if amount < 0:
                raise ValueError("Negative amount")
            if amount > max_amount:
                raise ValueError("Amount exceeds limit")
            return func(amount)
        return wrapper
    return decorator
@limit(10000)
def demand(amount):
    return amount * 0.10
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1083")
    print("Demand:", demand(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 3000
# Account: ACC-1083
# Demand: 300.0

# %% [markdown]
# Q84. Create a function registry for interest offers for banking case 2; use sample reference ACC-1084 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular(amount):
    return amount * 0.05
def premium(amount):
    return amount * 0.08
offers = {
    "regular": regular,
    "premium": premium
}
def get_interest(offer, amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    if offer not in offers:
        raise ValueError("Invalid offer")
    return offers[offer](amount)
try:
    offer = input("Enter offer (regular/premium): ")
    value = input("Enter amount: ")
    if offer == "" or value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1084")
    print("Interest:", get_interest(offer, amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter offer (regular/premium): regular
# Enter amount: 25000
# Account: ACC-1084
# Interest: 1250.0

# %% [markdown]
# Q85. Implement a currying example for amounts for banking case 2; use sample reference ACC-1085 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def add_tax(tax):
    def calculate(amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
        return amount + amount * tax / 100
    return calculate
tax_18 = add_tax(18)
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1085")
    print("Amount with tax:", tax_18(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 24000
# Account: ACC-1085
# Amount with tax: 28320.0

# %% [markdown]
# Q86. Compare lazy generators with eager map results for banking case 2; use sample reference ACC-1086 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate(amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    return amount * 1.10
def lazy(amounts):
    for amount in amounts:
        yield calculate(amount)
try:
    value = input("Enter amounts: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    print("Account:", "ACC-1086")
    print("Eager map:", list(map(calculate, amounts)))
    print("Lazy generator:", list(lazy(amounts)))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts: 2000 4000 6000
# Account: ACC-1086
# Eager map: [2200.0, 4400.0, 6600.000000000001]
# Lazy generator: [2200.0, 4400.0, 6600.000000000001]

# %% [markdown]
# Q87. Write a robust reduce for grouped totals for banking case 2; use sample reference ACC-1087 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def total(amounts):
    if not amounts:
        raise ValueError("Empty input")
    for amount in amounts:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
    return reduce(lambda a, b: a + b, amounts)
try:
    value = input("Enter amounts: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    print("Account:", "ACC-1087")
    print("Total:", total(amounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts: 5000 10000 15000
# Account: ACC-1087
# Total: 30000.0

# %% [markdown]
# Q88. Implement retry as a higher-transfer function for banking case 2; use sample reference ACC-1088 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def transfer(amount):
    if amount < 0:
        raise ValueError("Negative amount")
    if amount == 0:
        return "Success"
    raise ConnectionError("Failed")
def retry(func):
    def wrapper(amount):
        for _ in range(3):
            try:
                return func(amount)
            except ConnectionError:
                pass
        raise ConnectionError("Failed after 3 retries")
    return wrapper
safe_transfer = retry(transfer)
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1088")
    print(safe_transfer(amount))
except (ValueError, ConnectionError) as e:
    print("Error:", e)
# Out:
# Enter amount: 25000
# Account: ACC-1088
# Error: Failed after 3 retries

# %% [markdown]
# Q89. Create a functional checkout with immutable updates for banking case 2; use sample reference ACC-1089 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def checkout(balance, amount):
    if amount < 0:
        raise ValueError("Negative amount")
    if amount > balance:
        raise ValueError("Insufficient balance")
    return balance - amount
try:
    value = input("Enter checkout amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    balance = 5000
    print("Account:", "ACC-1089")
    print("New Balance:", checkout(balance, amount))
    print("Original Balance:", balance)
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter checkout amount: 2000
# Account: ACC-1089
# New Balance: 3000.0
# Original Balance: 5000

# %% [markdown]
# Q90. Design an end-to-end transactions analytics pipeline for banking case 2; use sample reference ACC-1090 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def analytics(transactions):
    if not transactions:
        raise ValueError("Empty input")
    for amount in transactions:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
    valid = filter(lambda x: x > 0, transactions)
    updated = map(lambda x: x * 1.10, valid)
    return reduce(lambda a, b: a + b, updated, 0)
try:
    value = input("Enter transaction amounts: ")
    if value == "":
        raise ValueError("Empty input")
    transactions = [float(x) for x in value.split()]
    print("Account:", "ACC-1090")
    print("Analytics Total:", analytics(transactions))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter transaction amounts: 30000
# Account: ACC-1090
# Analytics Total: 33000.0

# %% [markdown]
# Q91. Design a configurable transformation pipeline for banking case 3; use sample reference ACC-1091 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discount(amount, rate):
    return amount - (amount * rate / 100)
def tax(amount, rate):
    return amount + (amount * rate / 100)
def pipeline(amounts, discount_rate, tax_rate):
    if not amounts:
        raise ValueError("Empty input")
    for amount in amounts:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
    result = list(map(lambda x: discount(x, discount_rate), amounts))
    result = list(map(lambda x: tax(x, tax_rate), result))
    return result
try:
    value = input("Enter amounts: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    discount_rate = float(input("Enter discount rate: "))
    tax_rate = float(input("Enter tax rate: "))
    print("Account:", "ACC-1091")
    print("Result:", pipeline(amounts, discount_rate, tax_rate))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts: 2000 4000 7000
# Enter discount rate: 10
# Enter tax rate: 2
# Account: ACC-1091
# Result: [1836.0, 3672.0, 6426.0]

# %% [markdown]
# Q92. Implement memoized demand calculation for banking case 3; use sample reference ACC-1092 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import lru_cache
@lru_cache
def demand(amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    return amount * 0.10
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1092")
    print("Demand:", demand(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 24000
# Account: ACC-1092
# Demand: 2400.0

# %% [markdown]
# Q93. Build a decorator with arguments for banking case 3; use sample reference ACC-1093 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def limit(max_amount):
    def decorator(func):
        def wrapper(amount):
            if not isinstance(amount, (int, float)):
                raise TypeError("Invalid type")
            if amount < 0:
                raise ValueError("Negative amount")
            if amount > max_amount:
                raise ValueError("Amount exceeds limit")
            return func(amount)
        return wrapper
    return decorator
@limit(10000)
def demand(amount):
    return amount * 0.10
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1093")
    print("Demand:", demand(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 22000
# Account: ACC-1093
# Error: Amount exceeds limit

# %% [markdown]
# Q94. Create a function registry for interest offers for banking case 3; use sample reference ACC-1094 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular(amount):
    return amount * 0.05
def premium(amount):
    return amount * 0.08
offers = {
    "regular": regular,
    "premium": premium
}
def get_interest(offer, amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    if offer not in offers:
        raise ValueError("Invalid offer")
    return offers[offer](amount)
try:
    offer = input("Enter offer (regular/premium): ")
    value = input("Enter amount: ")
    if offer == "" or value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1094")
    print("Interest:", get_interest(offer, amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter offer (regular/premium): regular
# Enter amount: 30000
# Account: ACC-1094
# Interest: 1500.0

# %% [markdown]
# Q95. Implement a currying example for amounts for banking case 3; use sample reference ACC-1095 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def add_tax(tax_rate):
    def calculate(amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
        return amount + (amount * tax_rate / 100)
    return calculate
tax_18 = add_tax(18)
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1095")
    print("Amount with Tax:", tax_18(amount))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amount: 20000
# Account: ACC-1095
# Amount with Tax: 23600.0

# %% [markdown]
# Q96. Compare lazy generators with eager map results for banking case 3; use sample reference ACC-1096 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate(amount):
    if not isinstance(amount, (int, float)):
        raise TypeError("Invalid type")
    if amount < 0:
        raise ValueError("Negative amount")
    return amount * 1.10
def lazy(amounts):
    for amount in amounts:
        yield calculate(amount)
try:
    value = input("Enter amounts: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    print("Account:", "ACC-1096")
    # Eager map
    print("Eager Map:", list(map(calculate, amounts)))
    # Lazy generator
    print("Lazy Generator:", list(lazy(amounts)))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts: 23000 40000
# Account: ACC-1096
# Eager Map: [25300.000000000004, 44000.0]
# Lazy Generator: [25300.000000000004, 44000.0]

# %% [markdown]
# Q97. Write a robust reduce for grouped totals for banking case 3; use sample reference ACC-1097 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def grouped_total(amounts):
    if not amounts:
        raise ValueError("Empty input")
    for amount in amounts:
        if not isinstance(amount, (int, float)):
            raise TypeError("Invalid type")
        if amount < 0:
            raise ValueError("Negative amount")
    return reduce(lambda total, amount: total + amount, amounts, 0)
try:
    value = input("Enter amounts: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    print("Account:", "ACC-1097")
    print("Grouped Total:", grouped_total(amounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts: 2000 4000
# Account: ACC-1097
# Grouped Total: 6000.0

# %% [markdown]
# Q98. Implement retry as a higher-transfer function for banking case 3; use sample reference ACC-1098 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def transfer(amount):
    if amount == 0:
        return "Transfer successful"
    raise ConnectionError("Transfer failed")
def retry(func):
    def wrapper(amount):
        for i in range(3):
            try:
                return func(amount)
            except ConnectionError:
                pass
        return "Transfer failed after 3 retries"
    return wrapper
safe_transfer = retry(transfer)
try:
    value = input("Enter amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    print("Account:", "ACC-1098")
    print(safe_transfer(amount))
except ValueError as e:
    print("Error:", e)
# Out:
# Enter amount: 3000
# Account: ACC-1098
# Transfer failed after 3 retries

# %% [markdown]
# Q99. Create a functional checkout with immutable updates for banking case 3; use sample reference ACC-1099 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
def checkout(balance, amount):
    if amount < 0:
        raise ValueError("Negative amount")
    if amount > balance:
        raise ValueError("Insufficient balance")
    return balance - amount
try:
    value = input("Enter checkout amount: ")
    if value == "":
        raise ValueError("Empty input")
    amount = float(value)
    balance = 5000
    new_balance = checkout(balance, amount)
    print("Account:", "ACC-1099")
    print("New Balance:", new_balance)
    print("Original Balance:", balance)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter checkout amount: 3000
# Account: ACC-1099
# New Balance: 2000.0
# Original Balance: 5000

# %% [markdown]
# Q100. Design an end-to-end transactions analytics pipeline for banking case 3; use sample reference ACC-1100 and explain the result.
#
# Hints
#
# First express the input and return value of one pure function.
#
# Use filter for selection, map for transformation, and reduce only when a clearer built-in is not available.
#
# Test the pipeline with an empty collection and avoid mutating account records in place.
#
# Edge cases to test: empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
def analytics(transactions):
    if not transactions:
        raise ValueError("Empty input")
    valid = filter(lambda x: x > 0, transactions)
    updated = map(lambda x: x * 1.10, valid)
    return reduce(lambda a, b: a + b, updated, 0)
try:
    value = input("Enter amounts: ")
    if value == "":
        raise ValueError("Empty input")
    amounts = [float(x) for x in value.split()]
    print("Account:", "ACC-1100")
    print("Total:", analytics(amounts))
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Enter amounts: 2000 3000
# Account: ACC-1100
# Total: 5500.0
